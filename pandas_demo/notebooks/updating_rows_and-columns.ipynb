# %%
import pandas as pd

# %%
df = pd.read_csv('../data/survey.csv')
schema_df = pd.read_csv('../data/schema.csv')

# %%
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %%
df.Check.value_counts()           #returns the count of the given column
# Out:
# Check
# Apples    65437
# Name: count, dtype: int64

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                Remote  Apples
# 1      Employed, full-time                                Remote  Apples
# 2      Employed, full-time                                Remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1      Technical documentation;Blogs;Books;Written Tu...
# 2      Technical documentation;Blogs;Books;Written Tu...
# 3      Stack Overflow;How-to videos;Interactive tutorial
# 4      Technical documentation;Blogs;Written Tutorial...
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434  Technical documentation;Stack Overflow;Social ...
# 65435  Technical documentation;Blogs;Written Tutorial...
# 65436                                                NaN
#
#                                                  TechDoc YearsCode  \
# 0                                                    NaN       NaN
# 1      API document(s) and/or SDK document(s);User gu...        20
# 2      API document(s) and/or SDK document(s);User gu...        37
# 3                                                    NaN         4
# 4      API document(s) and/or SDK document(s);User gu...         9
# ...                                                  ...       ...
# 65432                                                NaN         5
# 65433                                                NaN       NaN
# 65434  API document(s) and/or SDK document(s);AI-powe...         9
# 65435  API document(s) and/or SDK document(s);User gu...         5
# 65436                                                NaN       NaN
#
#       YearsCodePro                DevType                   OrgSize  \
# 0              NaN                    NaN                       NaN
# 1               17  Developer, full-stack                       NaN
# 2               27   Developer Experience                       NaN
# 3              NaN  Developer, full-stack                       NaN
# 4              NaN  Developer, full-stack                       NaN
# ...            ...                    ...                       ...
# 65432            3             Blockchain          2 to 9 employees
# 65433          NaN                    NaN                       NaN
# 65434            5      Developer, mobile  1,000 to 4,999 employees
# 65435            2    Developer, back-end        20 to 99 employees
# 65436          NaN                    NaN                       NaN
#
#                    PurchaseInfluence  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 65432          I have some influence
# 65433                            NaN
# 65434  I have little or no influence
# 65435          I have some influence
# 65436                            NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  Ask developers I know/work with;Ask a generati...
# 65433                                                NaN
# 65434  Ask developers I know/work with;Ask a generati...
# 65435  Start a free trial;Ask developers I know/work ...
# 65436                                                NaN
#
#                                               BuildvsBuy  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  Is ready-to-go but also customizable for growt...
# 65433                                                NaN
# 65434                                                NaN
# 65435  Is ready-to-go but also customizable for growt...
# 65436                                                NaN
#
#                                              TechEndorse  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  APIs;Integrated developer community;Quality su...
# 65433                                                NaN
# 65434                                                NaN
# 65435  APIs;Customization;Connected to an open source...
# 65436                                                NaN
#
#                                                  Country           Currency  \
# 0                               United States of America                NaN
# 1      United Kingdom of Great Britain and Northern I...                NaN
# 2      United Kingdom of Great Britain and Northern I...                NaN
# 3                                                 Canada                NaN
# 4                                                 Norway                NaN
# ...                                                  ...                ...
# 65432                                                NaN                NaN
# 65433                                                NaN                NaN
# 65434                                                NaN                NaN
# 65435                                            Germany  EUR European Euro
# 65436                                                NaN                NaN
#
#        CompTotal                             LanguageHaveWorkedWith  \
# 0            NaN                                                NaN
# 1            NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2            NaN                                                 C#
# 3            NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4            NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
# ...          ...                                                ...
# 65432        NaN                                                NaN
# 65433        NaN                                                NaN
# 65434        NaN                                                NaN
# 65435        NaN           C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65436        NaN   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                    NaN
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                     C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                           Rust;SQL
# 65436                       JavaScript;Python;TypeScript
#
#                                          LanguageAdmired  \
# 0                                                    NaN
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                     C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                           Rust;SQL
# 65436                       JavaScript;Python;TypeScript
#
#                 DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                                  NaN                         NaN
# 1          Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2           Firebase Realtime Database  Firebase Realtime Database
# 3      MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                    PostgreSQL;SQLite           PostgreSQL;SQLite
# ...                                ...                         ...
# 65432                              NaN                         NaN
# 65433                              NaN                         NaN
# 65434                              NaN                         NaN
# 65435                PostgreSQL;SQLite           PostgreSQL;SQLite
# 65436  MongoDB;MySQL;Oracle;PostgreSQL    MongoDB;MySQL;PostgreSQL
#
#                   DatabaseAdmired  \
# 0                             NaN
# 1                      PostgreSQL
# 2      Firebase Realtime Database
# 3        MongoDB;MySQL;PostgreSQL
# 4               PostgreSQL;SQLite
# ...                           ...
# 65432                         NaN
# 65433                         NaN
# 65434                         NaN
# 65435           PostgreSQL;SQLite
# 65436    MongoDB;MySQL;PostgreSQL
#
#                                   PlatformHaveWorkedWith  \
# 0                                                    NaN
# 1               Amazon Web Services (AWS);Heroku;Netlify
# 2                                           Google Cloud
# 3                Amazon Web Services (AWS);Fly.io;Heroku
# 4                                                    NaN
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436  Amazon Web Services (AWS);Cloudflare;Google Cl...
#
#                          PlatformWantToWorkWith  \
# 0                                           NaN
# 1      Amazon Web Services (AWS);Heroku;Netlify
# 2                                  Google Cloud
# 3              Amazon Web Services (AWS);Vercel
# 4                                           NaN
# ...                                         ...
# 65432                                       NaN
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436    Cloudflare;Google Cloud;Netlify;Vercel
#
#                                 PlatformAdmired  \
# 0                                           NaN
# 1      Amazon Web Services (AWS);Heroku;Netlify
# 2                                  Google Cloud
# 3                     Amazon Web Services (AWS)
# 4                                           NaN
# ...                                         ...
# 65432                                       NaN
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436    Cloudflare;Google Cloud;Netlify;Vercel
#
#                             WebframeHaveWorkedWith  \
# 0                                              NaN
# 1                    Express;Next.js;Node.js;React
# 2                                     ASP.NET CORE
# 3           jQuery;Next.js;Node.js;React;WordPress
# 4                                              NaN
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435                        Angular;Node.js;React
# 65436  Django;Express;jQuery;Next.js;Node.js;React
#
#                      WebframeWantToWorkWith  \
# 0                                       NaN
# 1          Express;Htmx;Node.js;React;Remix
# 2                              ASP.NET CORE
# 3              jQuery;Next.js;Node.js;React
# 4                                       NaN
# ...                                     ...
# 65432                                   NaN
# 65433                                   NaN
# 65434                                   NaN
# 65435                                   NaN
# 65436  Django;Express;Next.js;Node.js;React
#
#                             WebframeAdmired  \
# 0                                       NaN
# 1                     Express;Node.js;React
# 2                              ASP.NET CORE
# 3              jQuery;Next.js;Node.js;React
# 4                                       NaN
# ...                                     ...
# 65432                                   NaN
# 65433                                   NaN
# 65434                                   NaN
# 65435                                   NaN
# 65436  Django;Express;Next.js;Node.js;React
#
#                         EmbeddedHaveWorkedWith     EmbeddedWantToWorkWith  \
# 0                                          NaN                        NaN
# 1                                          NaN                        NaN
# 2                                  Rasberry Pi                Rasberry Pi
# 3                                  Rasberry Pi                        NaN
# 4                      CMake;Cargo;Rasberry Pi          CMake;Rasberry Pi
# ...                                        ...                        ...
# 65432                                      NaN                        NaN
# 65433                                      NaN                        NaN
# 65434                                      NaN                        NaN
# 65435  Arduino;CMake;Cargo;GNU GCC;Rasberry Pi  Cargo;GNU GCC;Rasberry Pi
# 65436                                      NaN                        NaN
#
#                  EmbeddedAdmired  \
# 0                            NaN
# 1                            NaN
# 2                    Rasberry Pi
# 3                            NaN
# 4              CMake;Rasberry Pi
# ...                          ...
# 65432                        NaN
# 65433                        NaN
# 65434                        NaN
# 65435  Cargo;GNU GCC;Rasberry Pi
# 65436                        NaN
#
#                                 MiscTechHaveWorkedWith  \
# 0                                                  NaN
# 1                                                  NaN
# 2      .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                         NumPy;Pandas;Ruff;TensorFlow
# 4                                                  NaN
# ...                                                ...
# 65432                                              NaN
# 65433                                              NaN
# 65434                                              NaN
# 65435                                       GTK;OpenGL
# 65436                                              NaN
#
#                                 MiscTechWantToWorkWith  \
# 0                                                  NaN
# 1                                                  NaN
# 2      .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 65432                                              NaN
# 65433                                              NaN
# 65434                                              NaN
# 65435                                              NaN
# 65436                                              NaN
#
#                                        MiscTechAdmired  \
# 0                                                  NaN
# 1                                                  NaN
# 2      .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 65432                                              NaN
# 65433                                              NaN
# 65434                                              NaN
# 65435                                              NaN
# 65436                                              NaN
#
#                            ToolsTechHaveWorkedWith  \
# 0                                              NaN
# 1      Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                          MSBuild
# 3                                   Docker;npm;Pip
# 4                                     APT;Make;npm
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435       Ansible;APT;Docker;Make;npm;Pip;Podman
# 65436                                 npm;Pip;Vite
#
#                            ToolsTechWantToWorkWith  \
# 0                                              NaN
# 1      Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                          MSBuild
# 3                            Docker;Kubernetes;npm
# 4                                         APT;Make
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435       Ansible;APT;Docker;Make;npm;Pip;Podman
# 65436                                 npm;Pip;Vite
#
#                                   ToolsTechAdmired  \
# 0                                              NaN
# 1      Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                          MSBuild
# 3                                       Docker;npm
# 4                                         APT;Make
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435       Ansible;APT;Docker;Make;npm;Pip;Podman
# 65436                                 npm;Pip;Vite
#
#               NEWCollabToolsHaveWorkedWith  \
# 0                                      NaN
# 1      PyCharm;Visual Studio Code;WebStorm
# 2                            Visual Studio
# 3                                      NaN
# 4                                      Vim
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435               Vim;Visual Studio Code
# 65436                   Visual Studio Code
#
#               NEWCollabToolsWantToWorkWith  \
# 0                                      NaN
# 1      PyCharm;Visual Studio Code;WebStorm
# 2                            Visual Studio
# 3                                      NaN
# 4                                      Vim
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435               Vim;Visual Studio Code
# 65436                   Visual Studio Code
#
#                      NEWCollabToolsAdmired  \
# 0                                      NaN
# 1      PyCharm;Visual Studio Code;WebStorm
# 2                            Visual Studio
# 3                                      NaN
# 4                                      Vim
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435               Vim;Visual Studio Code
# 65436                   Visual Studio Code
#
#                               OpSysPersonal use  \
# 0                                           NaN
# 1                                 MacOS;Windows
# 2                                       Windows
# 3                                           NaN
# 4                       Other (please specify):
# ...                                         ...
# 65432                                       NaN
# 65433                                       NaN
# 65434                                       NaN
# 65435  Android;Other Linux-based;Ubuntu;Windows
# 65436                                   Windows
#
#                  OpSysProfessional use  \
# 0                                  NaN
# 1                                MacOS
# 2                              Windows
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 65432                              NaN
# 65433                              NaN
# 65434                              NaN
# 65435  Fedora;Other Linux-based;Ubuntu
# 65436                    MacOS;Windows
#
#                           OfficeStackAsyncHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      GitHub Discussions;Markdown File;Obsidian;Stac...
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435      Confluence;Jira;Markdown File;Obsidian;Trello
# 65436                                                NaN
#
#                   OfficeStackAsyncWantToWorkWith  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4      GitHub Discussions;Markdown File;Obsidian
# ...                                          ...
# 65432                                        NaN
# 65433                                        NaN
# 65434                                        NaN
# 65435       Confluence;Jira;Markdown File;Trello
# 65436                                        NaN
#
#                          OfficeStackAsyncAdmired  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4      GitHub Discussions;Markdown File;Obsidian
# ...                                          ...
# 65432                                        NaN
# 65433                                        NaN
# 65434                                        NaN
# 65435       Confluence;Jira;Markdown File;Trello
# 65436                                        NaN
#
#                       OfficeStackSyncHaveWorkedWith  \
# 0                                               NaN
# 1                             Microsoft Teams;Slack
# 2      Google Chat;Google Meet;Microsoft Teams;Zoom
# 3                                               NaN
# 4                                  Discord;Whatsapp
# ...                                             ...
# 65432                                           NaN
# 65433                                           NaN
# 65434                                           NaN
# 65435        Discord;Jitsi;Microsoft Teams;Whatsapp
# 65436                                           NaN
#
#       OfficeStackSyncWantToWorkWith        OfficeStackSyncAdmired  \
# 0                               NaN                           NaN
# 1                             Slack                         Slack
# 2      Google Chat;Google Meet;Zoom  Google Chat;Google Meet;Zoom
# 3                               NaN                           NaN
# 4                  Discord;Whatsapp              Discord;Whatsapp
# ...                             ...                           ...
# 65432                           NaN                           NaN
# 65433                           NaN                           NaN
# 65434                           NaN                           NaN
# 65435        Discord;Jitsi;Whatsapp        Discord;Jitsi;Whatsapp
# 65436                           NaN                           NaN
#
#       AISearchDevHaveWorkedWith AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                           NaN                       NaN                NaN
# 1                           NaN                       NaN                NaN
# 2                           NaN                       NaN                NaN
# 3                           NaN                       NaN                NaN
# 4                           NaN                       NaN                NaN
# ...                         ...                       ...                ...
# 65432                       NaN                       NaN                NaN
# 65433                       NaN                       NaN                NaN
# 65434                       NaN                       NaN                NaN
# 65435                       NaN                       NaN                NaN
# 65436                       NaN                       NaN                NaN
#
#                                               NEWSOSites  \
# 0      I have never visited Stack Overflow or the Sta...
# 1      Stack Overflow for Teams (private knowledge sh...
# 2      Stack Overflow;Stack Exchange;Stack Overflow B...
# 3                                         Stack Overflow
# 4      Stack Overflow for Teams (private knowledge sh...
# ...                                                  ...
# 65432                                                NaN
# 65433                      Stack Overflow;Stack Exchange
# 65434                                                NaN
# 65435                      Stack Overflow;Stack Exchange
# 65436                                     Stack Overflow
#
#                            SOVisitFreq SOAccount  \
# 0                                  NaN       NaN
# 1               Multiple times per day       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily        No
# 4               Multiple times per day       Yes
# ...                                ...       ...
# 65432                              NaN       NaN
# 65433                              NaN       NaN
# 65434                              NaN       NaN
# 65435  A few times per month or weekly        No
# 65436            Daily or almost daily       Yes
#
#                                 SOPartFreq  \
# 0                                      NaN
# 1                   Multiple times per day
# 2                   Multiple times per day
# 3                                      NaN
# 4                   Multiple times per day
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435                                  NaN
# 65436  Less than once per month or monthly
#
#                                                    SOHow           SOComm  \
# 0                                                    NaN              NaN
# 1      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                         Quickly finding code solutions   No, not really
# 4      Quickly finding code solutions;Engage with com...  Yes, definitely
# ...                                                  ...              ...
# 65432                                                NaN              NaN
# 65433                                                NaN              NaN
# 65434                                                NaN              NaN
# 65435                     Quickly finding code solutions   No, not really
# 65436                     Quickly finding code solutions    Yes, somewhat
#
#                       AISelect          AISent  \
# 0                          Yes  Very favorable
# 1      No, and I don't plan to             NaN
# 2      No, and I don't plan to             NaN
# 3                          Yes  Very favorable
# 4      No, and I don't plan to             NaN
# ...                        ...             ...
# 65432                      Yes       Favorable
# 65433                      NaN             NaN
# 65434                      NaN             NaN
# 65435  No, and I don't plan to             NaN
# 65436                      NaN             NaN
#
#                                                    AIBen  \
# 0                                  Increase productivity
# 1                                                    NaN
# 2                                                    NaN
# 3      Increase productivity;Greater efficiency;Impro...
# 4                                                    NaN
# ...                                                  ...
# 65432  Increase productivity;Greater efficiency;Speed...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#                             AIAcc  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                  Somewhat trust
# 4                             NaN
# ...                           ...
# 65432  Neither trust nor distrust
# 65433                         NaN
# 65434                         NaN
# 65435                         NaN
# 65436                         NaN
#
#                                            AIComplex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                      Bad at handling complex tasks
# 4                                                NaN
# ...                                              ...
# 65432  Good, but not great at handling complex tasks
# 65433                                            NaN
# 65434                                            NaN
# 65435                                            NaN
# 65436                                            NaN
#
#                                    AIToolCurrently Using  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Learning about a codebase;Project planning;Wri...
# 4                                                    NaN
# ...                                                  ...
# 65432  Learning about a codebase;Project planning;Wri...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#                                AIToolInterested in Using  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Testing code;Committing and reviewing code;Pre...
# 4                                                    NaN
# ...                                                  ...
# 65432  Debugging and getting help;Testing code;Deploy...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#        AIToolNot interested in Using  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 65432  Committing and reviewing code
# 65433                            NaN
# 65434                            NaN
# 65435                            NaN
# 65436                            NaN
#
#                               AINextMuch more integrated AINextNo change  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3      Learning about a codebase;Project planning;Wri...             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 65432  Writing code;Search for answers;Generating con...             NaN
# 65433                                                NaN             NaN
# 65434                                                NaN             NaN
# 65435                                                NaN             NaN
# 65436                                                NaN             NaN
#
#                                    AINextMore integrated  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  Learning about a codebase;Project planning;Doc...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#       AINextLess integrated AINextMuch less integrated AIThreat  \
# 0                       NaN                        NaN      NaN
# 1                       NaN                        NaN      NaN
# 2                       NaN                        NaN      NaN
# 3                       NaN                        NaN       No
# 4                       NaN                        NaN      NaN
# ...                     ...                        ...      ...
# 65432                   NaN                        NaN       No
# 65433                   NaN                        NaN      NaN
# 65434                   NaN                        NaN      NaN
# 65435                   NaN                        NaN      NaN
# 65436                   NaN                        NaN      NaN
#
#                                                 AIEthics  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Circulating misinformation or disinformation;M...
# 4                                                    NaN
# ...                                                  ...
# 65432       Circulating misinformation or disinformation
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#                                             AIChallenges TBranch  \
# 0                                                    NaN      No
# 1                                                    NaN     Yes
# 2                                                    NaN      No
# 3                      Don’t trust the output or answers     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 65432  AI tools lack context of codebase,  internal a...     NaN
# 65433                                                NaN     NaN
# 65434                                                NaN     NaN
# 65435                                                NaN     Yes
# 65436                                                NaN     NaN
#
#                        ICorPM  WorkExp Knowledge_1 Knowledge_2 Knowledge_3  \
# 0                         NaN      NaN         NaN         NaN         NaN
# 1      Individual contributor     17.0       Agree    Disagree       Agree
# 2                         NaN      NaN         NaN         NaN         NaN
# 3                         NaN      NaN         NaN         NaN         NaN
# 4                         NaN      NaN         NaN         NaN         NaN
# ...                       ...      ...         ...         ...         ...
# 65432                     NaN      NaN         NaN         NaN         NaN
# 65433                     NaN      NaN         NaN         NaN         NaN
# 65434                     NaN      NaN         NaN         NaN         NaN
# 65435  Individual contributor      5.0         NaN         NaN         NaN
# 65436                     NaN      NaN         NaN         NaN         NaN
#
#       Knowledge_4 Knowledge_5                 Knowledge_6 Knowledge_7  \
# 0             NaN         NaN                         NaN         NaN
# 1           Agree       Agree  Neither agree nor disagree    Disagree
# 2             NaN         NaN                         NaN         NaN
# 3             NaN         NaN                         NaN         NaN
# 4             NaN         NaN                         NaN         NaN
# ...           ...         ...                         ...         ...
# 65432         NaN         NaN                         NaN         NaN
# 65433         NaN         NaN                         NaN         NaN
# 65434         NaN         NaN                         NaN         NaN
# 65435         NaN         NaN                         NaN         NaN
# 65436         NaN         NaN                         NaN         NaN
#
#       Knowledge_8 Knowledge_9 Frequency_1 Frequency_2 Frequency_3  \
# 0             NaN         NaN         NaN         NaN         NaN
# 1           Agree       Agree         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 65432         NaN         NaN         NaN         NaN         NaN
# 65433         NaN         NaN         NaN         NaN         NaN
# 65434         NaN         NaN         NaN         NaN         NaN
# 65435         NaN         NaN         NaN         NaN         NaN
# 65436         NaN         NaN         NaN         NaN         NaN
#
#       TimeSearching TimeAnswering Frustration ProfessionalTech  \
# 0               NaN           NaN         NaN              NaN
# 1               NaN           NaN         NaN              NaN
# 2               NaN           NaN         NaN              NaN
# 3               NaN           NaN         NaN              NaN
# 4               NaN           NaN         NaN              NaN
# ...             ...           ...         ...              ...
# 65432           NaN           NaN         NaN              NaN
# 65433           NaN           NaN         NaN              NaN
# 65434           NaN           NaN         NaN              NaN
# 65435           NaN           NaN         NaN              NaN
# 65436           NaN           NaN         NaN              NaN
#
#       ProfessionalCloud ProfessionalQuestion Industry  JobSatPoints_1  \
# 0                   NaN                  NaN      NaN             NaN
# 1                   NaN                  NaN      NaN             0.0
# 2                   NaN                  NaN      NaN             NaN
# 3                   NaN                  NaN      NaN             NaN
# 4                   NaN                  NaN      NaN             NaN
# ...                 ...                  ...      ...             ...
# 65432               NaN                  NaN      NaN             NaN
# 65433               NaN                  NaN      NaN             NaN
# 65434               NaN                  NaN      NaN             NaN
# 65435               NaN                  NaN      NaN             0.0
# 65436               NaN                  NaN      NaN             NaN
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# 0                 NaN             NaN             NaN             NaN
# 1                 0.0             0.0             0.0             0.0
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 65432             NaN             NaN             NaN             NaN
# 65433             NaN             NaN             NaN             NaN
# 65434             NaN             NaN             NaN             NaN
# 65435             0.0             0.0             0.0             0.0
# 65436             NaN             NaN             NaN             NaN
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# 0                 NaN             NaN              NaN              NaN
# 1                 0.0             0.0              0.0              0.0
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4                 NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 65432             NaN             NaN              NaN              NaN
# 65433             NaN             NaN              NaN              NaN
# 65434             NaN             NaN              NaN              NaN
# 65435             0.0             0.0              0.0              0.0
# 65436             NaN             NaN              NaN              NaN
#
#                 SurveyLength SurveyEase  ConvertedCompYearly  JobSat
# 0                        NaN        NaN                  NaN     NaN
# 1                        NaN        NaN                  NaN     NaN
# 2      Appropriate in length       Easy                  NaN     NaN
# 3                   Too long       Easy                  NaN     NaN
# 4                  Too short       Easy                  NaN     NaN
# ...                      ...        ...                  ...     ...
# 65432                    NaN        NaN                  NaN     NaN
# 65433                    NaN        NaN                  NaN     NaN
# 65434                    NaN        NaN                  NaN     NaN
# 65435                    NaN        NaN                  NaN     NaN
# 65436                    NaN        NaN                  NaN     NaN
#
# [65437 rows x 114 columns]

# %%
df.columns.to_list()
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'Check',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'TechDoc',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'BuildvsBuy',
#  'TechEndorse',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'LanguageAdmired',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'DatabaseAdmired',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'PlatformAdmired',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'WebframeAdmired',
#  'EmbeddedHaveWorkedWith',
#  'EmbeddedWantToWorkWith',
#  'EmbeddedAdmired',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'MiscTechAdmired',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'ToolsTechAdmired',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
#  'NEWCollabToolsAdmired',
#  'OpSysPersonal use',
#  'OpSysProfessional use',
#  'OfficeStackAsyncHaveWorkedWith',
#  'OfficeStackAsyncWantToWorkWith',
#  'OfficeStackAsyncAdmired',
#  'OfficeStackSyncHaveWorkedWith',
#  'OfficeStackSyncWantToWorkWith',
#  'OfficeStackSyncAdmired',
#  'AISearchDevHaveWorkedWith',
#  'AISearchDevWantToWorkWith',
#  'AISearchDevAdmired',
#  'NEWSOSites',
#  'SOVisitFreq',
#  'SOAccount',
#  'SOPartFreq',
#  'SOHow',
#  'SOComm',
#  'AISelect',
#  'AISent',
#  'AIBen',
#  'AIAcc',
#  'AIComplex',
#  'AIToolCurrently Using',
#  'AIToolInterested in Using',
#  'AIToolNot interested in Using',
#  'AINextMuch more integrated',
#  'AINextNo change',
#  'AINextMore integrated',
#  'AINextLess integrated',
#  'AINextMuch less integrated',
#  'AIThreat',
#  'AIEthics',
#  'AIChallenges',
#  'TBranch',
#  'ICorPM',
#  'WorkExp',
#  'Knowledge_1',
#  'Knowledge_2',
#  'Knowledge_3',
#  'Knowledge_4',
#  'Knowledge_5',
#  'Knowledge_6',
#  'Knowledge_7',
#  'Knowledge_8',
#  'Knowledge_9',
#  'Frequency_1',
#  'Frequency_2',
#  'Frequency_3',
#  'TimeSearching',
#  'TimeAnswering',
#  'Frustration',
#  'ProfessionalTech',
#  'ProfessionalCloud',
#  'ProfessionalQuestion',
#  'Industry',
#  'JobSatPoints_1',
#  'JobSatPoints_4',
#  'JobSatPoints_5',
#  'JobSatPoints_6',
#  'JobSatPoints_7',
#  'JobSatPoints_8',
#  'JobSatPoints_9',
#  'JobSatPoints_10',
#  'JobSatPoints_11',
#  'SurveyLength',
#  'SurveyEase',
#  'ConvertedCompYearly',
#  'JobSat']

# %%
df.apply(len)
# Out:
# ResponseId                        65437
# MainBranch                        65437
# Age                               65437
# Employment                        65437
# RemoteWork                        65437
# Check                             65437
# CodingActivities                  65437
# EdLevel                           65437
# LearnCode                         65437
# LearnCodeOnline                   65437
# TechDoc                           65437
# YearsCode                         65437
# YearsCodePro                      65437
# DevType                           65437
# OrgSize                           65437
# PurchaseInfluence                 65437
# BuyNewTool                        65437
# BuildvsBuy                        65437
# TechEndorse                       65437
# Country                           65437
# Currency                          65437
# CompTotal                         65437
# LanguageHaveWorkedWith            65437
# LanguageWantToWorkWith            65437
# LanguageAdmired                   65437
# DatabaseHaveWorkedWith            65437
# DatabaseWantToWorkWith            65437
# DatabaseAdmired                   65437
# PlatformHaveWorkedWith            65437
# PlatformWantToWorkWith            65437
# PlatformAdmired                   65437
# WebframeHaveWorkedWith            65437
# WebframeWantToWorkWith            65437
# WebframeAdmired                   65437
# EmbeddedHaveWorkedWith            65437
# EmbeddedWantToWorkWith            65437
# EmbeddedAdmired                   65437
# MiscTechHaveWorkedWith            65437
# MiscTechWantToWorkWith            65437
# MiscTechAdmired                   65437
# ToolsTechHaveWorkedWith           65437
# ToolsTechWantToWorkWith           65437
# ToolsTechAdmired                  65437
# NEWCollabToolsHaveWorkedWith      65437
# NEWCollabToolsWantToWorkWith      65437
# NEWCollabToolsAdmired             65437
# OpSysPersonal use                 65437
# OpSysProfessional use             65437
# OfficeStackAsyncHaveWorkedWith    65437
# OfficeStackAsyncWantToWorkWith    65437
# OfficeStackAsyncAdmired           65437
# OfficeStackSyncHaveWorkedWith     65437
# OfficeStackSyncWantToWorkWith     65437
# OfficeStackSyncAdmired            65437
# AISearchDevHaveWorkedWith         65437
# AISearchDevWantToWorkWith         65437
# AISearchDevAdmired                65437
# NEWSOSites                        65437
# SOVisitFreq                       65437
# SOAccount                         65437
# SOPartFreq                        65437
# SOHow                             65437
# SOComm                            65437
# AISelect                          65437
# AISent                            65437
# AIBen                             65437
# AIAcc                             65437
# AIComplex                         65437
# AIToolCurrently Using             65437
# AIToolInterested in Using         65437
# AIToolNot interested in Using     65437
# AINextMuch more integrated        65437
# AINextNo change                   65437
# AINextMore integrated             65437
# AINextLess integrated             65437
# AINextMuch less integrated        65437
# AIThreat                          65437
# AIEthics                          65437
# AIChallenges                      65437
# TBranch                           65437
# ICorPM                            65437
# WorkExp                           65437
# Knowledge_1                       65437
# Knowledge_2                       65437
# Knowledge_3                       65437
# Knowledge_4                       65437
# Knowledge_5                       65437
# Knowledge_6                       65437
# Knowledge_7                       65437
# Knowledge_8                       65437
# Knowledge_9                       65437
# Frequency_1                       65437
# Frequency_2                       65437
# Frequency_3                       65437
# TimeSearching                     65437
# TimeAnswering                     65437
# Frustration                       65437
# ProfessionalTech                  65437
# ProfessionalCloud                 65437
# ProfessionalQuestion              65437
# Industry                          65437
# JobSatPoints_1                    65437
# JobSatPoints_4                    65437
# JobSatPoints_5                    65437
# JobSatPoints_6                    65437
# JobSatPoints_7                    65437
# JobSatPoints_8                    65437
# JobSatPoints_9                    65437
# JobSatPoints_10                   65437
# JobSatPoints_11                   65437
# SurveyLength                      65437
# SurveyEase                        65437
# ConvertedCompYearly               65437
# JobSat                            65437
# dtype: int64

# %%
df.apply(len, axis = 'columns')
# Out:
# 0        114
# 1        114
# 2        114
# 3        114
# 4        114
#         ...
# 65432    114
# 65433    114
# 65434    114
# 65435    114
# 65436    114
# Length: 65437, dtype: int64

# %%
df['RemoteWork'] = df['RemoteWork'].str.lower()

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                remote  Apples
# 1      Employed, full-time                                remote  Apples
# 2      Employed, full-time                                remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                remote  Apples
# 65433  Employed, full-time                                remote  Apples
# 65434  Employed, full-time                             in-person  Apples
# 65435  Employed, full-time  hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1      Technical documentation;Blogs;Books;Written Tu...
# 2      Technical documentation;Blogs;Books;Written Tu...
# 3      Stack Overflow;How-to videos;Interactive tutorial
# 4      Technical documentation;Blogs;Written Tutorial...
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434  Technical documentation;Stack Overflow;Social ...
# 65435  Technical documentation;Blogs;Written Tutorial...
# 65436                                                NaN
#
#                                                  TechDoc YearsCode  \
# 0                                                    NaN       NaN
# 1      API document(s) and/or SDK document(s);User gu...        20
# 2      API document(s) and/or SDK document(s);User gu...        37
# 3                                                    NaN         4
# 4      API document(s) and/or SDK document(s);User gu...         9
# ...                                                  ...       ...
# 65432                                                NaN         5
# 65433                                                NaN       NaN
# 65434  API document(s) and/or SDK document(s);AI-powe...         9
# 65435  API document(s) and/or SDK document(s);User gu...         5
# 65436                                                NaN       NaN
#
#       YearsCodePro                DevType                   OrgSize  \
# 0              NaN                    NaN                       NaN
# 1               17  Developer, full-stack                       NaN
# 2               27   Developer Experience                       NaN
# 3              NaN  Developer, full-stack                       NaN
# 4              NaN  Developer, full-stack                       NaN
# ...            ...                    ...                       ...
# 65432            3             Blockchain          2 to 9 employees
# 65433          NaN                    NaN                       NaN
# 65434            5      Developer, mobile  1,000 to 4,999 employees
# 65435            2    Developer, back-end        20 to 99 employees
# 65436          NaN                    NaN                       NaN
#
#                    PurchaseInfluence  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 65432          I have some influence
# 65433                            NaN
# 65434  I have little or no influence
# 65435          I have some influence
# 65436                            NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  Ask developers I know/work with;Ask a generati...
# 65433                                                NaN
# 65434  Ask developers I know/work with;Ask a generati...
# 65435  Start a free trial;Ask developers I know/work ...
# 65436                                                NaN
#
#                                               BuildvsBuy  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  Is ready-to-go but also customizable for growt...
# 65433                                                NaN
# 65434                                                NaN
# 65435  Is ready-to-go but also customizable for growt...
# 65436                                                NaN
#
#                                              TechEndorse  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  APIs;Integrated developer community;Quality su...
# 65433                                                NaN
# 65434                                                NaN
# 65435  APIs;Customization;Connected to an open source...
# 65436                                                NaN
#
#                                                  Country           Currency  \
# 0                               United States of America                NaN
# 1      United Kingdom of Great Britain and Northern I...                NaN
# 2      United Kingdom of Great Britain and Northern I...                NaN
# 3                                                 Canada                NaN
# 4                                                 Norway                NaN
# ...                                                  ...                ...
# 65432                                                NaN                NaN
# 65433                                                NaN                NaN
# 65434                                                NaN                NaN
# 65435                                            Germany  EUR European Euro
# 65436                                                NaN                NaN
#
#        CompTotal                             LanguageHaveWorkedWith  \
# 0            NaN                                                NaN
# 1            NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2            NaN                                                 C#
# 3            NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4            NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
# ...          ...                                                ...
# 65432        NaN                                                NaN
# 65433        NaN                                                NaN
# 65434        NaN                                                NaN
# 65435        NaN           C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65436        NaN   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                    NaN
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                     C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                           Rust;SQL
# 65436                       JavaScript;Python;TypeScript
#
#                                          LanguageAdmired  \
# 0                                                    NaN
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                     C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                           Rust;SQL
# 65436                       JavaScript;Python;TypeScript
#
#                 DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                                  NaN                         NaN
# 1          Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2           Firebase Realtime Database  Firebase Realtime Database
# 3      MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                    PostgreSQL;SQLite           PostgreSQL;SQLite
# ...                                ...                         ...
# 65432                              NaN                         NaN
# 65433                              NaN                         NaN
# 65434                              NaN                         NaN
# 65435                PostgreSQL;SQLite           PostgreSQL;SQLite
# 65436  MongoDB;MySQL;Oracle;PostgreSQL    MongoDB;MySQL;PostgreSQL
#
#                   DatabaseAdmired  \
# 0                             NaN
# 1                      PostgreSQL
# 2      Firebase Realtime Database
# 3        MongoDB;MySQL;PostgreSQL
# 4               PostgreSQL;SQLite
# ...                           ...
# 65432                         NaN
# 65433                         NaN
# 65434                         NaN
# 65435           PostgreSQL;SQLite
# 65436    MongoDB;MySQL;PostgreSQL
#
#                                   PlatformHaveWorkedWith  \
# 0                                                    NaN
# 1               Amazon Web Services (AWS);Heroku;Netlify
# 2                                           Google Cloud
# 3                Amazon Web Services (AWS);Fly.io;Heroku
# 4                                                    NaN
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436  Amazon Web Services (AWS);Cloudflare;Google Cl...
#
#                          PlatformWantToWorkWith  \
# 0                                           NaN
# 1      Amazon Web Services (AWS);Heroku;Netlify
# 2                                  Google Cloud
# 3              Amazon Web Services (AWS);Vercel
# 4                                           NaN
# ...                                         ...
# 65432                                       NaN
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436    Cloudflare;Google Cloud;Netlify;Vercel
#
#                                 PlatformAdmired  \
# 0                                           NaN
# 1      Amazon Web Services (AWS);Heroku;Netlify
# 2                                  Google Cloud
# 3                     Amazon Web Services (AWS)
# 4                                           NaN
# ...                                         ...
# 65432                                       NaN
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436    Cloudflare;Google Cloud;Netlify;Vercel
#
#                             WebframeHaveWorkedWith  \
# 0                                              NaN
# 1                    Express;Next.js;Node.js;React
# 2                                     ASP.NET CORE
# 3           jQuery;Next.js;Node.js;React;WordPress
# 4                                              NaN
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435                        Angular;Node.js;React
# 65436  Django;Express;jQuery;Next.js;Node.js;React
#
#                      WebframeWantToWorkWith  \
# 0                                       NaN
# 1          Express;Htmx;Node.js;React;Remix
# 2                              ASP.NET CORE
# 3              jQuery;Next.js;Node.js;React
# 4                                       NaN
# ...                                     ...
# 65432                                   NaN
# 65433                                   NaN
# 65434                                   NaN
# 65435                                   NaN
# 65436  Django;Express;Next.js;Node.js;React
#
#                             WebframeAdmired  \
# 0                                       NaN
# 1                     Express;Node.js;React
# 2                              ASP.NET CORE
# 3              jQuery;Next.js;Node.js;React
# 4                                       NaN
# ...                                     ...
# 65432                                   NaN
# 65433                                   NaN
# 65434                                   NaN
# 65435                                   NaN
# 65436  Django;Express;Next.js;Node.js;React
#
#                         EmbeddedHaveWorkedWith     EmbeddedWantToWorkWith  \
# 0                                          NaN                        NaN
# 1                                          NaN                        NaN
# 2                                  Rasberry Pi                Rasberry Pi
# 3                                  Rasberry Pi                        NaN
# 4                      CMake;Cargo;Rasberry Pi          CMake;Rasberry Pi
# ...                                        ...                        ...
# 65432                                      NaN                        NaN
# 65433                                      NaN                        NaN
# 65434                                      NaN                        NaN
# 65435  Arduino;CMake;Cargo;GNU GCC;Rasberry Pi  Cargo;GNU GCC;Rasberry Pi
# 65436                                      NaN                        NaN
#
#                  EmbeddedAdmired  \
# 0                            NaN
# 1                            NaN
# 2                    Rasberry Pi
# 3                            NaN
# 4              CMake;Rasberry Pi
# ...                          ...
# 65432                        NaN
# 65433                        NaN
# 65434                        NaN
# 65435  Cargo;GNU GCC;Rasberry Pi
# 65436                        NaN
#
#                                 MiscTechHaveWorkedWith  \
# 0                                                  NaN
# 1                                                  NaN
# 2      .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                         NumPy;Pandas;Ruff;TensorFlow
# 4                                                  NaN
# ...                                                ...
# 65432                                              NaN
# 65433                                              NaN
# 65434                                              NaN
# 65435                                       GTK;OpenGL
# 65436                                              NaN
#
#                                 MiscTechWantToWorkWith  \
# 0                                                  NaN
# 1                                                  NaN
# 2      .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 65432                                              NaN
# 65433                                              NaN
# 65434                                              NaN
# 65435                                              NaN
# 65436                                              NaN
#
#                                        MiscTechAdmired  \
# 0                                                  NaN
# 1                                                  NaN
# 2      .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 65432                                              NaN
# 65433                                              NaN
# 65434                                              NaN
# 65435                                              NaN
# 65436                                              NaN
#
#                            ToolsTechHaveWorkedWith  \
# 0                                              NaN
# 1      Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                          MSBuild
# 3                                   Docker;npm;Pip
# 4                                     APT;Make;npm
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435       Ansible;APT;Docker;Make;npm;Pip;Podman
# 65436                                 npm;Pip;Vite
#
#                            ToolsTechWantToWorkWith  \
# 0                                              NaN
# 1      Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                          MSBuild
# 3                            Docker;Kubernetes;npm
# 4                                         APT;Make
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435       Ansible;APT;Docker;Make;npm;Pip;Podman
# 65436                                 npm;Pip;Vite
#
#                                   ToolsTechAdmired  \
# 0                                              NaN
# 1      Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                          MSBuild
# 3                                       Docker;npm
# 4                                         APT;Make
# ...                                            ...
# 65432                                          NaN
# 65433                                          NaN
# 65434                                          NaN
# 65435       Ansible;APT;Docker;Make;npm;Pip;Podman
# 65436                                 npm;Pip;Vite
#
#               NEWCollabToolsHaveWorkedWith  \
# 0                                      NaN
# 1      PyCharm;Visual Studio Code;WebStorm
# 2                            Visual Studio
# 3                                      NaN
# 4                                      Vim
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435               Vim;Visual Studio Code
# 65436                   Visual Studio Code
#
#               NEWCollabToolsWantToWorkWith  \
# 0                                      NaN
# 1      PyCharm;Visual Studio Code;WebStorm
# 2                            Visual Studio
# 3                                      NaN
# 4                                      Vim
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435               Vim;Visual Studio Code
# 65436                   Visual Studio Code
#
#                      NEWCollabToolsAdmired  \
# 0                                      NaN
# 1      PyCharm;Visual Studio Code;WebStorm
# 2                            Visual Studio
# 3                                      NaN
# 4                                      Vim
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435               Vim;Visual Studio Code
# 65436                   Visual Studio Code
#
#                               OpSysPersonal use  \
# 0                                           NaN
# 1                                 MacOS;Windows
# 2                                       Windows
# 3                                           NaN
# 4                       Other (please specify):
# ...                                         ...
# 65432                                       NaN
# 65433                                       NaN
# 65434                                       NaN
# 65435  Android;Other Linux-based;Ubuntu;Windows
# 65436                                   Windows
#
#                  OpSysProfessional use  \
# 0                                  NaN
# 1                                MacOS
# 2                              Windows
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 65432                              NaN
# 65433                              NaN
# 65434                              NaN
# 65435  Fedora;Other Linux-based;Ubuntu
# 65436                    MacOS;Windows
#
#                           OfficeStackAsyncHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      GitHub Discussions;Markdown File;Obsidian;Stac...
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435      Confluence;Jira;Markdown File;Obsidian;Trello
# 65436                                                NaN
#
#                   OfficeStackAsyncWantToWorkWith  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4      GitHub Discussions;Markdown File;Obsidian
# ...                                          ...
# 65432                                        NaN
# 65433                                        NaN
# 65434                                        NaN
# 65435       Confluence;Jira;Markdown File;Trello
# 65436                                        NaN
#
#                          OfficeStackAsyncAdmired  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4      GitHub Discussions;Markdown File;Obsidian
# ...                                          ...
# 65432                                        NaN
# 65433                                        NaN
# 65434                                        NaN
# 65435       Confluence;Jira;Markdown File;Trello
# 65436                                        NaN
#
#                       OfficeStackSyncHaveWorkedWith  \
# 0                                               NaN
# 1                             Microsoft Teams;Slack
# 2      Google Chat;Google Meet;Microsoft Teams;Zoom
# 3                                               NaN
# 4                                  Discord;Whatsapp
# ...                                             ...
# 65432                                           NaN
# 65433                                           NaN
# 65434                                           NaN
# 65435        Discord;Jitsi;Microsoft Teams;Whatsapp
# 65436                                           NaN
#
#       OfficeStackSyncWantToWorkWith        OfficeStackSyncAdmired  \
# 0                               NaN                           NaN
# 1                             Slack                         Slack
# 2      Google Chat;Google Meet;Zoom  Google Chat;Google Meet;Zoom
# 3                               NaN                           NaN
# 4                  Discord;Whatsapp              Discord;Whatsapp
# ...                             ...                           ...
# 65432                           NaN                           NaN
# 65433                           NaN                           NaN
# 65434                           NaN                           NaN
# 65435        Discord;Jitsi;Whatsapp        Discord;Jitsi;Whatsapp
# 65436                           NaN                           NaN
#
#       AISearchDevHaveWorkedWith AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                           NaN                       NaN                NaN
# 1                           NaN                       NaN                NaN
# 2                           NaN                       NaN                NaN
# 3                           NaN                       NaN                NaN
# 4                           NaN                       NaN                NaN
# ...                         ...                       ...                ...
# 65432                       NaN                       NaN                NaN
# 65433                       NaN                       NaN                NaN
# 65434                       NaN                       NaN                NaN
# 65435                       NaN                       NaN                NaN
# 65436                       NaN                       NaN                NaN
#
#                                               NEWSOSites  \
# 0      I have never visited Stack Overflow or the Sta...
# 1      Stack Overflow for Teams (private knowledge sh...
# 2      Stack Overflow;Stack Exchange;Stack Overflow B...
# 3                                         Stack Overflow
# 4      Stack Overflow for Teams (private knowledge sh...
# ...                                                  ...
# 65432                                                NaN
# 65433                      Stack Overflow;Stack Exchange
# 65434                                                NaN
# 65435                      Stack Overflow;Stack Exchange
# 65436                                     Stack Overflow
#
#                            SOVisitFreq SOAccount  \
# 0                                  NaN       NaN
# 1               Multiple times per day       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily        No
# 4               Multiple times per day       Yes
# ...                                ...       ...
# 65432                              NaN       NaN
# 65433                              NaN       NaN
# 65434                              NaN       NaN
# 65435  A few times per month or weekly        No
# 65436            Daily or almost daily       Yes
#
#                                 SOPartFreq  \
# 0                                      NaN
# 1                   Multiple times per day
# 2                   Multiple times per day
# 3                                      NaN
# 4                   Multiple times per day
# ...                                    ...
# 65432                                  NaN
# 65433                                  NaN
# 65434                                  NaN
# 65435                                  NaN
# 65436  Less than once per month or monthly
#
#                                                    SOHow           SOComm  \
# 0                                                    NaN              NaN
# 1      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                         Quickly finding code solutions   No, not really
# 4      Quickly finding code solutions;Engage with com...  Yes, definitely
# ...                                                  ...              ...
# 65432                                                NaN              NaN
# 65433                                                NaN              NaN
# 65434                                                NaN              NaN
# 65435                     Quickly finding code solutions   No, not really
# 65436                     Quickly finding code solutions    Yes, somewhat
#
#                       AISelect          AISent  \
# 0                          Yes  Very favorable
# 1      No, and I don't plan to             NaN
# 2      No, and I don't plan to             NaN
# 3                          Yes  Very favorable
# 4      No, and I don't plan to             NaN
# ...                        ...             ...
# 65432                      Yes       Favorable
# 65433                      NaN             NaN
# 65434                      NaN             NaN
# 65435  No, and I don't plan to             NaN
# 65436                      NaN             NaN
#
#                                                    AIBen  \
# 0                                  Increase productivity
# 1                                                    NaN
# 2                                                    NaN
# 3      Increase productivity;Greater efficiency;Impro...
# 4                                                    NaN
# ...                                                  ...
# 65432  Increase productivity;Greater efficiency;Speed...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#                             AIAcc  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                  Somewhat trust
# 4                             NaN
# ...                           ...
# 65432  Neither trust nor distrust
# 65433                         NaN
# 65434                         NaN
# 65435                         NaN
# 65436                         NaN
#
#                                            AIComplex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                      Bad at handling complex tasks
# 4                                                NaN
# ...                                              ...
# 65432  Good, but not great at handling complex tasks
# 65433                                            NaN
# 65434                                            NaN
# 65435                                            NaN
# 65436                                            NaN
#
#                                    AIToolCurrently Using  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Learning about a codebase;Project planning;Wri...
# 4                                                    NaN
# ...                                                  ...
# 65432  Learning about a codebase;Project planning;Wri...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#                                AIToolInterested in Using  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Testing code;Committing and reviewing code;Pre...
# 4                                                    NaN
# ...                                                  ...
# 65432  Debugging and getting help;Testing code;Deploy...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#        AIToolNot interested in Using  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 65432  Committing and reviewing code
# 65433                            NaN
# 65434                            NaN
# 65435                            NaN
# 65436                            NaN
#
#                               AINextMuch more integrated AINextNo change  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3      Learning about a codebase;Project planning;Wri...             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 65432  Writing code;Search for answers;Generating con...             NaN
# 65433                                                NaN             NaN
# 65434                                                NaN             NaN
# 65435                                                NaN             NaN
# 65436                                                NaN             NaN
#
#                                    AINextMore integrated  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432  Learning about a codebase;Project planning;Doc...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#       AINextLess integrated AINextMuch less integrated AIThreat  \
# 0                       NaN                        NaN      NaN
# 1                       NaN                        NaN      NaN
# 2                       NaN                        NaN      NaN
# 3                       NaN                        NaN       No
# 4                       NaN                        NaN      NaN
# ...                     ...                        ...      ...
# 65432                   NaN                        NaN       No
# 65433                   NaN                        NaN      NaN
# 65434                   NaN                        NaN      NaN
# 65435                   NaN                        NaN      NaN
# 65436                   NaN                        NaN      NaN
#
#                                                 AIEthics  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Circulating misinformation or disinformation;M...
# 4                                                    NaN
# ...                                                  ...
# 65432       Circulating misinformation or disinformation
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436                                                NaN
#
#                                             AIChallenges TBranch  \
# 0                                                    NaN      No
# 1                                                    NaN     Yes
# 2                                                    NaN      No
# 3                      Don’t trust the output or answers     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 65432  AI tools lack context of codebase,  internal a...     NaN
# 65433                                                NaN     NaN
# 65434                                                NaN     NaN
# 65435                                                NaN     Yes
# 65436                                                NaN     NaN
#
#                        ICorPM  WorkExp Knowledge_1 Knowledge_2 Knowledge_3  \
# 0                         NaN      NaN         NaN         NaN         NaN
# 1      Individual contributor     17.0       Agree    Disagree       Agree
# 2                         NaN      NaN         NaN         NaN         NaN
# 3                         NaN      NaN         NaN         NaN         NaN
# 4                         NaN      NaN         NaN         NaN         NaN
# ...                       ...      ...         ...         ...         ...
# 65432                     NaN      NaN         NaN         NaN         NaN
# 65433                     NaN      NaN         NaN         NaN         NaN
# 65434                     NaN      NaN         NaN         NaN         NaN
# 65435  Individual contributor      5.0         NaN         NaN         NaN
# 65436                     NaN      NaN         NaN         NaN         NaN
#
#       Knowledge_4 Knowledge_5                 Knowledge_6 Knowledge_7  \
# 0             NaN         NaN                         NaN         NaN
# 1           Agree       Agree  Neither agree nor disagree    Disagree
# 2             NaN         NaN                         NaN         NaN
# 3             NaN         NaN                         NaN         NaN
# 4             NaN         NaN                         NaN         NaN
# ...           ...         ...                         ...         ...
# 65432         NaN         NaN                         NaN         NaN
# 65433         NaN         NaN                         NaN         NaN
# 65434         NaN         NaN                         NaN         NaN
# 65435         NaN         NaN                         NaN         NaN
# 65436         NaN         NaN                         NaN         NaN
#
#       Knowledge_8 Knowledge_9 Frequency_1 Frequency_2 Frequency_3  \
# 0             NaN         NaN         NaN         NaN         NaN
# 1           Agree       Agree         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 65432         NaN         NaN         NaN         NaN         NaN
# 65433         NaN         NaN         NaN         NaN         NaN
# 65434         NaN         NaN         NaN         NaN         NaN
# 65435         NaN         NaN         NaN         NaN         NaN
# 65436         NaN         NaN         NaN         NaN         NaN
#
#       TimeSearching TimeAnswering Frustration ProfessionalTech  \
# 0               NaN           NaN         NaN              NaN
# 1               NaN           NaN         NaN              NaN
# 2               NaN           NaN         NaN              NaN
# 3               NaN           NaN         NaN              NaN
# 4               NaN           NaN         NaN              NaN
# ...             ...           ...         ...              ...
# 65432           NaN           NaN         NaN              NaN
# 65433           NaN           NaN         NaN              NaN
# 65434           NaN           NaN         NaN              NaN
# 65435           NaN           NaN         NaN              NaN
# 65436           NaN           NaN         NaN              NaN
#
#       ProfessionalCloud ProfessionalQuestion Industry  JobSatPoints_1  \
# 0                   NaN                  NaN      NaN             NaN
# 1                   NaN                  NaN      NaN             0.0
# 2                   NaN                  NaN      NaN             NaN
# 3                   NaN                  NaN      NaN             NaN
# 4                   NaN                  NaN      NaN             NaN
# ...                 ...                  ...      ...             ...
# 65432               NaN                  NaN      NaN             NaN
# 65433               NaN                  NaN      NaN             NaN
# 65434               NaN                  NaN      NaN             NaN
# 65435               NaN                  NaN      NaN             0.0
# 65436               NaN                  NaN      NaN             NaN
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# 0                 NaN             NaN             NaN             NaN
# 1                 0.0             0.0             0.0             0.0
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 65432             NaN             NaN             NaN             NaN
# 65433             NaN             NaN             NaN             NaN
# 65434             NaN             NaN             NaN             NaN
# 65435             0.0             0.0             0.0             0.0
# 65436             NaN             NaN             NaN             NaN
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# 0                 NaN             NaN              NaN              NaN
# 1                 0.0             0.0              0.0              0.0
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4                 NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 65432             NaN             NaN              NaN              NaN
# 65433             NaN             NaN              NaN              NaN
# 65434             NaN             NaN              NaN              NaN
# 65435             0.0             0.0              0.0              0.0
# 65436             NaN             NaN              NaN              NaN
#
#                 SurveyLength SurveyEase  ConvertedCompYearly  JobSat
# 0                        NaN        NaN                  NaN     NaN
# 1                        NaN        NaN                  NaN     NaN
# 2      Appropriate in length       Easy                  NaN     NaN
# 3                   Too long       Easy                  NaN     NaN
# 4                  Too short       Easy                  NaN     NaN
# ...                      ...        ...                  ...     ...
# 65432                    NaN        NaN                  NaN     NaN
# 65433                    NaN        NaN                  NaN     NaN
# 65434                    NaN        NaN                  NaN     NaN
# 65435                    NaN        NaN                  NaN     NaN
# 65436                    NaN        NaN                  NaN     NaN
#
# [65437 rows x 114 columns]

# %%
df['Country'] = df['Country'].replace('India','Bharat')

# %%
filt = (df['Country'] == 'Bharat')
df[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 17             18                     I am a developer by profession
# 58             59  I am not primarily a developer, but I write co...
# 75             76                              I am learning to code
# 89             90                              I am learning to code
# 96             97                     I am a developer by profession
# ...           ...                                                ...
# 65339       65340  I am not primarily a developer, but I write co...
# 65383       65384                              I am learning to code
# 65413       65414                              I am learning to code
# 65415       65416                        I code primarily as a hobby
# 65428       65429                     I am a developer by profession
#
#                    Age                                         Employment  \
# 17     18-24 years old  Independent contractor, freelancer, or self-em...
# 58     18-24 years old                                 Student, full-time
# 75     25-34 years old                 Not employed, but looking for work
# 89     25-34 years old                                Employed, full-time
# 96     25-34 years old                                Employed, full-time
# ...                ...                                                ...
# 65339  18-24 years old                                 Student, full-time
# 65383  18-24 years old                 Not employed, but looking for work
# 65413  18-24 years old                                 Student, full-time
# 65415  35-44 years old                                I prefer not to say
# 65428  25-34 years old                                Employed, full-time
#
#       RemoteWork   Check                                   CodingActivities  \
# 17        remote  Apples  Hobby;Professional development or self-paced l...
# 58           NaN  Apples                                                NaN
# 75           NaN  Apples                                                NaN
# 89     in-person  Apples                 Contribute to open-source projects
# 96        remote  Apples                                              Hobby
# ...          ...     ...                                                ...
# 65339        NaN  Apples                                                NaN
# 65383        NaN  Apples                                                NaN
# 65413        NaN  Apples                                                NaN
# 65415        NaN  Apples                                                NaN
# 65428     remote  Apples  Hobby;Contribute to open-source projects;Profe...
#
#                                                  EdLevel  \
# 17          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58     Some college/university study without earning ...
# 75     Some college/university study without earning ...
# 89       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 96          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 65339       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65383  Some college/university study without earning ...
# 65413  Secondary school (e.g. American high school, G...
# 65415       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65428       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 17     Other online resources (e.g., videos, blogs, f...
# 58     Other online resources (e.g., videos, blogs, f...
# 75       Online Courses or Certification;Coding Bootcamp
# 89     School (i.e., University, College, etc);Online...
# 96               School (i.e., University, College, etc)
# ...                                                  ...
# 65339  Other online resources (e.g., videos, blogs, f...
# 65383            School (i.e., University, College, etc)
# 65413  Other online resources (e.g., videos, blogs, f...
# 65415  Other online resources (e.g., videos, blogs, f...
# 65428  Books / Physical media;Colleague;Other online ...
#
#                                          LearnCodeOnline  \
# 17     Blogs;Coding sessions (live or recorded);How-t...
# 58     Stack Overflow;Coding sessions (live or record...
# 75                                                   NaN
# 89                                                   NaN
# 96                                                   NaN
# ...                                                  ...
# 65339  Technical documentation;Social Media;How-to vi...
# 65383                                                NaN
# 65413  Social Media;How-to videos;Video-based Online ...
# 65415  Blogs;Stack Overflow;Social Media;Video-based ...
# 65428  Technical documentation;Books;Interactive tuto...
#
#                                                  TechDoc YearsCode  \
# 17                                                   NaN         6
# 58                                                   NaN         4
# 75                                                   NaN         4
# 89                                                   NaN         2
# 96                                                   NaN        11
# ...                                                  ...       ...
# 65339             API document(s) and/or SDK document(s)         4
# 65383                                                NaN         9
# 65413                                                NaN         3
# 65415                                                NaN         4
# 65428  API document(s) and/or SDK document(s);User gu...         4
#
#       YearsCodePro                DevType                   OrgSize  \
# 17               3   Developer, front-end                       NaN
# 58             NaN                Student                       NaN
# 75             NaN               Designer                       NaN
# 89             NaN  Security professional                       NaN
# 96               7      Developer, mobile                       NaN
# ...            ...                    ...                       ...
# 65339            2      Developer, mobile                       NaN
# 65383          NaN                Student                       NaN
# 65413          NaN                Student                       NaN
# 65415          NaN   System administrator                       NaN
# 65428            7    Developer, back-end  1,000 to 4,999 employees
#
#            PurchaseInfluence  \
# 17                       NaN
# 58                       NaN
# 75                       NaN
# 89                       NaN
# 96                       NaN
# ...                      ...
# 65339                    NaN
# 65383                    NaN
# 65413                    NaN
# 65415                    NaN
# 65428  I have some influence
#
#                                               BuyNewTool BuildvsBuy  \
# 17                                                   NaN        NaN
# 58                                                   NaN        NaN
# 75                                                   NaN        NaN
# 89                                                   NaN        NaN
# 96                                                   NaN        NaN
# ...                                                  ...        ...
# 65339                                                NaN        NaN
# 65383                                                NaN        NaN
# 65413                                                NaN        NaN
# 65415                                                NaN        NaN
# 65428  Start a free trial;Ask developers I know/work ...        NaN
#
#                                              TechEndorse Country  \
# 17                                                   NaN  Bharat
# 58                                                   NaN  Bharat
# 75                                                   NaN  Bharat
# 89                                                   NaN  Bharat
# 96                                                   NaN  Bharat
# ...                                                  ...     ...
# 65339                                                NaN  Bharat
# 65383                                                NaN  Bharat
# 65413                                                NaN  Bharat
# 65415                                                NaN  Bharat
# 65428  Integrated developer community;Frequent update...  Bharat
#
#                 Currency  CompTotal  \
# 17                   NaN        NaN
# 58                   NaN        NaN
# 75                   NaN        NaN
# 89                   NaN        NaN
# 96                   NaN        NaN
# ...                  ...        ...
# 65339                NaN        NaN
# 65383                NaN        NaN
# 65413                NaN        NaN
# 65415                NaN        NaN
# 65428  INR\tIndian rupee        NaN
#
#                                   LanguageHaveWorkedWith  \
# 17                        HTML/CSS;JavaScript;TypeScript
# 58                  C;C++;HTML/CSS;JavaScript;Python;SQL
# 75                                   HTML/CSS;JavaScript
# 89     C;C++;HTML/CSS;Java;JavaScript;PHP;SQL;Visual ...
# 96                 Bash/Shell (all shells);C#;JavaScript
# ...                                                  ...
# 65339  C;C#;C++;Go;HTML/CSS;JavaScript;Objective-C;Py...
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                   LanguageWantToWorkWith  \
# 17                        HTML/CSS;JavaScript;TypeScript
# 58                                   C++;HTML/CSS;Python
# 75                                     Dart;Kotlin;Swift
# 89     HTML/CSS;Java;JavaScript;PHP;SQL;Visual Basic ...
# 96                                                   NaN
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                          LanguageAdmired  \
# 17                        HTML/CSS;JavaScript;TypeScript
# 58                                   C++;HTML/CSS;Python
# 75                                                   NaN
# 89     HTML/CSS;Java;JavaScript;PHP;SQL;Visual Basic ...
# 96                                                   NaN
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                   DatabaseHaveWorkedWith  \
# 17                                                   NaN
# 58                                                SQLite
# 75                                               MongoDB
# 89                            Elasticsearch;MySQL;Oracle
# 96                                                   NaN
# ...                                                  ...
# 65339  Cassandra;Firebase Realtime Database;MariaDB;M...
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#            DatabaseWantToWorkWith             DatabaseAdmired  \
# 17                            NaN                         NaN
# 58                            NaN                         NaN
# 75                            NaN                         NaN
# 89     Elasticsearch;MySQL;Oracle  Elasticsearch;MySQL;Oracle
# 96                            NaN                         NaN
# ...                           ...                         ...
# 65339                         NaN                         NaN
# 65383                         NaN                         NaN
# 65413                         NaN                         NaN
# 65415                         NaN                         NaN
# 65428                         NaN                         NaN
#
#                                   PlatformHaveWorkedWith  \
# 17     Amazon Web Services (AWS);Digital Ocean;Fireba...
# 58                                                   NaN
# 75                                Firebase;Heroku;VMware
# 89                                Managed Hosting;VMware
# 96                                                   NaN
# ...                                                  ...
# 65339  Amazon Web Services (AWS);Cloudflare;Firebase;...
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#       PlatformWantToWorkWith PlatformAdmired  \
# 17                       NaN             NaN
# 58                       NaN             NaN
# 75             Digital Ocean             NaN
# 89                       NaN             NaN
# 96                       NaN             NaN
# ...                      ...             ...
# 65339                    NaN             NaN
# 65383                    NaN             NaN
# 65413                    NaN             NaN
# 65415                    NaN             NaN
# 65428                    NaN             NaN
#
#                       WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 17                      jQuery;Next.js;React          Next.js;React
# 58                            Django;Node.js                 Django
# 75                             Node.js;React                    NaN
# 89     ASP.NET;CodeIgniter;Node.js;WordPress    CodeIgniter;Node.js
# 96                                       NaN                    NaN
# ...                                      ...                    ...
# 65339     Django;Flask;Next.js;Node.js;React                    NaN
# 65383                                    NaN                    NaN
# 65413                                    NaN                    NaN
# 65415                                    NaN                    NaN
# 65428                                    NaN                    NaN
#
#            WebframeAdmired EmbeddedHaveWorkedWith EmbeddedWantToWorkWith  \
# 17           Next.js;React                    NaN                    NaN
# 58                  Django                Arduino                Arduino
# 75                     NaN                    NaN                    NaN
# 89     CodeIgniter;Node.js            Rasberry Pi            Rasberry Pi
# 96                     NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 65339                  NaN    Arduino;Rasberry Pi                    NaN
# 65383                  NaN                    NaN                    NaN
# 65413                  NaN                    NaN                    NaN
# 65415                  NaN                    NaN                    NaN
# 65428                  NaN                    NaN                    NaN
#
#       EmbeddedAdmired      MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# 17                NaN                React Native    OpenGL;React Native
# 58            Arduino                         NaN                    NaN
# 75                NaN  Flutter;Ionic;React Native                    NaN
# 89        Rasberry Pi                       NumPy                    NaN
# 96                NaN        .NET (5+) ;.NET MAUI                    NaN
# ...               ...                         ...                    ...
# 65339             NaN                         NaN                    NaN
# 65383             NaN                         NaN                    NaN
# 65413             NaN                         NaN                    NaN
# 65415             NaN                         NaN                    NaN
# 65428             NaN                         NaN                    NaN
#
#       MiscTechAdmired ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# 17       React Native    Docker;npm;Vite;Yarn        Docker;pnpm;Vite
# 58                NaN                     npm                     NaN
# 75                NaN                     npm                     NaN
# 89                NaN                     npm                     NaN
# 96                NaN                   NuGet                     NaN
# ...               ...                     ...                     ...
# 65339             NaN                     NaN                     NaN
# 65383             NaN                     NaN                     NaN
# 65413             NaN                     NaN                     NaN
# 65415             NaN                     NaN                     NaN
# 65428             NaN                     NaN                     NaN
#
#       ToolsTechAdmired                       NEWCollabToolsHaveWorkedWith  \
# 17         Docker;Vite                                           VSCodium
# 58                 NaN            Code::Blocks;PyCharm;Visual Studio Code
# 75                 NaN  Android Studio;IntelliJ IDEA;Notepad++;Sublime...
# 89                 NaN  Nano;Netbeans;Notepad++;Sublime Text;Vim;Visua...
# 96                 NaN             Visual Studio;Visual Studio Code;Xcode
# ...                ...                                                ...
# 65339              NaN                                                NaN
# 65383              NaN                                                NaN
# 65413              NaN                                                NaN
# 65415              NaN                                                NaN
# 65428              NaN                                                NaN
#
#             NEWCollabToolsWantToWorkWith              NEWCollabToolsAdmired  \
# 17                              VSCodium                           VSCodium
# 58       Code::Blocks;Visual Studio Code    Code::Blocks;Visual Studio Code
# 75                                   NaN                                NaN
# 89     Nano;Notepad++;Visual Studio Code  Nano;Notepad++;Visual Studio Code
# 96                                 Rider                                NaN
# ...                                  ...                                ...
# 65339                                NaN                                NaN
# 65383                                NaN                                NaN
# 65413                                NaN                                NaN
# 65415                                NaN                                NaN
# 65428                                NaN                                NaN
#
#                                        OpSysPersonal use  \
# 17                                               Windows
# 58                                Android;Ubuntu;Windows
# 75                                Android;Ubuntu;Windows
# 89     Debian;Ubuntu;Windows;Windows Subsystem for Li...
# 96                                       Android;Windows
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                    OpSysProfessional use  \
# 17                                               Windows
# 58                                               Windows
# 75                                                   NaN
# 89     Debian;Ubuntu;Windows;Windows Subsystem for Li...
# 96                             Android;iOS;MacOS;Windows
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#       OfficeStackAsyncHaveWorkedWith   OfficeStackAsyncWantToWorkWith  \
# 17                      Azure Devops                     Azure Devops
# 58                               NaN                              NaN
# 75     Asana;Clickup;Miro;Monday.com  Notion;Stack Overflow for Teams
# 89          Stack Overflow for Teams                              NaN
# 96                      Azure Devops                              NaN
# ...                              ...                              ...
# 65339                            NaN                              NaN
# 65383                            NaN                              NaN
# 65413                            NaN                              NaN
# 65415                            NaN                              NaN
# 65428                            NaN                              NaN
#
#       OfficeStackAsyncAdmired  \
# 17               Azure Devops
# 58                        NaN
# 75                        NaN
# 89                        NaN
# 96                        NaN
# ...                       ...
# 65339                     NaN
# 65383                     NaN
# 65413                     NaN
# 65415                     NaN
# 65428                     NaN
#
#                            OfficeStackSyncHaveWorkedWith  \
# 17         Google Meet;Microsoft Teams;Telegram;Whatsapp
# 58                             Discord;Telegram;Whatsapp
# 75                             Skype;Slack;Whatsapp;Zoom
# 89     Cisco Webex Teams;Discord;Google Meet;Microsof...
# 96                                       Microsoft Teams
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                            OfficeStackSyncWantToWorkWith  \
# 17                           Google Meet;Microsoft Teams
# 58                                              Whatsapp
# 75                                   Discord;Google Chat
# 89     Discord;Google Meet;Microsoft Teams;Telegram;W...
# 96                                                   NaN
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                   OfficeStackSyncAdmired  \
# 17                           Google Meet;Microsoft Teams
# 58                                              Whatsapp
# 75                                                   NaN
# 89     Discord;Google Meet;Microsoft Teams;Telegram;W...
# 96                                                   NaN
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#       AISearchDevHaveWorkedWith                     AISearchDevWantToWorkWith  \
# 17                      ChatGPT                  GitHub Copilot;Google Gemini
# 58                      ChatGPT                  GitHub Copilot;Google Gemini
# 75                Google Gemini                                           NaN
# 89            ChatGPT;Snyk Code                             ChatGPT;Snyk Code
# 96       ChatGPT;GitHub Copilot  ChatGPT;GitHub Copilot;Google Gemini;Meta AI
# ...                         ...                                           ...
# 65339                       NaN                                           NaN
# 65383                       NaN                                           NaN
# 65413                       NaN                                           NaN
# 65415                       NaN                                           NaN
# 65428                       NaN                                           NaN
#
#            AISearchDevAdmired                     NEWSOSites  \
# 17                        NaN  Stack Overflow;Stack Exchange
# 58                        NaN  Stack Overflow;Stack Exchange
# 75                        NaN  Stack Overflow;Stack Exchange
# 89          ChatGPT;Snyk Code                 Stack Exchange
# 96     ChatGPT;GitHub Copilot                 Stack Overflow
# ...                       ...                            ...
# 65339                     NaN  Stack Overflow;Stack Exchange
# 65383                     NaN                 Stack Exchange
# 65413                     NaN  Stack Overflow;Stack Exchange
# 65415                     NaN                 Stack Overflow
# 65428                     NaN  Stack Overflow;Stack Exchange
#
#                                SOVisitFreq SOAccount  \
# 17     Less than once per month or monthly       Yes
# 58                    A few times per week       Yes
# 75                   Daily or almost daily       Yes
# 89         A few times per month or weekly       Yes
# 96                    A few times per week       Yes
# ...                                    ...       ...
# 65339                Daily or almost daily        No
# 65383  Less than once per month or monthly       Yes
# 65413      A few times per month or weekly        No
# 65415                 A few times per week       Yes
# 65428      A few times per month or weekly        No
#
#                                               SOPartFreq  \
# 17                   Less than once per month or monthly
# 58                   Less than once per month or monthly
# 75                                  A few times per week
# 89                   Less than once per month or monthly
# 96                   Less than once per month or monthly
# ...                                                  ...
# 65339                                                NaN
# 65383  I have never participated in Q&A on Stack Over...
# 65413                                                NaN
# 65415                Less than once per month or monthly
# 65428                                                NaN
#
#                                                    SOHow           SOComm  \
# 17                        Quickly finding code solutions          Neutral
# 58     Quickly finding code solutions;Finding reliabl...          Neutral
# 75     Quickly finding code solutions;Finding reliabl...          Neutral
# 89     Finding reliable guidance from community-vette...  Yes, definitely
# 96     Quickly finding code solutions;Finding reliabl...    Yes, somewhat
# ...                                                  ...              ...
# 65339  Quickly finding code solutions;Finding reliabl...          Neutral
# 65383  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 65413                     Quickly finding code solutions   No, not at all
# 65415  Quickly finding code solutions;Engage with com...    Yes, somewhat
# 65428  Quickly finding code solutions;Finding reliabl...          Neutral
#
#                       AISelect          AISent  \
# 17      No, but I plan to soon       Favorable
# 58                         Yes       Favorable
# 75      No, but I plan to soon       Favorable
# 89      No, but I plan to soon       Favorable
# 96                         Yes  Very favorable
# ...                        ...             ...
# 65339                      NaN             NaN
# 65383                      NaN             NaN
# 65413                      Yes          Unsure
# 65415                      NaN             NaN
# 65428  No, and I don't plan to             NaN
#
#                                                    AIBen           AIAcc  \
# 17                                                   NaN             NaN
# 58     Increase productivity;Greater efficiency;Make ...  Somewhat trust
# 75                                                   NaN             NaN
# 89                                                   NaN             NaN
# 96     Increase productivity;Greater efficiency;Impro...  Somewhat trust
# ...                                                  ...             ...
# 65339                                                NaN             NaN
# 65383                                                NaN             NaN
# 65413  Increase productivity;Speed up learning;Make w...  Somewhat trust
# 65415                                                NaN             NaN
# 65428                                                NaN             NaN
#
#                                            AIComplex  \
# 17                                               NaN
# 58     Neither good or bad at handling complex tasks
# 75                                               NaN
# 89                                               NaN
# 96     Good, but not great at handling complex tasks
# ...                                              ...
# 65339                                            NaN
# 65383                                            NaN
# 65413                  Bad at handling complex tasks
# 65415                                            NaN
# 65428                                            NaN
#
#                                    AIToolCurrently Using  \
# 17                                                   NaN
# 58         Debugging and getting help;Search for answers
# 75                                                   NaN
# 89                                                   NaN
# 96     Writing code;Documenting code;Search for answe...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                AIToolInterested in Using  \
# 17                                                   NaN
# 58                                                   NaN
# 75                                                   NaN
# 89                                                   NaN
# 96     Learning about a codebase;Project planning;Deb...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#       AIToolNot interested in Using            AINextMuch more integrated  \
# 17                              NaN                                   NaN
# 58                              NaN                                   NaN
# 75                              NaN                                   NaN
# 89                              NaN                                   NaN
# 96                              NaN  Generating content or synthetic data
# ...                             ...                                   ...
# 65339                           NaN                                   NaN
# 65383                           NaN                                   NaN
# 65413                           NaN                                   NaN
# 65415                           NaN                                   NaN
# 65428                           NaN                                   NaN
#
#           AINextNo change                             AINextMore integrated  \
# 17                    NaN                                               NaN
# 58     Search for answers                        Debugging and getting help
# 75                    NaN                                               NaN
# 89                    NaN                                               NaN
# 96                    NaN  Writing code;Documenting code;Search for answers
# ...                   ...                                               ...
# 65339                 NaN                                               NaN
# 65383                 NaN                                               NaN
# 65413                 NaN                                               NaN
# 65415                 NaN                                               NaN
# 65428                 NaN                                               NaN
#
#       AINextLess integrated AINextMuch less integrated      AIThreat  \
# 17                      NaN                        NaN  I'm not sure
# 58                      NaN                        NaN            No
# 75                      NaN                        NaN            No
# 89                      NaN                        NaN            No
# 96                      NaN                        NaN           Yes
# ...                     ...                        ...           ...
# 65339                   NaN                        NaN           NaN
# 65383                   NaN                        NaN           NaN
# 65413                   NaN                        NaN           NaN
# 65415                   NaN                        NaN           NaN
# 65428                   NaN                        NaN           NaN
#
#                                                 AIEthics  \
# 17     Replacing jobs without options for new employm...
# 58     Circulating misinformation or disinformation;M...
# 75     Replacing jobs without options for new employm...
# 89     Circulating misinformation or disinformation;R...
# 96     Biased results that do not represent diverse v...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                             AIChallenges TBranch  \
# 17                              Lack of executive buy-in     NaN
# 58                                                   NaN     NaN
# 75     Don’t trust the output or answers;Not everyone...     NaN
# 89                                Not everyone uses them     Yes
# 96     AI tools lack context of codebase,  internal a...     Yes
# ...                                                  ...     ...
# 65339                                                NaN     NaN
# 65383                                                NaN     NaN
# 65413                                                NaN     NaN
# 65415                                                NaN     NaN
# 65428                                                NaN     NaN
#
#                        ICorPM  WorkExp Knowledge_1  \
# 17                        NaN      NaN         NaN
# 58                        NaN      NaN         NaN
# 75                        NaN      NaN         NaN
# 89     Individual contributor      3.0       Agree
# 96     Individual contributor      7.0       Agree
# ...                       ...      ...         ...
# 65339                     NaN      NaN         NaN
# 65383                     NaN      NaN         NaN
# 65413                     NaN      NaN         NaN
# 65415                     NaN      NaN         NaN
# 65428                     NaN      NaN         NaN
#
#                       Knowledge_2 Knowledge_3 Knowledge_4  \
# 17                            NaN         NaN         NaN
# 58                            NaN         NaN         NaN
# 75                            NaN         NaN         NaN
# 89     Neither agree nor disagree       Agree       Agree
# 96     Neither agree nor disagree    Disagree       Agree
# ...                           ...         ...         ...
# 65339                         NaN         NaN         NaN
# 65383                         NaN         NaN         NaN
# 65413                         NaN         NaN         NaN
# 65415                         NaN         NaN         NaN
# 65428                         NaN         NaN         NaN
#
#                       Knowledge_5 Knowledge_6                 Knowledge_7  \
# 17                            NaN         NaN                         NaN
# 58                            NaN         NaN                         NaN
# 75                            NaN         NaN                         NaN
# 89                          Agree       Agree  Neither agree nor disagree
# 96     Neither agree nor disagree       Agree                       Agree
# ...                           ...         ...                         ...
# 65339                         NaN         NaN                         NaN
# 65383                         NaN         NaN                         NaN
# 65413                         NaN         NaN                         NaN
# 65415                         NaN         NaN                         NaN
# 65428                         NaN         NaN                         NaN
#
#       Knowledge_8        Knowledge_9       Frequency_1       Frequency_2  \
# 17            NaN                NaN               NaN               NaN
# 58            NaN                NaN               NaN               NaN
# 75            NaN                NaN               NaN               NaN
# 89          Agree              Agree             Never  1-2 times a week
# 96          Agree  Strongly disagree  1-2 times a week  1-2 times a week
# ...           ...                ...               ...               ...
# 65339         NaN                NaN               NaN               NaN
# 65383         NaN                NaN               NaN               NaN
# 65413         NaN                NaN               NaN               NaN
# 65415         NaN                NaN               NaN               NaN
# 65428         NaN                NaN               NaN               NaN
#
#             Frequency_3         TimeSearching               TimeAnswering  \
# 17                  NaN                   NaN                         NaN
# 58                  NaN                   NaN                         NaN
# 75                  NaN                   NaN                         NaN
# 89                Never  60-120 minutes a day  Less than 15 minutes a day
# 96     1-2 times a week   30-60 minutes a day         30-60 minutes a day
# ...                 ...                   ...                         ...
# 65339               NaN                   NaN                         NaN
# 65383               NaN                   NaN                         NaN
# 65413               NaN                   NaN                         NaN
# 65415               NaN                   NaN                         NaN
# 65428               NaN                   NaN                         NaN
#
#                                              Frustration  \
# 17                                                   NaN
# 58                                                   NaN
# 75                                                   NaN
# 89                                         None of these
# 96     Amount of technical debt;Tracking my work;Show...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                         ProfessionalTech  \
# 17                                                   NaN
# 58                                                   NaN
# 75                                                   NaN
# 89       Observability tools;Knowledge sharing community
# 96     DevOps function;Developer portal or other cent...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                         ProfessionalCloud      ProfessionalQuestion  \
# 17                                    NaN                       NaN
# 58                                    NaN                       NaN
# 75                                    NaN                       NaN
# 89             Hybrid (on-prem and cloud)  AI-powered search (free)
# 96     Cloud only (single or multi-cloud)                A coworker
# ...                                   ...                       ...
# 65339                                 NaN                       NaN
# 65383                                 NaN                       NaN
# 65413                                 NaN                       NaN
# 65415                                 NaN                       NaN
# 65428                                 NaN                       NaN
#
#                    Industry  JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  \
# 17                      NaN             NaN             NaN             NaN
# 58                      NaN             NaN             NaN             NaN
# 75                      NaN             NaN             NaN             NaN
# 89         Higher Education            80.0            90.0            90.0
# 96     Software Development             0.0             0.0             0.0
# ...                     ...             ...             ...             ...
# 65339                   NaN             NaN             NaN             NaN
# 65383                   NaN             NaN             NaN             NaN
# 65413                   NaN             NaN             NaN             NaN
# 65415                   NaN             NaN             NaN             NaN
# 65428                   NaN             NaN             NaN             NaN
#
#        JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  \
# 17                NaN             NaN             NaN             NaN
# 58                NaN             NaN             NaN             NaN
# 75                NaN             NaN             NaN             NaN
# 89               50.0            70.0            50.0            50.0
# 96                0.0             0.0             0.0             0.0
# ...               ...             ...             ...             ...
# 65339             NaN             NaN             NaN             NaN
# 65383             NaN             NaN             NaN             NaN
# 65413             NaN             NaN             NaN             NaN
# 65415             NaN             NaN             NaN             NaN
# 65428             NaN             NaN             NaN             NaN
#
#        JobSatPoints_10  JobSatPoints_11           SurveyLength SurveyEase  \
# 17                 NaN              NaN  Appropriate in length       Easy
# 58                 NaN              NaN  Appropriate in length       Easy
# 75                 NaN              NaN  Appropriate in length       Easy
# 89                50.0             80.0  Appropriate in length       Easy
# 96                 0.0              0.0               Too long       Easy
# ...                ...              ...                    ...        ...
# 65339              NaN              NaN                    NaN        NaN
# 65383              NaN              NaN                    NaN        NaN
# 65413              NaN              NaN                    NaN        NaN
# 65415              NaN              NaN                    NaN        NaN
# 65428              NaN              NaN                    NaN        NaN
#
#        ConvertedCompYearly  JobSat
# 17                     NaN     NaN
# 58                     NaN     NaN
# 75                     NaN     NaN
# 89                     NaN     8.0
# 96                     NaN     7.0
# ...                    ...     ...
# 65339                  NaN     NaN
# 65383                  NaN     NaN
# 65413                  NaN     NaN
# 65415                  NaN     NaN
# 65428                  NaN     NaN
#
# [4231 rows x 114 columns]

# %%
df['Country'] = df['Country'].replace({'Bharat': 'India', 'Canada': 'Canneda', 'United States of America': 'USA' })

# %%
countries = ['India', 'Canneda', 'USA']
filt2 = df['Country'].isin(countries)
df[filt2]
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 3               4                              I am learning to code
# 5               6                        I code primarily as a hobby
# 6               7  I am not primarily a developer, but I write co...
# 10             11  I used to be a developer by profession, but no...
# ...           ...                                                ...
# 65339       65340  I am not primarily a developer, but I write co...
# 65383       65384                              I am learning to code
# 65413       65414                              I am learning to code
# 65415       65416                        I code primarily as a hobby
# 65428       65429                     I am a developer by profession
#
#                       Age                          Employment RemoteWork  \
# 0      Under 18 years old                 Employed, full-time     remote
# 3         18-24 years old                  Student, full-time        NaN
# 5      Under 18 years old                  Student, full-time        NaN
# 6         35-44 years old                 Employed, full-time     remote
# 10        35-44 years old                 Employed, full-time     remote
# ...                   ...                                 ...        ...
# 65339     18-24 years old                  Student, full-time        NaN
# 65383     18-24 years old  Not employed, but looking for work        NaN
# 65413     18-24 years old                  Student, full-time        NaN
# 65415     35-44 years old                 I prefer not to say        NaN
# 65428     25-34 years old                 Employed, full-time     remote
#
#         Check                                   CodingActivities  \
# 0      Apples                                              Hobby
# 3      Apples                                                NaN
# 5      Apples                                                NaN
# 6      Apples                       I don’t code outside of work
# 10     Apples           Hobby;Contribute to open-source projects
# ...       ...                                                ...
# 65339  Apples                                                NaN
# 65383  Apples                                                NaN
# 65413  Apples                                                NaN
# 65415  Apples                                                NaN
# 65428  Apples  Hobby;Contribute to open-source projects;Profe...
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 3      Some college/university study without earning ...
# 5                              Primary/elementary school
# 6         Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 10          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 65339       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65383  Some college/university study without earning ...
# 65413  Secondary school (e.g. American high school, G...
# 65415       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65428       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 3      Other online resources (e.g., videos, blogs, f...
# 5      School (i.e., University, College, etc);Online...
# 6      Other online resources (e.g., videos, blogs, f...
# 10     Books / Physical media;Other online resources ...
# ...                                                  ...
# 65339  Other online resources (e.g., videos, blogs, f...
# 65383            School (i.e., University, College, etc)
# 65413  Other online resources (e.g., videos, blogs, f...
# 65415  Other online resources (e.g., videos, blogs, f...
# 65428  Books / Physical media;Colleague;Other online ...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 3      Stack Overflow;How-to videos;Interactive tutorial
# 5                                                    NaN
# 6      Technical documentation;Stack Overflow;Written...
# 10     Technical documentation;Books;Written Tutorial...
# ...                                                  ...
# 65339  Technical documentation;Social Media;How-to vi...
# 65383                                                NaN
# 65413  Social Media;How-to videos;Video-based Online ...
# 65415  Blogs;Stack Overflow;Social Media;Video-based ...
# 65428  Technical documentation;Books;Interactive tuto...
#
#                                                  TechDoc YearsCode  \
# 0                                                    NaN       NaN
# 3                                                    NaN         4
# 5                                                    NaN        10
# 6                                                    NaN         7
# 10     API document(s) and/or SDK document(s);User gu...        20
# ...                                                  ...       ...
# 65339             API document(s) and/or SDK document(s)         4
# 65383                                                NaN         9
# 65413                                                NaN         3
# 65415                                                NaN         4
# 65428  API document(s) and/or SDK document(s);User gu...         4
#
#       YearsCodePro                DevType                   OrgSize  \
# 0              NaN                    NaN                       NaN
# 3              NaN  Developer, full-stack                       NaN
# 5              NaN                Student                       NaN
# 6                7    Academic researcher                       NaN
# 10             NaN        Project manager                       NaN
# ...            ...                    ...                       ...
# 65339            2      Developer, mobile                       NaN
# 65383          NaN                Student                       NaN
# 65413          NaN                Student                       NaN
# 65415          NaN   System administrator                       NaN
# 65428            7    Developer, back-end  1,000 to 4,999 employees
#
#            PurchaseInfluence  \
# 0                        NaN
# 3                        NaN
# 5                        NaN
# 6                        NaN
# 10                       NaN
# ...                      ...
# 65339                    NaN
# 65383                    NaN
# 65413                    NaN
# 65415                    NaN
# 65428  I have some influence
#
#                                               BuyNewTool BuildvsBuy  \
# 0                                                    NaN        NaN
# 3                                                    NaN        NaN
# 5                                                    NaN        NaN
# 6                                                    NaN        NaN
# 10                                                   NaN        NaN
# ...                                                  ...        ...
# 65339                                                NaN        NaN
# 65383                                                NaN        NaN
# 65413                                                NaN        NaN
# 65415                                                NaN        NaN
# 65428  Start a free trial;Ask developers I know/work ...        NaN
#
#                                              TechEndorse  Country  \
# 0                                                    NaN      USA
# 3                                                    NaN  Canneda
# 5                                                    NaN      USA
# 6                                                    NaN      USA
# 10                                                   NaN      USA
# ...                                                  ...      ...
# 65339                                                NaN    India
# 65383                                                NaN    India
# 65413                                                NaN    India
# 65415                                                NaN    India
# 65428  Integrated developer community;Frequent update...    India
#
#                 Currency  CompTotal  \
# 0                    NaN        NaN
# 3                    NaN        NaN
# 5                    NaN        NaN
# 6                    NaN        NaN
# 10                   NaN        NaN
# ...                  ...        ...
# 65339                NaN        NaN
# 65383                NaN        NaN
# 65413                NaN        NaN
# 65415                NaN        NaN
# 65428  INR\tIndian rupee        NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 3      C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                      R
# 10                                JavaScript;Python;Ruby
# ...                                                  ...
# 65339  C;C#;C++;Go;HTML/CSS;JavaScript;Objective-C;Py...
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                   LanguageWantToWorkWith  \
# 0                                                    NaN
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                      R
# 10                C#;Crystal;Java;JavaScript;Python;Ruby
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                          LanguageAdmired  \
# 0                                                    NaN
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                      R
# 10                                JavaScript;Python;Ruby
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 3                        MongoDB;MySQL;PostgreSQL;SQLite
# 5                                        Cloud Firestore
# 6                                                    NaN
# 10               Elasticsearch;MongoDB;PostgreSQL;SQLite
# ...                                                  ...
# 65339  Cassandra;Firebase Realtime Database;MariaDB;M...
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                         DatabaseWantToWorkWith  \
# 0                                          NaN
# 3                     MongoDB;MySQL;PostgreSQL
# 5                              Cloud Firestore
# 6                                          NaN
# 10     Elasticsearch;MongoDB;PostgreSQL;SQLite
# ...                                        ...
# 65339                                      NaN
# 65383                                      NaN
# 65413                                      NaN
# 65415                                      NaN
# 65428                                      NaN
#
#                                DatabaseAdmired  \
# 0                                          NaN
# 3                     MongoDB;MySQL;PostgreSQL
# 5                              Cloud Firestore
# 6                                          NaN
# 10     Elasticsearch;MongoDB;PostgreSQL;SQLite
# ...                                        ...
# 65339                                      NaN
# 65383                                      NaN
# 65413                                      NaN
# 65415                                      NaN
# 65428                                      NaN
#
#                                   PlatformHaveWorkedWith  \
# 0                                                    NaN
# 3                Amazon Web Services (AWS);Fly.io;Heroku
# 5                                             Cloudflare
# 6                                                    NaN
# 10                Amazon Web Services (AWS);Google Cloud
# ...                                                  ...
# 65339  Amazon Web Services (AWS);Cloudflare;Firebase;...
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                  PlatformWantToWorkWith            PlatformAdmired  \
# 0                                   NaN                        NaN
# 3      Amazon Web Services (AWS);Vercel  Amazon Web Services (AWS)
# 5                            Cloudflare                 Cloudflare
# 6                                   NaN                        NaN
# 10                         Google Cloud               Google Cloud
# ...                                 ...                        ...
# 65339                               NaN                        NaN
# 65383                               NaN                        NaN
# 65413                               NaN                        NaN
# 65415                               NaN                        NaN
# 65428                               NaN                        NaN
#
#                        WebframeHaveWorkedWith  \
# 0                                         NaN
# 3      jQuery;Next.js;Node.js;React;WordPress
# 5                                     Node.js
# 6                                         NaN
# 10                Node.js;React;Ruby on Rails
# ...                                       ...
# 65339      Django;Flask;Next.js;Node.js;React
# 65383                                     NaN
# 65413                                     NaN
# 65415                                     NaN
# 65428                                     NaN
#
#                    WebframeWantToWorkWith               WebframeAdmired  \
# 0                                     NaN                           NaN
# 3            jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 5                                 Node.js                       Node.js
# 6                                     NaN                           NaN
# 10     Django;Node.js;React;Ruby on Rails   Node.js;React;Ruby on Rails
# ...                                   ...                           ...
# 65339                                 NaN                           NaN
# 65383                                 NaN                           NaN
# 65413                                 NaN                           NaN
# 65415                                 NaN                           NaN
# 65428                                 NaN                           NaN
#
#       EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# 0                        NaN                    NaN             NaN
# 3                Rasberry Pi                    NaN             NaN
# 5                Rasberry Pi            Rasberry Pi     Rasberry Pi
# 6                        NaN                    NaN             NaN
# 10                       NaN                    NaN             NaN
# ...                      ...                    ...             ...
# 65339    Arduino;Rasberry Pi                    NaN             NaN
# 65383                    NaN                    NaN             NaN
# 65413                    NaN                    NaN             NaN
# 65415                    NaN                    NaN             NaN
# 65428                    NaN                    NaN             NaN
#
#              MiscTechHaveWorkedWith MiscTechWantToWorkWith MiscTechAdmired  \
# 0                               NaN                    NaN             NaN
# 3      NumPy;Pandas;Ruff;TensorFlow                    NaN             NaN
# 5                               NaN                    NaN             NaN
# 6                               NaN                    NaN             NaN
# 10                              NaN                    NaN             NaN
# ...                             ...                    ...             ...
# 65339                           NaN                    NaN             NaN
# 65383                           NaN                    NaN             NaN
# 65413                           NaN                    NaN             NaN
# 65415                           NaN                    NaN             NaN
# 65428                           NaN                    NaN             NaN
#
#             ToolsTechHaveWorkedWith    ToolsTechWantToWorkWith  \
# 0                               NaN                        NaN
# 3                    Docker;npm;Pip      Docker;Kubernetes;npm
# 5      Docker;Homebrew;npm;Pip;pnpm      Homebrew;npm;Pip;pnpm
# 6                               NaN                        NaN
# 10        Ansible;Docker;Kubernetes  Ansible;Docker;Kubernetes
# ...                             ...                        ...
# 65339                           NaN                        NaN
# 65383                           NaN                        NaN
# 65413                           NaN                        NaN
# 65415                           NaN                        NaN
# 65428                           NaN                        NaN
#
#                 ToolsTechAdmired       NEWCollabToolsHaveWorkedWith  \
# 0                            NaN                                NaN
# 3                     Docker;npm                                NaN
# 5          Homebrew;npm;Pip;pnpm  Nano;Vim;Visual Studio Code;Xcode
# 6                            NaN                            RStudio
# 10     Ansible;Docker;Kubernetes                 Visual Studio Code
# ...                          ...                                ...
# 65339                        NaN                                NaN
# 65383                        NaN                                NaN
# 65413                        NaN                                NaN
# 65415                        NaN                                NaN
# 65428                        NaN                                NaN
#
#             NEWCollabToolsWantToWorkWith              NEWCollabToolsAdmired  \
# 0                                    NaN                                NaN
# 3                                    NaN                                NaN
# 5      Nano;Vim;Visual Studio Code;Xcode  Nano;Vim;Visual Studio Code;Xcode
# 6                                RStudio                            RStudio
# 10                    Visual Studio Code                 Visual Studio Code
# ...                                  ...                                ...
# 65339                                NaN                                NaN
# 65383                                NaN                                NaN
# 65413                                NaN                                NaN
# 65415                                NaN                                NaN
# 65428                                NaN                                NaN
#
#                                OpSysPersonal use OpSysProfessional use  \
# 0                                            NaN                   NaN
# 3                                            NaN                   NaN
# 5                               iOS;MacOS;Ubuntu                   NaN
# 6                                          MacOS                 MacOS
# 10     Windows;Windows Subsystem for Linux (WSL)               Windows
# ...                                          ...                   ...
# 65339                                        NaN                   NaN
# 65383                                        NaN                   NaN
# 65413                                        NaN                   NaN
# 65415                                        NaN                   NaN
# 65428                                        NaN                   NaN
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 0                                                NaN
# 3                                                NaN
# 5                                      Markdown File
# 6                                                NaN
# 10     Confluence;GitHub Discussions;Jira;Smartsheet
# ...                                              ...
# 65339                                            NaN
# 65383                                            NaN
# 65413                                            NaN
# 65415                                            NaN
# 65428                                            NaN
#
#            OfficeStackAsyncWantToWorkWith             OfficeStackAsyncAdmired  \
# 0                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 5                           Markdown File                       Markdown File
# 6                                     NaN                                 NaN
# 10     Confluence;GitHub Discussions;Jira  Confluence;GitHub Discussions;Jira
# ...                                   ...                                 ...
# 65339                                 NaN                                 NaN
# 65383                                 NaN                                 NaN
# 65413                                 NaN                                 NaN
# 65415                                 NaN                                 NaN
# 65428                                 NaN                                 NaN
#
#                         OfficeStackSyncHaveWorkedWith  \
# 0                                                 NaN
# 3                                                 NaN
# 5                                             Discord
# 6                            Microsoft Teams;Whatsapp
# 10     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# ...                                               ...
# 65339                                             NaN
# 65383                                             NaN
# 65413                                             NaN
# 65415                                             NaN
# 65428                                             NaN
#
#                         OfficeStackSyncWantToWorkWith  \
# 0                                                 NaN
# 3                                                 NaN
# 5                                             Discord
# 6                            Microsoft Teams;Whatsapp
# 10     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# ...                                               ...
# 65339                                             NaN
# 65383                                             NaN
# 65413                                             NaN
# 65415                                             NaN
# 65428                                             NaN
#
#                                OfficeStackSyncAdmired  \
# 0                                                 NaN
# 3                                                 NaN
# 5                                             Discord
# 6                            Microsoft Teams;Whatsapp
# 10     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# ...                                               ...
# 65339                                             NaN
# 65383                                             NaN
# 65413                                             NaN
# 65415                                             NaN
# 65428                                             NaN
#
#                                AISearchDevHaveWorkedWith  \
# 0                                                    NaN
# 3                                                    NaN
# 5                    ChatGPT;GitHub Copilot;OpenAI Codex
# 6                                                    NaN
# 10     ChatGPT;GitHub Copilot;Google Gemini;Meta AI;V...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                AISearchDevWantToWorkWith  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                 ChatGPT;GitHub Copilot
# 6                                                    NaN
# 10     GitHub Copilot;Google Gemini;Visual Studio Int...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                       AISearchDevAdmired  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                 ChatGPT;GitHub Copilot
# 6                                                    NaN
# 10     GitHub Copilot;Google Gemini;Visual Studio Int...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                               NEWSOSites  \
# 0      I have never visited Stack Overflow or the Sta...
# 3                                         Stack Overflow
# 5                          Stack Overflow;Stack Exchange
# 6                                         Stack Overflow
# 10     Stack Overflow for Teams (private knowledge sh...
# ...                                                  ...
# 65339                      Stack Overflow;Stack Exchange
# 65383                                     Stack Exchange
# 65413                      Stack Overflow;Stack Exchange
# 65415                                     Stack Overflow
# 65428                      Stack Overflow;Stack Exchange
#
#                                SOVisitFreq SOAccount  \
# 0                                      NaN       NaN
# 3                    Daily or almost daily        No
# 5                   Multiple times per day       Yes
# 6                    Daily or almost daily       Yes
# 10                    A few times per week       Yes
# ...                                    ...       ...
# 65339                Daily or almost daily        No
# 65383  Less than once per month or monthly       Yes
# 65413      A few times per month or weekly        No
# 65415                 A few times per week       Yes
# 65428      A few times per month or weekly        No
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                 Multiple times per day
# 6                                  Daily or almost daily
# 10                   Less than once per month or monthly
# ...                                                  ...
# 65339                                                NaN
# 65383  I have never participated in Q&A on Stack Over...
# 65413                                                NaN
# 65415                Less than once per month or monthly
# 65428                                                NaN
#
#                                                    SOHow           SOComm  \
# 0                                                    NaN              NaN
# 3                         Quickly finding code solutions   No, not really
# 5      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 6      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 10     Quickly finding code solutions;Finding reliabl...  Yes, definitely
# ...                                                  ...              ...
# 65339  Quickly finding code solutions;Finding reliabl...          Neutral
# 65383  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 65413                     Quickly finding code solutions   No, not at all
# 65415  Quickly finding code solutions;Engage with com...    Yes, somewhat
# 65428  Quickly finding code solutions;Finding reliabl...          Neutral
#
#                       AISelect          AISent  \
# 0                          Yes  Very favorable
# 3                          Yes  Very favorable
# 5                          Yes       Favorable
# 6      No, and I don't plan to             NaN
# 10                         Yes       Favorable
# ...                        ...             ...
# 65339                      NaN             NaN
# 65383                      NaN             NaN
# 65413                      Yes          Unsure
# 65415                      NaN             NaN
# 65428  No, and I don't plan to             NaN
#
#                                                    AIBen              AIAcc  \
# 0                                  Increase productivity                NaN
# 3      Increase productivity;Greater efficiency;Impro...     Somewhat trust
# 5      Increase productivity;Greater efficiency;Impro...     Somewhat trust
# 6                                                    NaN                NaN
# 10     Increase productivity;Speed up learning;Improv...  Somewhat distrust
# ...                                                  ...                ...
# 65339                                                NaN                NaN
# 65383                                                NaN                NaN
# 65413  Increase productivity;Speed up learning;Make w...     Somewhat trust
# 65415                                                NaN                NaN
# 65428                                                NaN                NaN
#
#                                            AIComplex  \
# 0                                                NaN
# 3                      Bad at handling complex tasks
# 5      Good, but not great at handling complex tasks
# 6                                                NaN
# 10     Neither good or bad at handling complex tasks
# ...                                              ...
# 65339                                            NaN
# 65383                                            NaN
# 65413                  Bad at handling complex tasks
# 65415                                            NaN
# 65428                                            NaN
#
#                                    AIToolCurrently Using  \
# 0                                                    NaN
# 3      Learning about a codebase;Project planning;Wri...
# 5                Writing code;Debugging and getting help
# 6                                                    NaN
# 10     Learning about a codebase;Writing code;Documen...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                AIToolInterested in Using  \
# 0                                                    NaN
# 3      Testing code;Committing and reviewing code;Pre...
# 5      Documenting code;Testing code;Committing and r...
# 6                                                    NaN
# 10     Project planning;Testing code;Generating conte...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                            AIToolNot interested in Using  \
# 0                                                    NaN
# 3                                                    NaN
# 5             Learning about a codebase;Project planning
# 6                                                    NaN
# 10     Committing and reviewing code;Deployment and m...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                               AINextMuch more integrated  \
# 0                                                    NaN
# 3      Learning about a codebase;Project planning;Wri...
# 5                                                    NaN
# 6                                                    NaN
# 10                                                   NaN
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                AINextNo change  \
# 0                                          NaN
# 3                                          NaN
# 5      Writing code;Debugging and getting help
# 6                                          NaN
# 10                                         NaN
# ...                                        ...
# 65339                                      NaN
# 65383                                      NaN
# 65413                                      NaN
# 65415                                      NaN
# 65428                                      NaN
#
#                                    AINextMore integrated  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 10     Learning about a codebase;Writing code;Documen...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#       AINextLess integrated AINextMuch less integrated AIThreat  \
# 0                       NaN                        NaN      NaN
# 3                       NaN                        NaN       No
# 5                       NaN                        NaN       No
# 6                       NaN                        NaN      NaN
# 10                      NaN                        NaN       No
# ...                     ...                        ...      ...
# 65339                   NaN                        NaN      NaN
# 65383                   NaN                        NaN      NaN
# 65413                   NaN                        NaN      NaN
# 65415                   NaN                        NaN      NaN
# 65428                   NaN                        NaN      NaN
#
#                                                 AIEthics  \
# 0                                                    NaN
# 3      Circulating misinformation or disinformation;M...
# 5      Circulating misinformation or disinformation;M...
# 6                                                    NaN
# 10     Circulating misinformation or disinformation;M...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                             AIChallenges TBranch  \
# 0                                                    NaN      No
# 3                      Don’t trust the output or answers     NaN
# 5                                                    NaN     NaN
# 6                                                    NaN      No
# 10     Don’t trust the output or answers;AI tools lac...     Yes
# ...                                                  ...     ...
# 65339                                                NaN     NaN
# 65383                                                NaN     NaN
# 65413                                                NaN     NaN
# 65415                                                NaN     NaN
# 65428                                                NaN     NaN
#
#                        ICorPM  WorkExp     Knowledge_1 Knowledge_2  \
# 0                         NaN      NaN             NaN         NaN
# 3                         NaN      NaN             NaN         NaN
# 5                         NaN      NaN             NaN         NaN
# 6                         NaN      NaN             NaN         NaN
# 10     Individual contributor     15.0  Strongly agree       Agree
# ...                       ...      ...             ...         ...
# 65339                     NaN      NaN             NaN         NaN
# 65383                     NaN      NaN             NaN         NaN
# 65413                     NaN      NaN             NaN         NaN
# 65415                     NaN      NaN             NaN         NaN
# 65428                     NaN      NaN             NaN         NaN
#
#           Knowledge_3 Knowledge_4 Knowledge_5     Knowledge_6 Knowledge_7  \
# 0                 NaN         NaN         NaN             NaN         NaN
# 3                 NaN         NaN         NaN             NaN         NaN
# 5                 NaN         NaN         NaN             NaN         NaN
# 6                 NaN         NaN         NaN             NaN         NaN
# 10     Strongly agree       Agree       Agree  Strongly agree       Agree
# ...               ...         ...         ...             ...         ...
# 65339             NaN         NaN         NaN             NaN         NaN
# 65383             NaN         NaN         NaN             NaN         NaN
# 65413             NaN         NaN         NaN             NaN         NaN
# 65415             NaN         NaN         NaN             NaN         NaN
# 65428             NaN         NaN         NaN             NaN         NaN
#
#                       Knowledge_8                 Knowledge_9  \
# 0                             NaN                         NaN
# 3                             NaN                         NaN
# 5                             NaN                         NaN
# 6                             NaN                         NaN
# 10     Neither agree nor disagree  Neither agree nor disagree
# ...                           ...                         ...
# 65339                         NaN                         NaN
# 65383                         NaN                         NaN
# 65413                         NaN                         NaN
# 65415                         NaN                         NaN
# 65428                         NaN                         NaN
#
#             Frequency_1        Frequency_2        Frequency_3  \
# 0                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 5                   NaN                NaN                NaN
# 6                   NaN                NaN                NaN
# 10     3-5 times a week  6-10 times a week  6-10 times a week
# ...                 ...                ...                ...
# 65339               NaN                NaN                NaN
# 65383               NaN                NaN                NaN
# 65413               NaN                NaN                NaN
# 65415               NaN                NaN                NaN
# 65428               NaN                NaN                NaN
#
#              TimeSearching         TimeAnswering  \
# 0                      NaN                   NaN
# 3                      NaN                   NaN
# 5                      NaN                   NaN
# 6                      NaN                   NaN
# 10     30-60 minutes a day  60-120 minutes a day
# ...                    ...                   ...
# 65339                  NaN                   NaN
# 65383                  NaN                   NaN
# 65413                  NaN                   NaN
# 65415                  NaN                   NaN
# 65428                  NaN                   NaN
#
#                                              Frustration  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 10     Amount of technical debt;Number of software to...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                                         ProfessionalTech  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 10     DevOps function;Automated testing;Observabilit...
# ...                                                  ...
# 65339                                                NaN
# 65383                                                NaN
# 65413                                                NaN
# 65415                                                NaN
# 65428                                                NaN
#
#                         ProfessionalCloud       ProfessionalQuestion  \
# 0                                     NaN                        NaN
# 3                                     NaN                        NaN
# 5                                     NaN                        NaN
# 6                                     NaN                        NaN
# 10     Cloud only (single or multi-cloud)  Internal Developer portal
# ...                                   ...                        ...
# 65339                                 NaN                        NaN
# 65383                                 NaN                        NaN
# 65413                                 NaN                        NaN
# 65415                                 NaN                        NaN
# 65428                                 NaN                        NaN
#
#          Industry  JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  \
# 0             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 5             NaN             NaN             NaN             NaN
# 6             NaN             NaN             NaN             NaN
# 10     Healthcare            50.0             0.0             0.0
# ...           ...             ...             ...             ...
# 65339         NaN             NaN             NaN             NaN
# 65383         NaN             NaN             NaN             NaN
# 65413         NaN             NaN             NaN             NaN
# 65415         NaN             NaN             NaN             NaN
# 65428         NaN             NaN             NaN             NaN
#
#        JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  \
# 0                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 5                 NaN             NaN             NaN             NaN
# 6                 NaN             NaN             NaN             NaN
# 10               25.0            10.0             0.0            15.0
# ...               ...             ...             ...             ...
# 65339             NaN             NaN             NaN             NaN
# 65383             NaN             NaN             NaN             NaN
# 65413             NaN             NaN             NaN             NaN
# 65415             NaN             NaN             NaN             NaN
# 65428             NaN             NaN             NaN             NaN
#
#        JobSatPoints_10  JobSatPoints_11           SurveyLength  \
# 0                  NaN              NaN                    NaN
# 3                  NaN              NaN               Too long
# 5                  NaN              NaN  Appropriate in length
# 6                  NaN              NaN               Too long
# 10                 0.0              0.0  Appropriate in length
# ...                ...              ...                    ...
# 65339              NaN              NaN                    NaN
# 65383              NaN              NaN                    NaN
# 65413              NaN              NaN                    NaN
# 65415              NaN              NaN                    NaN
# 65428              NaN              NaN                    NaN
#
#                        SurveyEase  ConvertedCompYearly  JobSat
# 0                             NaN                  NaN     NaN
# 3                            Easy                  NaN     NaN
# 5                            Easy                  NaN     NaN
# 6      Neither easy nor difficult                  NaN     NaN
# 10                           Easy                  NaN     8.0
# ...                           ...                  ...     ...
# 65339                         NaN                  NaN     NaN
# 65383                         NaN                  NaN     NaN
# 65413                         NaN                  NaN     NaN
# 65415                         NaN                  NaN     NaN
# 65428                         NaN                  NaN     NaN
#
# [17430 rows x 114 columns]

# %%
df['Country'] = df['Country'].replace('Canneda','Canada')
filt = (df['Country'] == 'Canada')
df[filt]
# Out:
#        ResponseId                      MainBranch                 Age  \
# 3               4           I am learning to code     18-24 years old
# 16             17     I code primarily as a hobby  Under 18 years old
# 183           184  I am a developer by profession     45-54 years old
# 188           189  I am a developer by profession     25-34 years old
# 190           191  I am a developer by profession     55-64 years old
# ...           ...                             ...                 ...
# 64794       64795  I am a developer by profession     35-44 years old
# 64992       64993  I am a developer by profession     25-34 years old
# 65122       65123  I am a developer by profession     18-24 years old
# 65226       65227  I am a developer by profession     35-44 years old
# 65282       65283  I am a developer by profession     25-34 years old
#
#                                               Employment  \
# 3                                     Student, full-time
# 16                                    Student, full-time
# 183    Independent contractor, freelancer, or self-em...
# 188                                  Employed, full-time
# 190                                  Employed, full-time
# ...                                                  ...
# 64794                                Employed, full-time
# 64992                                Employed, full-time
# 65122                                Employed, full-time
# 65226                                Employed, full-time
# 65282                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 3                                       NaN  Apples
# 16                                      NaN  Apples
# 183                                  remote  Apples
# 188                                  remote  Apples
# 190                                  remote  Apples
# ...                                     ...     ...
# 64794                                remote  Apples
# 64992                                remote  Apples
# 65122                             in-person  Apples
# 65226                                remote  Apples
# 65282  hybrid (some remote, some in-person)  Apples
#
#                                         CodingActivities  \
# 3                                                    NaN
# 16                                                   NaN
# 183                   Contribute to open-source projects
# 188    Hobby;Professional development or self-paced l...
# 190    Professional development or self-paced learnin...
# ...                                                  ...
# 64794  Hobby;Contribute to open-source projects;Profe...
# 64992                           Bootstrapping a business
# 65122  Professional development or self-paced learnin...
# 65226                 Contribute to open-source projects
# 65282  School or academic work;Professional developme...
#
#                                                  EdLevel  \
# 3      Some college/university study without earning ...
# 16                             Primary/elementary school
# 183    Some college/university study without earning ...
# 188         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 190    Some college/university study without earning ...
# ...                                                  ...
# 64794    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64992                Associate degree (A.A., A.S., etc.)
# 65122       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65226                Associate degree (A.A., A.S., etc.)
# 65282       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 3      Other online resources (e.g., videos, blogs, f...
# 16     Books / Physical media;Other online resources ...
# 183    Books / Physical media;Other online resources ...
# 188    Books / Physical media;Colleague;On the job tr...
# 190    Books / Physical media;School (i.e., Universit...
# ...                                                  ...
# 64794  Books / Physical media;Other online resources ...
# 64992  Books / Physical media;Online Courses or Certi...
# 65122  On the job training;Other online resources (e....
# 65226  On the job training;School (i.e., University, ...
# 65282  On the job training;School (i.e., University, ...
#
#                                          LearnCodeOnline  \
# 3      Stack Overflow;How-to videos;Interactive tutorial
# 16     Technical documentation;Written Tutorials;Stac...
# 183    Technical documentation;Blogs;Books;Written Tu...
# 188    Technical documentation;Blogs;Books;Written Tu...
# 190                                                  NaN
# ...                                                  ...
# 64794  Technical documentation;Books;Interactive tuto...
# 64992                                                NaN
# 65122  Technical documentation;Blogs;Books;Written-ba...
# 65226                                                NaN
# 65282                                                NaN
#
#                                                  TechDoc YearsCode  \
# 3                                                    NaN         4
# 16     API document(s) and/or SDK document(s);Traditi...         7
# 183    API document(s) and/or SDK document(s);User gu...         7
# 188    API document(s) and/or SDK document(s);First-p...         8
# 190                                                  NaN        31
# ...                                                  ...       ...
# 64794  API document(s) and/or SDK document(s);User gu...        20
# 64992                                                NaN         7
# 65122  API document(s) and/or SDK document(s);User gu...         8
# 65226                                                NaN        24
# 65282                                                NaN        10
#
#       YearsCodePro                DevType                   OrgSize  \
# 3              NaN  Developer, full-stack                       NaN
# 16             NaN                Student                       NaN
# 183              4  Developer, full-stack                       NaN
# 188              8    Engineering manager                       NaN
# 190             30    Developer, back-end                       NaN
# ...            ...                    ...                       ...
# 64794           19    Developer, back-end  10,000 or more employees
# 64992            8    Developer, back-end  1,000 to 4,999 employees
# 65122            2    Developer, back-end  10,000 or more employees
# 65226           16   Developer Experience  1,000 to 4,999 employees
# 65282            5    Developer, back-end  1,000 to 4,999 employees
#
#                    PurchaseInfluence  \
# 3                                NaN
# 16                               NaN
# 183                              NaN
# 188                              NaN
# 190                              NaN
# ...                              ...
# 64794          I have some influence
# 64992          I have some influence
# 65122  I have little or no influence
# 65226          I have some influence
# 65282  I have little or no influence
#
#                                               BuyNewTool  \
# 3                                                    NaN
# 16                                                   NaN
# 183                                                  NaN
# 188                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 64794  Start a free trial;Ask developers I know/work ...
# 64992  Start a free trial;Ask developers I know/work ...
# 65122  Ask developers I know/work with;Ask a generati...
# 65226  Start a free trial;Research companies that hav...
# 65282                    Ask developers I know/work with
#
#                                               BuildvsBuy  \
# 3                                                    NaN
# 16                                                   NaN
# 183                                                  NaN
# 188                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 64794                                                NaN
# 64992  Is ready-to-go but also customizable for growt...
# 65122  Is ready-to-go but also customizable for growt...
# 65226  Is set up to be customized and needs to be eng...
# 65282                                                NaN
#
#                                              TechEndorse Country  \
# 3                                                    NaN  Canada
# 16                                                   NaN  Canada
# 183                                                  NaN  Canada
# 188                                                  NaN  Canada
# 190                                                  NaN  Canada
# ...                                                  ...     ...
# 64794  Reputation for quality and excellence;Frequent...  Canada
# 64992         APIs;Reputation for quality and excellence  Canada
# 65122  APIs;Customization;Integrated developer commun...  Canada
# 65226  APIs;Frequent updates to features;Connected to...  Canada
# 65282                                                NaN  Canada
#
#                    Currency  CompTotal  \
# 3                       NaN        NaN
# 16                      NaN        NaN
# 183                     NaN        NaN
# 188                     NaN        NaN
# 190                     NaN        NaN
# ...                     ...        ...
# 64794  CAD\tCanadian dollar        NaN
# 64992  CAD\tCanadian dollar   200000.0
# 65122  CAD\tCanadian dollar   100000.0
# 65226  CAD\tCanadian dollar        NaN
# 65282  CAD\tCanadian dollar   174000.0
#
#                                   LanguageHaveWorkedWith  \
# 3      C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 16                                       Rust;TypeScript
# 183           Bash/Shell (all shells);C;Clojure;Dart;Lua
# 188                Go;HTML/CSS;JavaScript;SQL;TypeScript
# 190                                                   C#
# ...                                                  ...
# 64794                                       Go;Java;Ruby
# 64992  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 65122                                Java;SQL;TypeScript
# 65226                                                NaN
# 65282  Bash/Shell (all shells);Go;JavaScript;Python;S...
#
#                                   LanguageWantToWorkWith  \
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 16                                       Rust;TypeScript
# 183                                                  NaN
# 188                                   Dart;Go;TypeScript
# 190                        C#;HTML/CSS;JavaScript;Python
# ...                                                  ...
# 64794                                Go;Java;Kotlin;Rust
# 64992  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 65122                                       Python;Scala
# 65226                                                NaN
# 65282       Bash/Shell (all shells);Go;Python;TypeScript
#
#                                          LanguageAdmired  \
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 16                                       Rust;TypeScript
# 183                                                  NaN
# 188                                        Go;TypeScript
# 190                                                   C#
# ...                                                  ...
# 64794                                            Go;Java
# 64992  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 65122                                                NaN
# 65226                                                NaN
# 65282       Bash/Shell (all shells);Go;Python;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 3                        MongoDB;MySQL;PostgreSQL;SQLite
# 16                                                   NaN
# 183                                         MySQL;SQLite
# 188                           Dynamodb;PostgreSQL;SQLite
# 190                                 Microsoft SQL Server
# ...                                                  ...
# 64794                                   MySQL;PostgreSQL
# 64992  Databricks SQL;Dynamodb;Elasticsearch;Firebase...
# 65122                                    IBM DB2;MongoDB
# 65226                                                NaN
# 65282                     Dynamodb;Elasticsearch;MongoDB
#
#                              DatabaseWantToWorkWith  \
# 3                          MongoDB;MySQL;PostgreSQL
# 16                                              NaN
# 183                                             NaN
# 188                     Dynamodb;MongoDB;PostgreSQL
# 190                Microsoft SQL Server;Neo4J;Redis
# ...                                             ...
# 64794                              MySQL;PostgreSQL
# 64992  BigQuery;Dynamodb;PostgreSQL;Redis;Snowflake
# 65122                                           NaN
# 65226                                           NaN
# 65282                                 Elasticsearch
#
#                            DatabaseAdmired  \
# 3                 MongoDB;MySQL;PostgreSQL
# 16                                     NaN
# 183                                    NaN
# 188                    Dynamodb;PostgreSQL
# 190                   Microsoft SQL Server
# ...                                    ...
# 64794                     MySQL;PostgreSQL
# 64992  Dynamodb;PostgreSQL;Redis;Snowflake
# 65122                                  NaN
# 65226                                  NaN
# 65282                        Elasticsearch
#
#                                   PlatformHaveWorkedWith  \
# 3                Amazon Web Services (AWS);Fly.io;Heroku
# 16                                                   NaN
# 183                                             Supabase
# 188             Amazon Web Services (AWS);Netlify;Vercel
# 190                                      Microsoft Azure
# ...                                                  ...
# 64794                                                NaN
# 64992  Amazon Web Services (AWS);Databricks;Google Cl...
# 65122                                                NaN
# 65226                                                NaN
# 65282            Amazon Web Services (AWS);Digital Ocean
#
#                           PlatformWantToWorkWith  \
# 3               Amazon Web Services (AWS);Vercel
# 16                                           NaN
# 183                                        Vultr
# 188             Amazon Web Services (AWS);Vercel
# 190    Amazon Web Services (AWS);Microsoft Azure
# ...                                          ...
# 64794                                        NaN
# 64992     Amazon Web Services (AWS);Google Cloud
# 65122                                        NaN
# 65226                                        NaN
# 65282    Amazon Web Services (AWS);Digital Ocean
#
#                                PlatformAdmired  \
# 3                    Amazon Web Services (AWS)
# 16                                         NaN
# 183                                        NaN
# 188           Amazon Web Services (AWS);Vercel
# 190                            Microsoft Azure
# ...                                        ...
# 64794                                      NaN
# 64992   Amazon Web Services (AWS);Google Cloud
# 65122                                      NaN
# 65226                                      NaN
# 65282  Amazon Web Services (AWS);Digital Ocean
#
#                        WebframeHaveWorkedWith  \
# 3      jQuery;Next.js;Node.js;React;WordPress
# 16                                    Node.js
# 183                                 WordPress
# 188                    Angular;NestJS;Node.js
# 190                       ASP.NET CORE;Blazor
# ...                                       ...
# 64794                                     NaN
# 64992                                     NaN
# 65122                                 Angular
# 65226                                     NaN
# 65282                          NestJS;Node.js
#
#                        WebframeWantToWorkWith               WebframeAdmired  \
# 3                jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 16                              Deno;Solid.js                           NaN
# 183                                       NaN                           NaN
# 188                                    NestJS                        NestJS
# 190    Angular;ASP.NET CORE;Blazor;Htmx;React           ASP.NET CORE;Blazor
# ...                                       ...                           ...
# 64794                                     NaN                           NaN
# 64992                                     NaN                           NaN
# 65122                                     NaN                           NaN
# 65226                                     NaN                           NaN
# 65282                                  NestJS                        NestJS
#
#       EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# 3                Rasberry Pi                    NaN             NaN
# 16                       NaN                    NaN             NaN
# 183       CMake;LLVM's Clang                    NaN             NaN
# 188              Rasberry Pi            Rasberry Pi     Rasberry Pi
# 190                      NaN                    NaN             NaN
# ...                      ...                    ...             ...
# 64794                    NaN                    NaN             NaN
# 64992                    NaN                    NaN             NaN
# 65122                    NaN                    NaN             NaN
# 65226                    NaN                    NaN             NaN
# 65282                    NaN                    NaN             NaN
#
#              MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# 3      NumPy;Pandas;Ruff;TensorFlow                    NaN
# 16                              NaN                    NaN
# 183                         Flutter                    NaN
# 188              Capacitor;RabbitMQ               RabbitMQ
# 190             .NET (5+) ;RabbitMQ    .NET (5+) ;RabbitMQ
# ...                             ...                    ...
# 64794                           NaN                    NaN
# 64992                           NaN                    NaN
# 65122              Spring Framework       Spring Framework
# 65226                           NaN                    NaN
# 65282                  Apache Kafka                    NaN
#
#            MiscTechAdmired                        ToolsTechHaveWorkedWith  \
# 3                      NaN                                 Docker;npm;Pip
# 16                     NaN                                       npm;Vite
# 183                    NaN  Docker;Homebrew;Kubernetes;Maven (build tool)
# 188               RabbitMQ             Docker;npm;Terraform;Unity 3D;Vite
# 190    .NET (5+) ;RabbitMQ                                   Docker;NuGet
# ...                    ...                                            ...
# 64794                  NaN                                            NaN
# 64992                  NaN                                            NaN
# 65122     Spring Framework                           Docker;Gradle;Podman
# 65226                  NaN                                            NaN
# 65282                  NaN                     Docker;Kubernetes;Pip;pnpm
#
#                  ToolsTechWantToWorkWith                ToolsTechAdmired  \
# 3                  Docker;Kubernetes;npm                      Docker;npm
# 16                                  Vite                            Vite
# 183                                  NaN                             NaN
# 188       Docker;Terraform;Unity 3D;Vite  Docker;Terraform;Unity 3D;Vite
# 190    Docker;Kubernetes;NuGet;Terraform                    Docker;NuGet
# ...                                  ...                             ...
# 64794                                NaN                             NaN
# 64992                                NaN                             NaN
# 65122                      Docker;Podman                   Docker;Podman
# 65226                                NaN                             NaN
# 65282         Docker;Kubernetes;Pip;pnpm      Docker;Kubernetes;Pip;pnpm
#
#                             NEWCollabToolsHaveWorkedWith  \
# 3                                                    NaN
# 16                                    Visual Studio Code
# 183                          Android Studio;Neovim;Xcode
# 188                                    Vim;Visual Studio
# 190                     Visual Studio;Visual Studio Code
# ...                                                  ...
# 64794                                                NaN
# 64992                                                NaN
# 65122         IntelliJ IDEA;Notepad++;Visual Studio Code
# 65226                                                NaN
# 65282  BBEdit;Jupyter Notebook/JupyterLab;PyCharm;Vis...
#
#                      NEWCollabToolsWantToWorkWith  \
# 3                                             NaN
# 16                             Visual Studio Code
# 183                                           NaN
# 188                             Vim;Visual Studio
# 190              Visual Studio;Visual Studio Code
# ...                                           ...
# 64794                                         NaN
# 64992                                         NaN
# 65122  IntelliJ IDEA;Notepad++;Visual Studio Code
# 65226                                         NaN
# 65282                  PyCharm;Visual Studio Code
#
#                             NEWCollabToolsAdmired  \
# 3                                             NaN
# 16                             Visual Studio Code
# 183                                           NaN
# 188                             Vim;Visual Studio
# 190              Visual Studio;Visual Studio Code
# ...                                           ...
# 64794                                         NaN
# 64992                                         NaN
# 65122  IntelliJ IDEA;Notepad++;Visual Studio Code
# 65226                                         NaN
# 65282                  PyCharm;Visual Studio Code
#
#                                        OpSysPersonal use  \
# 3                                                    NaN
# 16                                                  Arch
# 183                                                MacOS
# 188    Debian;Ubuntu;Windows;Windows Subsystem for Li...
# 190    Windows;Windows Subsystem for Linux (WSL);Othe...
# ...                                                  ...
# 64794                                                NaN
# 64992                                                NaN
# 65122                                            Windows
# 65226                                                NaN
# 65282                                   iOS;iPadOS;MacOS
#
#                                    OpSysProfessional use  \
# 3                                                    NaN
# 16                                                   NaN
# 183                                                  NaN
# 188                                                MacOS
# 190    Windows;Windows Subsystem for Linux (WSL);Othe...
# ...                                                  ...
# 64794                                                NaN
# 64992                                                NaN
# 65122                                            Windows
# 65226                                                NaN
# 65282                                              MacOS
#
#                           OfficeStackAsyncHaveWorkedWith  \
# 3                                                    NaN
# 16                                                   NaN
# 183                     GitHub Discussions;Markdown File
# 188                                     Jira;Miro;Notion
# 190                                Azure Devops;Obsidian
# ...                                                  ...
# 64794                                                NaN
# 64992                                                NaN
# 65122  Jira;Markdown File;Obsidian;Stack Overflow for...
# 65226                                                NaN
# 65282                               Confluence;Jira;Miro
#
#           OfficeStackAsyncWantToWorkWith            OfficeStackAsyncAdmired  \
# 3                                    NaN                                NaN
# 16                                   NaN                                NaN
# 183                                  NaN                                NaN
# 188                          Miro;Notion                        Miro;Notion
# 190                Azure Devops;Obsidian              Azure Devops;Obsidian
# ...                                  ...                                ...
# 64794                                NaN                                NaN
# 64992                                NaN                                NaN
# 65122  Obsidian;Stack Overflow for Teams  Obsidian;Stack Overflow for Teams
# 65226                                NaN                                NaN
# 65282                    Confluence;Jira                    Confluence;Jira
#
#       OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 3                               NaN                           NaN
# 16                          Discord                       Discord
# 183                           Slack                           NaN
# 188               Google Meet;Slack             Google Meet;Slack
# 190                 Microsoft Teams               Microsoft Teams
# ...                             ...                           ...
# 64794                           NaN                           NaN
# 64992                           NaN                           NaN
# 65122                          Zoom                           NaN
# 65226                           NaN                           NaN
# 65282     Discord;Google Meet;Slack     Discord;Google Meet;Slack
#
#           OfficeStackSyncAdmired  \
# 3                            NaN
# 16                       Discord
# 183                          NaN
# 188            Google Meet;Slack
# 190              Microsoft Teams
# ...                          ...
# 64794                        NaN
# 64992                        NaN
# 65122                        NaN
# 65226                        NaN
# 65282  Discord;Google Meet;Slack
#
#                               AISearchDevHaveWorkedWith  \
# 3                                                   NaN
# 16     ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 183                                                 NaN
# 188                                      GitHub Copilot
# 190                   ChatGPT;Visual Studio Intellicode
# ...                                                 ...
# 64794                                               NaN
# 64992                                               NaN
# 65122                             ChatGPT;Perplexity AI
# 65226                                               NaN
# 65282                             Claude;GitHub Copilot
#
#                               AISearchDevWantToWorkWith  \
# 3                                                   NaN
# 16     ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 183                                                 NaN
# 188                                      GitHub Copilot
# 190    ChatGPT;GitHub Copilot;Visual Studio Intellicode
# ...                                                 ...
# 64794                                               NaN
# 64992                                               NaN
# 65122                                               NaN
# 65226                                               NaN
# 65282                     ChatGPT;Claude;GitHub Copilot
#
#                                      AISearchDevAdmired  \
# 3                                                   NaN
# 16     ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 183                                                 NaN
# 188                                      GitHub Copilot
# 190                   ChatGPT;Visual Studio Intellicode
# ...                                                 ...
# 64794                                               NaN
# 64992                                               NaN
# 65122                                               NaN
# 65226                                               NaN
# 65282                             Claude;GitHub Copilot
#
#                                               NEWSOSites  \
# 3                                         Stack Overflow
# 16                                        Stack Overflow
# 183    Stack Overflow;Stack Exchange;Stack Overflow B...
# 188                                       Stack Overflow
# 190                        Stack Overflow;Stack Exchange
# ...                                                  ...
# 64794                                                NaN
# 64992                      Stack Overflow;Stack Exchange
# 65122                      Stack Overflow;Stack Exchange
# 65226                                     Stack Overflow
# 65282  Stack Overflow for Teams (private knowledge sh...
#
#                            SOVisitFreq SOAccount  \
# 3                Daily or almost daily        No
# 16                A few times per week       Yes
# 183              Daily or almost daily       Yes
# 188    A few times per month or weekly       Yes
# 190    A few times per month or weekly       Yes
# ...                                ...       ...
# 64794                              NaN       NaN
# 64992            Daily or almost daily       Yes
# 65122            Daily or almost daily       Yes
# 65226  A few times per month or weekly       Yes
# 65282             A few times per week       Yes
#
#                                               SOPartFreq  \
# 3                                                    NaN
# 16                   Less than once per month or monthly
# 183                                Daily or almost daily
# 188    I have never participated in Q&A on Stack Over...
# 190                      A few times per month or weekly
# ...                                                  ...
# 64794                                                NaN
# 64992                               A few times per week
# 65122                Less than once per month or monthly
# 65226                Less than once per month or monthly
# 65282                Less than once per month or monthly
#
#                                                    SOHow           SOComm  \
# 3                         Quickly finding code solutions   No, not really
# 16     Quickly finding code solutions;Learning new-to...   No, not really
# 183    Quickly finding code solutions;Finding reliabl...    Yes, somewhat
# 188                       Quickly finding code solutions   No, not really
# 190    Quickly finding code solutions;Finding reliabl...   No, not really
# ...                                                  ...              ...
# 64794                                                NaN              NaN
# 64992  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 65122                     Quickly finding code solutions          Neutral
# 65226  Finding reliable guidance from community-vette...    Yes, somewhat
# 65282                     Quickly finding code solutions   No, not really
#
#                       AISelect          AISent  \
# 3                          Yes  Very favorable
# 16                         Yes       Favorable
# 183    No, and I don't plan to             NaN
# 188     No, but I plan to soon       Favorable
# 190     No, but I plan to soon       Favorable
# ...                        ...             ...
# 64794  No, and I don't plan to             NaN
# 64992                      Yes  Very favorable
# 65122   No, but I plan to soon       Favorable
# 65226                      NaN             NaN
# 65282                      Yes       Favorable
#
#                                                    AIBen              AIAcc  \
# 3      Increase productivity;Greater efficiency;Impro...     Somewhat trust
# 16              Increase productivity;Greater efficiency  Somewhat distrust
# 183                                                  NaN                NaN
# 188                                                  NaN                NaN
# 190                                                  NaN                NaN
# ...                                                  ...                ...
# 64794                                                NaN                NaN
# 64992           Increase productivity;Greater efficiency     Somewhat trust
# 65122                                                NaN                NaN
# 65226                                                NaN                NaN
# 65282  Increase productivity;Greater efficiency;Speed...     Somewhat trust
#
#                                            AIComplex  \
# 3                      Bad at handling complex tasks
# 16     Neither good or bad at handling complex tasks
# 183                                              NaN
# 188                                              NaN
# 190                                              NaN
# ...                                              ...
# 64794                                            NaN
# 64992  Neither good or bad at handling complex tasks
# 65122                                            NaN
# 65226                                            NaN
# 65282            Very poor at handling complex tasks
#
#                                    AIToolCurrently Using  \
# 3      Learning about a codebase;Project planning;Wri...
# 16                             Writing code;Testing code
# 183                                                  NaN
# 188                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 64794                                                NaN
# 64992  Writing code;Documenting code;Search for answe...
# 65122                                                NaN
# 65226                                                NaN
# 65282  Writing code;Documenting code;Debugging and ge...
#
#                                AIToolInterested in Using  \
# 3      Testing code;Committing and reviewing code;Pre...
# 16     Learning about a codebase;Documenting code;Sea...
# 183                                                  NaN
# 188                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 64794                                                NaN
# 64992  Debugging and getting help;Testing code;Commit...
# 65122                                                NaN
# 65226                                                NaN
# 65282                          Learning about a codebase
#
#                            AIToolNot interested in Using  \
# 3                                                    NaN
# 16     Project planning;Debugging and getting help;Co...
# 183                                                  NaN
# 188                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 64794                                                NaN
# 64992         Learning about a codebase;Project planning
# 65122                                                NaN
# 65226                                                NaN
# 65282                                                NaN
#
#                               AINextMuch more integrated AINextNo change  \
# 3      Learning about a codebase;Project planning;Wri...             NaN
# 16                                                   NaN             NaN
# 183                                                  NaN             NaN
# 188                                                  NaN             NaN
# 190                                                  NaN             NaN
# ...                                                  ...             ...
# 64794                                                NaN             NaN
# 64992                      Writing code;Documenting code             NaN
# 65122                                                NaN             NaN
# 65226                                                NaN             NaN
# 65282  Writing code;Documenting code;Debugging and ge...             NaN
#
#                                    AINextMore integrated  \
# 3                                                    NaN
# 16                             Writing code;Testing code
# 183                                                  NaN
# 188                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 64794                                                NaN
# 64992  Search for answers;Generating content or synth...
# 65122                                                NaN
# 65226                                                NaN
# 65282                                                NaN
#
#       AINextLess integrated AINextMuch less integrated      AIThreat  \
# 3                       NaN                        NaN            No
# 16                      NaN                        NaN            No
# 183                     NaN                        NaN           NaN
# 188                     NaN                        NaN  I'm not sure
# 190                     NaN                        NaN  I'm not sure
# ...                     ...                        ...           ...
# 64794                   NaN                        NaN           NaN
# 64992                   NaN                        NaN            No
# 65122                   NaN                        NaN            No
# 65226                   NaN                        NaN           NaN
# 65282                   NaN                        NaN  I'm not sure
#
#                                                 AIEthics  \
# 3      Circulating misinformation or disinformation;M...
# 16     Circulating misinformation or disinformation;M...
# 183                                                  NaN
# 188    Circulating misinformation or disinformation;M...
# 190    Circulating misinformation or disinformation;M...
# ...                                                  ...
# 64794                                                NaN
# 64992  Biased results that do not represent diverse v...
# 65122  Circulating misinformation or disinformation;M...
# 65226                                                NaN
# 65282  Circulating misinformation or disinformation;M...
#
#                                             AIChallenges TBranch  \
# 3                      Don’t trust the output or answers     NaN
# 16                                                   NaN     NaN
# 183                                                  NaN     NaN
# 188    Don’t trust the output or answers;Lack of prop...     Yes
# 190    We don’t have the right policies in place to r...     Yes
# ...                                                  ...     ...
# 64794                                                NaN     NaN
# 64992    Lack of executive buy-in;Not everyone uses them     NaN
# 65122  Don’t trust the output or answers;AI tools lac...     Yes
# 65226                                                NaN     NaN
# 65282  AI tools lack context of codebase,  internal a...     Yes
#
#                        ICorPM  WorkExp     Knowledge_1  \
# 3                         NaN      NaN             NaN
# 16                        NaN      NaN             NaN
# 183                       NaN      NaN             NaN
# 188            People manager      8.0  Strongly agree
# 190    Individual contributor     30.0  Strongly agree
# ...                       ...      ...             ...
# 64794                     NaN      NaN             NaN
# 64992                     NaN      NaN             NaN
# 65122  Individual contributor      3.0             NaN
# 65226                     NaN      NaN             NaN
# 65282  Individual contributor      7.0             NaN
#
#                       Knowledge_2 Knowledge_3        Knowledge_4  \
# 3                             NaN         NaN                NaN
# 16                            NaN         NaN                NaN
# 183                           NaN         NaN                NaN
# 188    Neither agree nor disagree    Disagree              Agree
# 190                         Agree    Disagree  Strongly disagree
# ...                           ...         ...                ...
# 64794                         NaN         NaN                NaN
# 64992                         NaN         NaN                NaN
# 65122                         NaN         NaN                NaN
# 65226                         NaN         NaN                NaN
# 65282                         NaN         NaN                NaN
#
#                       Knowledge_5     Knowledge_6                 Knowledge_7  \
# 3                             NaN             NaN                         NaN
# 16                            NaN             NaN                         NaN
# 183                           NaN             NaN                         NaN
# 188                         Agree           Agree                       Agree
# 190    Neither agree nor disagree  Strongly agree  Neither agree nor disagree
# ...                           ...             ...                         ...
# 64794                         NaN             NaN                         NaN
# 64992                         NaN             NaN                         NaN
# 65122                         NaN             NaN                         NaN
# 65226                         NaN             NaN                         NaN
# 65282                         NaN             NaN                         NaN
#
#       Knowledge_8        Knowledge_9       Frequency_1       Frequency_2  \
# 3             NaN                NaN               NaN               NaN
# 16            NaN                NaN               NaN               NaN
# 183           NaN                NaN               NaN               NaN
# 188      Disagree              Agree  1-2 times a week  1-2 times a week
# 190         Agree  Strongly disagree  1-2 times a week  10+ times a week
# ...           ...                ...               ...               ...
# 64794         NaN                NaN               NaN               NaN
# 64992         NaN                NaN               NaN               NaN
# 65122         NaN                NaN               NaN               NaN
# 65226         NaN                NaN               NaN               NaN
# 65282         NaN                NaN               NaN               NaN
#
#             Frequency_3        TimeSearching        TimeAnswering  \
# 3                   NaN                  NaN                  NaN
# 16                  NaN                  NaN                  NaN
# 183                 NaN                  NaN                  NaN
# 188    1-2 times a week  15-30 minutes a day  15-30 minutes a day
# 190    3-5 times a week  15-30 minutes a day  30-60 minutes a day
# ...                 ...                  ...                  ...
# 64794               NaN                  NaN                  NaN
# 64992               NaN                  NaN                  NaN
# 65122               NaN                  NaN                  NaN
# 65226               NaN                  NaN                  NaN
# 65282               NaN                  NaN                  NaN
#
#                                              Frustration  \
# 3                                                    NaN
# 16                                                   NaN
# 183                                                  NaN
# 188    Tracking my work;Complexity of tech stack for ...
# 190                             Amount of technical debt
# ...                                                  ...
# 64794                                                NaN
# 64992                                                NaN
# 65122                                                NaN
# 65226                                                NaN
# 65282                                                NaN
#
#                                         ProfessionalTech  \
# 3                                                    NaN
# 16                                                   NaN
# 183                                                  NaN
# 188    DevOps function;Automated testing;Observabilit...
# 190    DevOps function;Microservices;Continuous integ...
# ...                                                  ...
# 64794                                                NaN
# 64992                                                NaN
# 65122                                                NaN
# 65226                                                NaN
# 65282                                                NaN
#
#                         ProfessionalCloud  \
# 3                                     NaN
# 16                                    NaN
# 183                                   NaN
# 188    Cloud only (single or multi-cloud)
# 190    Cloud only (single or multi-cloud)
# ...                                   ...
# 64794                                 NaN
# 64992                                 NaN
# 65122                                 NaN
# 65226                                 NaN
# 65282                                 NaN
#
#                                     ProfessionalQuestion Industry  \
# 3                                                    NaN      NaN
# 16                                                   NaN      NaN
# 183                                                  NaN      NaN
# 188    Do search of internal share drives/storage loc...  Fintech
# 190                                           A coworker  Fintech
# ...                                                  ...      ...
# 64794                                                NaN      NaN
# 64992                                                NaN      NaN
# 65122                                                NaN      NaN
# 65226                                                NaN      NaN
# 65282                                                NaN      NaN
#
#        JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 3                 NaN             NaN             NaN             NaN
# 16                NaN             NaN             NaN             NaN
# 183               NaN             NaN             NaN             NaN
# 188              10.0             5.0             0.0            20.0
# 190              40.0             0.0             0.0            25.0
# ...               ...             ...             ...             ...
# 64794             NaN             NaN             NaN             NaN
# 64992             NaN             NaN             NaN             NaN
# 65122             NaN             NaN             NaN             NaN
# 65226             NaN             NaN             NaN             NaN
# 65282             NaN             NaN             NaN             NaN
#
#        JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 3                 NaN             NaN             NaN              NaN
# 16                NaN             NaN             NaN              NaN
# 183               NaN             NaN             NaN              NaN
# 188              15.0            15.0            20.0              5.0
# 190               5.0            25.0             5.0              0.0
# ...               ...             ...             ...              ...
# 64794             NaN             NaN             NaN              NaN
# 64992             NaN             NaN             NaN              NaN
# 65122             NaN             NaN             NaN              NaN
# 65226             NaN             NaN             NaN              NaN
# 65282             NaN             NaN             NaN              NaN
#
#        JobSatPoints_11           SurveyLength                  SurveyEase  \
# 3                  NaN               Too long                        Easy
# 16                 NaN  Appropriate in length                        Easy
# 183                NaN  Appropriate in length                        Easy
# 188               10.0  Appropriate in length  Neither easy nor difficult
# 190                0.0  Appropriate in length  Neither easy nor difficult
# ...                ...                    ...                         ...
# 64794              NaN                    NaN                         NaN
# 64992              NaN                    NaN                         NaN
# 65122              NaN                    NaN                         NaN
# 65226              NaN                    NaN                         NaN
# 65282              NaN                    NaN                         NaN
#
#        ConvertedCompYearly  JobSat
# 3                      NaN     NaN
# 16                     NaN     NaN
# 183                    NaN     NaN
# 188                    NaN     7.0
# 190                    NaN     9.0
# ...                    ...     ...
# 64794                  NaN     NaN
# 64992                  NaN     NaN
# 65122                  NaN     NaN
# 65226                  NaN     NaN
# 65282                  NaN     NaN
#
# [2104 rows x 114 columns]

# %%
df.rename(columns={'CompTotal':'Salary'}, inplace= True)    #renaming column 'CompTotal' with 'Salary'
df['Salary']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 65432   NaN
# 65433   NaN
# 65434   NaN
# 65435   NaN
# 65436   NaN
# Name: Salary, Length: 65437, dtype: float64

# %%
df['SOAccount'].map({'Yes':'True', 'No': 'False'})   # Mapping Yes and No values to True and False respectively
df['SOAccount']
# Out:
# 0        NaN
# 1        Yes
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 65432    NaN
# 65433    NaN
# 65434    NaN
# 65435     No
# 65436    Yes
# Name: SOAccount, Length: 65437, dtype: str

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/survey.csv')
schema_df = pd.read_csv('../data/schema.csv')

# %%
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %%
df.Check.value_counts()
# Out:
# Check
# Apples    65437
# Name: count, dtype: int64

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# 2           Employed, full-time                                Remote  Apples
# 3           Employed, full-time                                Remote  Apples
# 4            Student, full-time                                   NaN  Apples
# 5            Student, full-time                                   NaN  Apples
# ...                         ...                                   ...     ...
# 65433       Employed, full-time                                Remote  Apples
# 65434       Employed, full-time                                Remote  Apples
# 65435       Employed, full-time                             In-person  Apples
# 65436       Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65437        Student, full-time                                   NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 65433                           Hobby;School or academic work
# 65434                Hobby;Contribute to open-source projects
# 65435                                                   Hobby
# 65436       Hobby;Contribute to open-source projects;Profe...
# 65437                                                     NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
# ...                                                       ...
# 65433            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65434                                                     NaN
# 65435            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65436       Secondary school (e.g. American high school, G...
# 65437                                                     NaN
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# 2           Books / Physical media;Colleague;On the job tr...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
# ...                                                       ...
# 65433       On the job training;School (i.e., University, ...
# 65434                                                     NaN
# 65435       Other online resources (e.g., videos, blogs, f...
# 65436       On the job training;Other online resources (e....
# 65437                                                     NaN
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2           Technical documentation;Blogs;Books;Written Tu...
# 3           Technical documentation;Blogs;Books;Written Tu...
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 5           Technical documentation;Blogs;Written Tutorial...
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435       Technical documentation;Stack Overflow;Social ...
# 65436       Technical documentation;Blogs;Written Tutorial...
# 65437                                                     NaN
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 1                                                         NaN       NaN
# 2           API document(s) and/or SDK document(s);User gu...        20
# 3           API document(s) and/or SDK document(s);User gu...        37
# 4                                                         NaN         4
# 5           API document(s) and/or SDK document(s);User gu...         9
# ...                                                       ...       ...
# 65433                                                     NaN         5
# 65434                                                     NaN       NaN
# 65435       API document(s) and/or SDK document(s);AI-powe...         9
# 65436       API document(s) and/or SDK document(s);User gu...         5
# 65437                                                     NaN       NaN
#
#            YearsCodePro                DevType                   OrgSize  \
# ResponseId
# 1                   NaN                    NaN                       NaN
# 2                    17  Developer, full-stack                       NaN
# 3                    27   Developer Experience                       NaN
# 4                   NaN  Developer, full-stack                       NaN
# 5                   NaN  Developer, full-stack                       NaN
# ...                 ...                    ...                       ...
# 65433                 3             Blockchain          2 to 9 employees
# 65434               NaN                    NaN                       NaN
# 65435                 5      Developer, mobile  1,000 to 4,999 employees
# 65436                 2    Developer, back-end        20 to 99 employees
# 65437               NaN                    NaN                       NaN
#
#                         PurchaseInfluence  \
# ResponseId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# ...                                   ...
# 65433               I have some influence
# 65434                                 NaN
# 65435       I have little or no influence
# 65436               I have some influence
# 65437                                 NaN
#
#                                                    BuyNewTool  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 65433       Ask developers I know/work with;Ask a generati...
# 65434                                                     NaN
# 65435       Ask developers I know/work with;Ask a generati...
# 65436       Start a free trial;Ask developers I know/work ...
# 65437                                                     NaN
#
#                                                    BuildvsBuy  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 65433       Is ready-to-go but also customizable for growt...
# 65434                                                     NaN
# 65435                                                     NaN
# 65436       Is ready-to-go but also customizable for growt...
# 65437                                                     NaN
#
#                                                   TechEndorse  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 65433       APIs;Integrated developer community;Quality su...
# 65434                                                     NaN
# 65435                                                     NaN
# 65436       APIs;Customization;Connected to an open source...
# 65437                                                     NaN
#
#                                                       Country  \
# ResponseId
# 1                                    United States of America
# 2           United Kingdom of Great Britain and Northern I...
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Canada
# 5                                                      Norway
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                 Germany
# 65437                                                     NaN
#
#                      Currency  CompTotal  \
# ResponseId
# 1                         NaN        NaN
# 2                         NaN        NaN
# 3                         NaN        NaN
# 4                         NaN        NaN
# 5                         NaN        NaN
# ...                       ...        ...
# 65433                     NaN        NaN
# 65434                     NaN        NaN
# 65435                     NaN        NaN
# 65436       EUR European Euro        NaN
# 65437                     NaN        NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                     C++;HTML/CSS;JavaScript;Lua;Python;Rust
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65437        C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                Rust;SQL
# 65437                            JavaScript;Python;TypeScript
#
#                                               LanguageAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                Rust;SQL
# 65437                            JavaScript;Python;TypeScript
#
#                      DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# ResponseId
# 1                                       NaN                         NaN
# 2               Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 3                Firebase Realtime Database  Firebase Realtime Database
# 4           MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 5                         PostgreSQL;SQLite           PostgreSQL;SQLite
# ...                                     ...                         ...
# 65433                                   NaN                         NaN
# 65434                                   NaN                         NaN
# 65435                                   NaN                         NaN
# 65436                     PostgreSQL;SQLite           PostgreSQL;SQLite
# 65437       MongoDB;MySQL;Oracle;PostgreSQL    MongoDB;MySQL;PostgreSQL
#
#                        DatabaseAdmired  \
# ResponseId
# 1                                  NaN
# 2                           PostgreSQL
# 3           Firebase Realtime Database
# 4             MongoDB;MySQL;PostgreSQL
# 5                    PostgreSQL;SQLite
# ...                                ...
# 65433                              NaN
# 65434                              NaN
# 65435                              NaN
# 65436                PostgreSQL;SQLite
# 65437         MongoDB;MySQL;PostgreSQL
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                    Amazon Web Services (AWS);Heroku;Netlify
# 3                                                Google Cloud
# 4                     Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                         NaN
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                     NaN
# 65437       Amazon Web Services (AWS);Cloudflare;Google Cl...
#
#                               PlatformWantToWorkWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                   Amazon Web Services (AWS);Vercel
# 5                                                NaN
# ...                                              ...
# 65433                                            NaN
# 65434                                            NaN
# 65435                                            NaN
# 65436                                            NaN
# 65437         Cloudflare;Google Cloud;Netlify;Vercel
#
#                                      PlatformAdmired  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                          Amazon Web Services (AWS)
# 5                                                NaN
# ...                                              ...
# 65433                                            NaN
# 65434                                            NaN
# 65435                                            NaN
# 65436                                            NaN
# 65437         Cloudflare;Google Cloud;Netlify;Vercel
#
#                                  WebframeHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2                         Express;Next.js;Node.js;React
# 3                                          ASP.NET CORE
# 4                jQuery;Next.js;Node.js;React;WordPress
# 5                                                   NaN
# ...                                                 ...
# 65433                                               NaN
# 65434                                               NaN
# 65435                                               NaN
# 65436                             Angular;Node.js;React
# 65437       Django;Express;jQuery;Next.js;Node.js;React
#
#                           WebframeWantToWorkWith  \
# ResponseId
# 1                                            NaN
# 2               Express;Htmx;Node.js;React;Remix
# 3                                   ASP.NET CORE
# 4                   jQuery;Next.js;Node.js;React
# 5                                            NaN
# ...                                          ...
# 65433                                        NaN
# 65434                                        NaN
# 65435                                        NaN
# 65436                                        NaN
# 65437       Django;Express;Next.js;Node.js;React
#
#                                  WebframeAdmired  \
# ResponseId
# 1                                            NaN
# 2                          Express;Node.js;React
# 3                                   ASP.NET CORE
# 4                   jQuery;Next.js;Node.js;React
# 5                                            NaN
# ...                                          ...
# 65433                                        NaN
# 65434                                        NaN
# 65435                                        NaN
# 65436                                        NaN
# 65437       Django;Express;Next.js;Node.js;React
#
#                              EmbeddedHaveWorkedWith  \
# ResponseId
# 1                                               NaN
# 2                                               NaN
# 3                                       Rasberry Pi
# 4                                       Rasberry Pi
# 5                           CMake;Cargo;Rasberry Pi
# ...                                             ...
# 65433                                           NaN
# 65434                                           NaN
# 65435                                           NaN
# 65436       Arduino;CMake;Cargo;GNU GCC;Rasberry Pi
# 65437                                           NaN
#
#                EmbeddedWantToWorkWith            EmbeddedAdmired  \
# ResponseId
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                         Rasberry Pi                Rasberry Pi
# 4                                 NaN                        NaN
# 5                   CMake;Rasberry Pi          CMake;Rasberry Pi
# ...                               ...                        ...
# 65433                             NaN                        NaN
# 65434                             NaN                        NaN
# 65435                             NaN                        NaN
# 65436       Cargo;GNU GCC;Rasberry Pi  Cargo;GNU GCC;Rasberry Pi
# 65437                             NaN                        NaN
#
#                                      MiscTechHaveWorkedWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                              NumPy;Pandas;Ruff;TensorFlow
# 5                                                       NaN
# ...                                                     ...
# 65433                                                   NaN
# 65434                                                   NaN
# 65435                                                   NaN
# 65436                                            GTK;OpenGL
# 65437                                                   NaN
#
#                                      MiscTechWantToWorkWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
# ...                                                     ...
# 65433                                                   NaN
# 65434                                                   NaN
# 65435                                                   NaN
# 65436                                                   NaN
# 65437                                                   NaN
#
#                                             MiscTechAdmired  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
# ...                                                     ...
# 65433                                                   NaN
# 65434                                                   NaN
# 65435                                                   NaN
# 65436                                                   NaN
# 65437                                                   NaN
#
#                                 ToolsTechHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                        Docker;npm;Pip
# 5                                          APT;Make;npm
# ...                                                 ...
# 65433                                               NaN
# 65434                                               NaN
# 65435                                               NaN
# 65436            Ansible;APT;Docker;Make;npm;Pip;Podman
# 65437                                      npm;Pip;Vite
#
#                                 ToolsTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                 Docker;Kubernetes;npm
# 5                                              APT;Make
# ...                                                 ...
# 65433                                               NaN
# 65434                                               NaN
# 65435                                               NaN
# 65436            Ansible;APT;Docker;Make;npm;Pip;Podman
# 65437                                      npm;Pip;Vite
#
#                                        ToolsTechAdmired  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                            Docker;npm
# 5                                              APT;Make
# ...                                                 ...
# 65433                                               NaN
# 65434                                               NaN
# 65435                                               NaN
# 65436            Ansible;APT;Docker;Make;npm;Pip;Podman
# 65437                                      npm;Pip;Vite
#
#                    NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
# ...                                         ...
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436                    Vim;Visual Studio Code
# 65437                        Visual Studio Code
#
#                    NEWCollabToolsWantToWorkWith  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
# ...                                         ...
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436                    Vim;Visual Studio Code
# 65437                        Visual Studio Code
#
#                           NEWCollabToolsAdmired  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
# ...                                         ...
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436                    Vim;Visual Studio Code
# 65437                        Visual Studio Code
#
#                                    OpSysPersonal use  \
# ResponseId
# 1                                                NaN
# 2                                      MacOS;Windows
# 3                                            Windows
# 4                                                NaN
# 5                            Other (please specify):
# ...                                              ...
# 65433                                            NaN
# 65434                                            NaN
# 65435                                            NaN
# 65436       Android;Other Linux-based;Ubuntu;Windows
# 65437                                        Windows
#
#                       OpSysProfessional use  \
# ResponseId
# 1                                       NaN
# 2                                     MacOS
# 3                                   Windows
# 4                                       NaN
# 5                                       NaN
# ...                                     ...
# 65433                                   NaN
# 65434                                   NaN
# 65435                                   NaN
# 65436       Fedora;Other Linux-based;Ubuntu
# 65437                         MacOS;Windows
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           GitHub Discussions;Markdown File;Obsidian;Stac...
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436           Confluence;Jira;Markdown File;Obsidian;Trello
# 65437                                                     NaN
#
#                        OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
# ...                                               ...
# 65433                                             NaN
# 65434                                             NaN
# 65435                                             NaN
# 65436            Confluence;Jira;Markdown File;Trello
# 65437                                             NaN
#
#                               OfficeStackAsyncAdmired  \
# ResponseId
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
# ...                                               ...
# 65433                                             NaN
# 65434                                             NaN
# 65435                                             NaN
# 65436            Confluence;Jira;Markdown File;Trello
# 65437                                             NaN
#
#                            OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 1                                                    NaN
# 2                                  Microsoft Teams;Slack
# 3           Google Chat;Google Meet;Microsoft Teams;Zoom
# 4                                                    NaN
# 5                                       Discord;Whatsapp
# ...                                                  ...
# 65433                                                NaN
# 65434                                                NaN
# 65435                                                NaN
# 65436             Discord;Jitsi;Microsoft Teams;Whatsapp
# 65437                                                NaN
#
#            OfficeStackSyncWantToWorkWith        OfficeStackSyncAdmired  \
# ResponseId
# 1                                    NaN                           NaN
# 2                                  Slack                         Slack
# 3           Google Chat;Google Meet;Zoom  Google Chat;Google Meet;Zoom
# 4                                    NaN                           NaN
# 5                       Discord;Whatsapp              Discord;Whatsapp
# ...                                  ...                           ...
# 65433                                NaN                           NaN
# 65434                                NaN                           NaN
# 65435                                NaN                           NaN
# 65436             Discord;Jitsi;Whatsapp        Discord;Jitsi;Whatsapp
# 65437                                NaN                           NaN
#
#            AISearchDevHaveWorkedWith AISearchDevWantToWorkWith  \
# ResponseId
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# 5                                NaN                       NaN
# ...                              ...                       ...
# 65433                            NaN                       NaN
# 65434                            NaN                       NaN
# 65435                            NaN                       NaN
# 65436                            NaN                       NaN
# 65437                            NaN                       NaN
#
#            AISearchDevAdmired  \
# ResponseId
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 65433                     NaN
# 65434                     NaN
# 65435                     NaN
# 65436                     NaN
# 65437                     NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 1           I have never visited Stack Overflow or the Sta...
# 2           Stack Overflow for Teams (private knowledge sh...
# 3           Stack Overflow;Stack Exchange;Stack Overflow B...
# 4                                              Stack Overflow
# 5           Stack Overflow for Teams (private knowledge sh...
# ...                                                       ...
# 65433                                                     NaN
# 65434                           Stack Overflow;Stack Exchange
# 65435                                                     NaN
# 65436                           Stack Overflow;Stack Exchange
# 65437                                          Stack Overflow
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                                       NaN       NaN
# 2                    Multiple times per day       Yes
# 3                    Multiple times per day       Yes
# 4                     Daily or almost daily        No
# 5                    Multiple times per day       Yes
# ...                                     ...       ...
# 65433                                   NaN       NaN
# 65434                                   NaN       NaN
# 65435                                   NaN       NaN
# 65436       A few times per month or weekly        No
# 65437                 Daily or almost daily       Yes
#
#                                      SOPartFreq  \
# ResponseId
# 1                                           NaN
# 2                        Multiple times per day
# 3                        Multiple times per day
# 4                                           NaN
# 5                        Multiple times per day
# ...                                         ...
# 65433                                       NaN
# 65434                                       NaN
# 65435                                       NaN
# 65436                                       NaN
# 65437       Less than once per month or monthly
#
#                                                         SOHow  \
# ResponseId
# 1                                                         NaN
# 2           Quickly finding code solutions;Finding reliabl...
# 3           Quickly finding code solutions;Finding reliabl...
# 4                              Quickly finding code solutions
# 5           Quickly finding code solutions;Engage with com...
# ...                                                       ...
# 65433                                                     NaN
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                          Quickly finding code solutions
# 65437                          Quickly finding code solutions
#
#                      SOComm                 AISelect          AISent  \
# ResponseId
# 1                       NaN                      Yes  Very favorable
# 2           Yes, definitely  No, and I don't plan to             NaN
# 3           Yes, definitely  No, and I don't plan to             NaN
# 4            No, not really                      Yes  Very favorable
# 5           Yes, definitely  No, and I don't plan to             NaN
# ...                     ...                      ...             ...
# 65433                   NaN                      Yes       Favorable
# 65434                   NaN                      NaN             NaN
# 65435                   NaN                      NaN             NaN
# 65436        No, not really  No, and I don't plan to             NaN
# 65437         Yes, somewhat                      NaN             NaN
#
#                                                         AIBen  \
# ResponseId
# 1                                       Increase productivity
# 2                                                         NaN
# 3                                                         NaN
# 4           Increase productivity;Greater efficiency;Impro...
# 5                                                         NaN
# ...                                                       ...
# 65433       Increase productivity;Greater efficiency;Speed...
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                     NaN
# 65437                                                     NaN
#
#                                  AIAcc  \
# ResponseId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                       Somewhat trust
# 5                                  NaN
# ...                                ...
# 65433       Neither trust nor distrust
# 65434                              NaN
# 65435                              NaN
# 65436                              NaN
# 65437                              NaN
#
#                                                 AIComplex  \
# ResponseId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                           Bad at handling complex tasks
# 5                                                     NaN
# ...                                                   ...
# 65433       Good, but not great at handling complex tasks
# 65434                                                 NaN
# 65435                                                 NaN
# 65436                                                 NaN
# 65437                                                 NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Learning about a codebase;Project planning;Wri...
# 5                                                         NaN
# ...                                                       ...
# 65433       Learning about a codebase;Project planning;Wri...
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                     NaN
# 65437                                                     NaN
#
#                                     AIToolInterested in Using  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Testing code;Committing and reviewing code;Pre...
# 5                                                         NaN
# ...                                                       ...
# 65433       Debugging and getting help;Testing code;Deploy...
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                     NaN
# 65437                                                     NaN
#
#             AIToolNot interested in Using  \
# ResponseId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# ...                                   ...
# 65433       Committing and reviewing code
# 65434                                 NaN
# 65435                                 NaN
# 65436                                 NaN
# 65437                                 NaN
#
#                                    AINextMuch more integrated AINextNo change  \
# ResponseId
# 1                                                         NaN             NaN
# 2                                                         NaN             NaN
# 3                                                         NaN             NaN
# 4           Learning about a codebase;Project planning;Wri...             NaN
# 5                                                         NaN             NaN
# ...                                                       ...             ...
# 65433       Writing code;Search for answers;Generating con...             NaN
# 65434                                                     NaN             NaN
# 65435                                                     NaN             NaN
# 65436                                                     NaN             NaN
# 65437                                                     NaN             NaN
#
#                                         AINextMore integrated  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 65433       Learning about a codebase;Project planning;Doc...
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                     NaN
# 65437                                                     NaN
#
#            AINextLess integrated AINextMuch less integrated AIThreat  \
# ResponseId
# 1                            NaN                        NaN      NaN
# 2                            NaN                        NaN      NaN
# 3                            NaN                        NaN      NaN
# 4                            NaN                        NaN       No
# 5                            NaN                        NaN      NaN
# ...                          ...                        ...      ...
# 65433                        NaN                        NaN       No
# 65434                        NaN                        NaN      NaN
# 65435                        NaN                        NaN      NaN
# 65436                        NaN                        NaN      NaN
# 65437                        NaN                        NaN      NaN
#
#                                                      AIEthics  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Circulating misinformation or disinformation;M...
# 5                                                         NaN
# ...                                                       ...
# 65433            Circulating misinformation or disinformation
# 65434                                                     NaN
# 65435                                                     NaN
# 65436                                                     NaN
# 65437                                                     NaN
#
#                                                  AIChallenges TBranch  \
# ResponseId
# 1                                                         NaN      No
# 2                                                         NaN     Yes
# 3                                                         NaN      No
# 4                           Don’t trust the output or answers     NaN
# 5                                                         NaN     NaN
# ...                                                       ...     ...
# 65433       AI tools lack context of codebase,  internal a...     NaN
# 65434                                                     NaN     NaN
# 65435                                                     NaN     NaN
# 65436                                                     NaN     Yes
# 65437                                                     NaN     NaN
#
#                             ICorPM  WorkExp Knowledge_1 Knowledge_2  \
# ResponseId
# 1                              NaN      NaN         NaN         NaN
# 2           Individual contributor     17.0       Agree    Disagree
# 3                              NaN      NaN         NaN         NaN
# 4                              NaN      NaN         NaN         NaN
# 5                              NaN      NaN         NaN         NaN
# ...                            ...      ...         ...         ...
# 65433                          NaN      NaN         NaN         NaN
# 65434                          NaN      NaN         NaN         NaN
# 65435                          NaN      NaN         NaN         NaN
# 65436       Individual contributor      5.0         NaN         NaN
# 65437                          NaN      NaN         NaN         NaN
#
#            Knowledge_3 Knowledge_4 Knowledge_5                 Knowledge_6  \
# ResponseId
# 1                  NaN         NaN         NaN                         NaN
# 2                Agree       Agree       Agree  Neither agree nor disagree
# 3                  NaN         NaN         NaN                         NaN
# 4                  NaN         NaN         NaN                         NaN
# 5                  NaN         NaN         NaN                         NaN
# ...                ...         ...         ...                         ...
# 65433              NaN         NaN         NaN                         NaN
# 65434              NaN         NaN         NaN                         NaN
# 65435              NaN         NaN         NaN                         NaN
# 65436              NaN         NaN         NaN                         NaN
# 65437              NaN         NaN         NaN                         NaN
#
#            Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1 Frequency_2  \
# ResponseId
# 1                  NaN         NaN         NaN         NaN         NaN
# 2             Disagree       Agree       Agree         NaN         NaN
# 3                  NaN         NaN         NaN         NaN         NaN
# 4                  NaN         NaN         NaN         NaN         NaN
# 5                  NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 65433              NaN         NaN         NaN         NaN         NaN
# 65434              NaN         NaN         NaN         NaN         NaN
# 65435              NaN         NaN         NaN         NaN         NaN
# 65436              NaN         NaN         NaN         NaN         NaN
# 65437              NaN         NaN         NaN         NaN         NaN
#
#            Frequency_3 TimeSearching TimeAnswering Frustration  \
# ResponseId
# 1                  NaN           NaN           NaN         NaN
# 2                  NaN           NaN           NaN         NaN
# 3                  NaN           NaN           NaN         NaN
# 4                  NaN           NaN           NaN         NaN
# 5                  NaN           NaN           NaN         NaN
# ...                ...           ...           ...         ...
# 65433              NaN           NaN           NaN         NaN
# 65434              NaN           NaN           NaN         NaN
# 65435              NaN           NaN           NaN         NaN
# 65436              NaN           NaN           NaN         NaN
# 65437              NaN           NaN           NaN         NaN
#
#            ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# ResponseId
# 1                       NaN               NaN                  NaN      NaN
# 2                       NaN               NaN                  NaN      NaN
# 3                       NaN               NaN                  NaN      NaN
# 4                       NaN               NaN                  NaN      NaN
# 5                       NaN               NaN                  NaN      NaN
# ...                     ...               ...                  ...      ...
# 65433                   NaN               NaN                  NaN      NaN
# 65434                   NaN               NaN                  NaN      NaN
# 65435                   NaN               NaN                  NaN      NaN
# 65436                   NaN               NaN                  NaN      NaN
# 65437                   NaN               NaN                  NaN      NaN
#
#             JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# ResponseId
# 1                      NaN             NaN             NaN             NaN
# 2                      0.0             0.0             0.0             0.0
# 3                      NaN             NaN             NaN             NaN
# 4                      NaN             NaN             NaN             NaN
# 5                      NaN             NaN             NaN             NaN
# ...                    ...             ...             ...             ...
# 65433                  NaN             NaN             NaN             NaN
# 65434                  NaN             NaN             NaN             NaN
# 65435                  NaN             NaN             NaN             NaN
# 65436                  0.0             0.0             0.0             0.0
# 65437                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# ResponseId
# 1                      NaN             NaN             NaN              NaN
# 2                      0.0             0.0             0.0              0.0
# 3                      NaN             NaN             NaN              NaN
# 4                      NaN             NaN             NaN              NaN
# 5                      NaN             NaN             NaN              NaN
# ...                    ...             ...             ...              ...
# 65433                  NaN             NaN             NaN              NaN
# 65434                  NaN             NaN             NaN              NaN
# 65435                  NaN             NaN             NaN              NaN
# 65436                  0.0             0.0             0.0              0.0
# 65437                  NaN             NaN             NaN              NaN
#
#             JobSatPoints_11           SurveyLength SurveyEase  \
# ResponseId
# 1                       NaN                    NaN        NaN
# 2                       0.0                    NaN        NaN
# 3                       NaN  Appropriate in length       Easy
# 4                       NaN               Too long       Easy
# 5                       NaN              Too short       Easy
# ...                     ...                    ...        ...
# 65433                   NaN                    NaN        NaN
# 65434                   NaN                    NaN        NaN
# 65435                   NaN                    NaN        NaN
# 65436                   0.0                    NaN        NaN
# 65437                   NaN                    NaN        NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                           NaN     NaN
# 2                           NaN     NaN
# 3                           NaN     NaN
# 4                           NaN     NaN
# 5                           NaN     NaN
# ...                         ...     ...
# 65433                       NaN     NaN
# 65434                       NaN     NaN
# 65435                       NaN     NaN
# 65436                       NaN     NaN
# 65437                       NaN     NaN
#
# [65437 rows x 113 columns]

# %%
df['Employment'] == "Student, full-time"
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4         True
# 5         True
#          ...
# 65433    False
# 65434    False
# 65435    False
# 65436    False
# 65437     True
# Name: Employment, Length: 65437, dtype: bool

# %%
filt = (df['Employment'] == "Student, full-time")     #creating a filter

# %%
df[filt]        #fetches all the columns for the filter
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# 6              I code primarily as a hobby  Under 18 years old
# 17             I code primarily as a hobby  Under 18 years old
# 31          I am a developer by profession   Prefer not to say
# ...                                    ...                 ...
# 65408          I code primarily as a hobby     18-24 years old
# 65414                I am learning to code     18-24 years old
# 65419          I code primarily as a hobby     18-24 years old
# 65421                I am learning to code  Under 18 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                     Employment RemoteWork   Check CodingActivities  \
# ResponseId
# 4           Student, full-time        NaN  Apples              NaN
# 5           Student, full-time        NaN  Apples              NaN
# 6           Student, full-time        NaN  Apples              NaN
# 17          Student, full-time        NaN  Apples              NaN
# 31          Student, full-time        NaN  Apples              NaN
# ...                        ...        ...     ...              ...
# 65408       Student, full-time        NaN  Apples              NaN
# 65414       Student, full-time        NaN  Apples              NaN
# 65419       Student, full-time        NaN  Apples              NaN
# 65421       Student, full-time        NaN  Apples              NaN
# 65437       Student, full-time        NaN  Apples              NaN
#
#                                                       EdLevel  \
# ResponseId
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
# 6                                   Primary/elementary school
# 17                                  Primary/elementary school
# 31                                             Something else
# ...                                                       ...
# 65408                                                     NaN
# 65414       Secondary school (e.g. American high school, G...
# 65419                                                     NaN
# 65421       Secondary school (e.g. American high school, G...
# 65437                                                     NaN
#
#                                                     LearnCode  \
# ResponseId
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
# 6           School (i.e., University, College, etc);Online...
# 17          Books / Physical media;Other online resources ...
# 31          Books / Physical media;School (i.e., Universit...
# ...                                                       ...
# 65408                                                     NaN
# 65414       Other online resources (e.g., videos, blogs, f...
# 65419                                                     NaN
# 65421       Other online resources (e.g., videos, blogs, f...
# 65437                                                     NaN
#
#                                               LearnCodeOnline  \
# ResponseId
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 5           Technical documentation;Blogs;Written Tutorial...
# 6                                                         NaN
# 17          Technical documentation;Written Tutorials;Stac...
# 31                                                        NaN
# ...                                                       ...
# 65408                                                     NaN
# 65414       Social Media;How-to videos;Video-based Online ...
# 65419                                                     NaN
# 65421       Coding sessions (live or recorded);Video-based...
# 65437                                                     NaN
#
#                                                       TechDoc  \
# ResponseId
# 4                                                         NaN
# 5           API document(s) and/or SDK document(s);User gu...
# 6                                                         NaN
# 17          API document(s) and/or SDK document(s);Traditi...
# 31                                                        NaN
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                    YearsCode YearsCodePro                DevType OrgSize  \
# ResponseId
# 4                          4          NaN  Developer, full-stack     NaN
# 5                          9          NaN  Developer, full-stack     NaN
# 6                         10          NaN                Student     NaN
# 17                         7          NaN                Student     NaN
# 31                         3            2    Developer, back-end     NaN
# ...                      ...          ...                    ...     ...
# 65408                    NaN          NaN                    NaN     NaN
# 65414                      3          NaN                Student     NaN
# 65419                    NaN          NaN                    NaN     NaN
# 65421       Less than 1 year          NaN                    NaN     NaN
# 65437                    NaN          NaN                    NaN     NaN
#
#            PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse  \
# ResponseId
# 4                        NaN        NaN        NaN         NaN
# 5                        NaN        NaN        NaN         NaN
# 6                        NaN        NaN        NaN         NaN
# 17                       NaN        NaN        NaN         NaN
# 31                       NaN        NaN        NaN         NaN
# ...                      ...        ...        ...         ...
# 65408                    NaN        NaN        NaN         NaN
# 65414                    NaN        NaN        NaN         NaN
# 65419                    NaN        NaN        NaN         NaN
# 65421                    NaN        NaN        NaN         NaN
# 65437                    NaN        NaN        NaN         NaN
#
#                              Country Currency  CompTotal  \
# ResponseId
# 4                             Canada      NaN        NaN
# 5                             Norway      NaN        NaN
# 6           United States of America      NaN        NaN
# 17                            Canada      NaN        NaN
# 31                         Australia      NaN        NaN
# ...                              ...      ...        ...
# 65408                            NaN      NaN        NaN
# 65414                          India      NaN        NaN
# 65419                            NaN      NaN        NaN
# 65421                            NaN      NaN        NaN
# 65437                            NaN      NaN        NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 4           C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                     C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 6           Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 17                                            Rust;TypeScript
# 31          Go;HTML/CSS;Java;JavaScript;Perl;Python;TypeSc...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437        C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
# 6           Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 17                                            Rust;TypeScript
# 31          Go;HTML/CSS;JavaScript;Julia;PHP;Python;TypeSc...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                            JavaScript;Python;TypeScript
#
#                                               LanguageAdmired  \
# ResponseId
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
# 6           Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 17                                            Rust;TypeScript
# 31                   Go;HTML/CSS;JavaScript;Python;TypeScript
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                            JavaScript;Python;TypeScript
#
#                                  DatabaseHaveWorkedWith  \
# ResponseId
# 4                       MongoDB;MySQL;PostgreSQL;SQLite
# 5                                     PostgreSQL;SQLite
# 6                                       Cloud Firestore
# 17                                                  NaN
# 31          Firebase Realtime Database;Microsoft Access
# ...                                                 ...
# 65408                                               NaN
# 65414                                               NaN
# 65419                                               NaN
# 65421                                               NaN
# 65437                   MongoDB;MySQL;Oracle;PostgreSQL
#
#                                  DatabaseWantToWorkWith  \
# ResponseId
# 4                              MongoDB;MySQL;PostgreSQL
# 5                                     PostgreSQL;SQLite
# 6                                       Cloud Firestore
# 17                                                  NaN
# 31          Firebase Realtime Database;Microsoft Access
# ...                                                 ...
# 65408                                               NaN
# 65414                                               NaN
# 65419                                               NaN
# 65421                                               NaN
# 65437                          MongoDB;MySQL;PostgreSQL
#
#                                         DatabaseAdmired  \
# ResponseId
# 4                              MongoDB;MySQL;PostgreSQL
# 5                                     PostgreSQL;SQLite
# 6                                       Cloud Firestore
# 17                                                  NaN
# 31          Firebase Realtime Database;Microsoft Access
# ...                                                 ...
# 65408                                               NaN
# 65414                                               NaN
# 65419                                               NaN
# 65421                                               NaN
# 65437                          MongoDB;MySQL;PostgreSQL
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 4                     Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                         NaN
# 6                                                  Cloudflare
# 17                                                        NaN
# 31                                  Amazon Web Services (AWS)
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437       Amazon Web Services (AWS);Cloudflare;Google Cl...
#
#                                      PlatformWantToWorkWith  \
# ResponseId
# 4                          Amazon Web Services (AWS);Vercel
# 5                                                       NaN
# 6                                                Cloudflare
# 17                                                      NaN
# 31          Amazon Web Services (AWS);Firebase;Google Cloud
# ...                                                     ...
# 65408                                                   NaN
# 65414                                                   NaN
# 65419                                                   NaN
# 65421                                                   NaN
# 65437                Cloudflare;Google Cloud;Netlify;Vercel
#
#                                    PlatformAdmired  \
# ResponseId
# 4                        Amazon Web Services (AWS)
# 5                                              NaN
# 6                                       Cloudflare
# 17                                             NaN
# 31                       Amazon Web Services (AWS)
# ...                                            ...
# 65408                                          NaN
# 65414                                          NaN
# 65419                                          NaN
# 65421                                          NaN
# 65437       Cloudflare;Google Cloud;Netlify;Vercel
#
#                                  WebframeHaveWorkedWith  \
# ResponseId
# 4                jQuery;Next.js;Node.js;React;WordPress
# 5                                                   NaN
# 6                                               Node.js
# 17                                              Node.js
# 31                   Angular;Django;Flask;Node.js;React
# ...                                                 ...
# 65408                                               NaN
# 65414                                               NaN
# 65419                                               NaN
# 65421                                               NaN
# 65437       Django;Express;jQuery;Next.js;Node.js;React
#
#                           WebframeWantToWorkWith  \
# ResponseId
# 4                   jQuery;Next.js;Node.js;React
# 5                                            NaN
# 6                                        Node.js
# 17                                 Deno;Solid.js
# 31          Angular;Django;Flask;Next.js;Node.js
# ...                                          ...
# 65408                                        NaN
# 65414                                        NaN
# 65419                                        NaN
# 65421                                        NaN
# 65437       Django;Express;Next.js;Node.js;React
#
#                                  WebframeAdmired   EmbeddedHaveWorkedWith  \
# ResponseId
# 4                   jQuery;Next.js;Node.js;React              Rasberry Pi
# 5                                            NaN  CMake;Cargo;Rasberry Pi
# 6                                        Node.js              Rasberry Pi
# 17                                           NaN                      NaN
# 31                  Angular;Django;Flask;Node.js      Arduino;Rasberry Pi
# ...                                          ...                      ...
# 65408                                        NaN                      NaN
# 65414                                        NaN                      NaN
# 65419                                        NaN                      NaN
# 65421                                        NaN                      NaN
# 65437       Django;Express;Next.js;Node.js;React                      NaN
#
#            EmbeddedWantToWorkWith      EmbeddedAdmired  \
# ResponseId
# 4                             NaN                  NaN
# 5               CMake;Rasberry Pi    CMake;Rasberry Pi
# 6                     Rasberry Pi          Rasberry Pi
# 17                            NaN                  NaN
# 31            Arduino;Rasberry Pi  Arduino;Rasberry Pi
# ...                           ...                  ...
# 65408                         NaN                  NaN
# 65414                         NaN                  NaN
# 65419                         NaN                  NaN
# 65421                         NaN                  NaN
# 65437                         NaN                  NaN
#
#                                        MiscTechHaveWorkedWith  \
# ResponseId
# 4                                NumPy;Pandas;Ruff;TensorFlow
# 5                                                         NaN
# 6                                                         NaN
# 17                                                        NaN
# 31          Cordova;Keras;NumPy;Pandas;React Native;Scikit...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 17                                                        NaN
# 31          Cordova;Keras;NumPy;Pandas;React Native;Scikit...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                                               MiscTechAdmired  \
# ResponseId
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 17                                                        NaN
# 31          Cordova;Keras;NumPy;Pandas;React Native;Scikit...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                       ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# ResponseId
# 4                              Docker;npm;Pip   Docker;Kubernetes;npm
# 5                                APT;Make;npm                APT;Make
# 6                Docker;Homebrew;npm;Pip;pnpm   Homebrew;npm;Pip;pnpm
# 17                                   npm;Vite                    Vite
# 31          Chocolatey;Visual Studio Solution  Visual Studio Solution
# ...                                       ...                     ...
# 65408                                     NaN                     NaN
# 65414                                     NaN                     NaN
# 65419                                     NaN                     NaN
# 65421                                     NaN                     NaN
# 65437                            npm;Pip;Vite            npm;Pip;Vite
#
#                   ToolsTechAdmired  \
# ResponseId
# 4                       Docker;npm
# 5                         APT;Make
# 6            Homebrew;npm;Pip;pnpm
# 17                            Vite
# 31          Visual Studio Solution
# ...                            ...
# 65408                          NaN
# 65414                          NaN
# 65419                          NaN
# 65421                          NaN
# 65437                 npm;Pip;Vite
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 4                                                         NaN
# 5                                                         Vim
# 6                           Nano;Vim;Visual Studio Code;Xcode
# 17                                         Visual Studio Code
# 31          Jupyter Notebook/JupyterLab;Sublime Text;Visua...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                      Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith  \
# ResponseId
# 4                                                         NaN
# 5                                                         Vim
# 6                           Nano;Vim;Visual Studio Code;Xcode
# 17                                         Visual Studio Code
# 31          Jupyter Notebook/JupyterLab;Sublime Text;Vim;V...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                      Visual Studio Code
#
#                                         NEWCollabToolsAdmired  \
# ResponseId
# 4                                                         NaN
# 5                                                         Vim
# 6                           Nano;Vim;Visual Studio Code;Xcode
# 17                                         Visual Studio Code
# 31          Jupyter Notebook/JupyterLab;Sublime Text;Visua...
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                      Visual Studio Code
#
#                   OpSysPersonal use OpSysProfessional use  \
# ResponseId
# 4                               NaN                   NaN
# 5           Other (please specify):                   NaN
# 6                  iOS;MacOS;Ubuntu                   NaN
# 17                             Arch                   NaN
# 31                   Ubuntu;Windows                 MacOS
# ...                             ...                   ...
# 65408                           NaN                   NaN
# 65414                           NaN                   NaN
# 65419                           NaN                   NaN
# 65421                           NaN                   NaN
# 65437                       Windows         MacOS;Windows
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 4                                                         NaN
# 5           GitHub Discussions;Markdown File;Obsidian;Stac...
# 6                                               Markdown File
# 17                                                        NaN
# 31                                              Markdown File
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                        OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
# 6                                       Markdown File
# 17                                                NaN
# 31                                      Markdown File
# ...                                               ...
# 65408                                             NaN
# 65414                                             NaN
# 65419                                             NaN
# 65421                                             NaN
# 65437                                             NaN
#
#                               OfficeStackAsyncAdmired  \
# ResponseId
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
# 6                                       Markdown File
# 17                                                NaN
# 31                                      Markdown File
# ...                                               ...
# 65408                                             NaN
# 65414                                             NaN
# 65419                                             NaN
# 65421                                             NaN
# 65437                                             NaN
#
#               OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# ResponseId
# 4                                       NaN                           NaN
# 5                          Discord;Whatsapp              Discord;Whatsapp
# 6                                   Discord                       Discord
# 17                                  Discord                       Discord
# 31          Discord;Google Chat;Google Meet                       Discord
# ...                                     ...                           ...
# 65408                                   NaN                           NaN
# 65414                                   NaN                           NaN
# 65419                                   NaN                           NaN
# 65421                                   NaN                           NaN
# 65437                                   NaN                           NaN
#
#            OfficeStackSyncAdmired  \
# ResponseId
# 4                             NaN
# 5                Discord;Whatsapp
# 6                         Discord
# 17                        Discord
# 31                        Discord
# ...                           ...
# 65408                         NaN
# 65414                         NaN
# 65419                         NaN
# 65421                         NaN
# 65437                         NaN
#
#                                    AISearchDevHaveWorkedWith  \
# ResponseId
# 4                                                        NaN
# 5                                                        NaN
# 6                        ChatGPT;GitHub Copilot;OpenAI Codex
# 17          ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 31                                                   ChatGPT
# ...                                                      ...
# 65408                                                    NaN
# 65414                                                    NaN
# 65419                                                    NaN
# 65421                                                    NaN
# 65437                                                    NaN
#
#                                    AISearchDevWantToWorkWith  \
# ResponseId
# 4                                                        NaN
# 5                                                        NaN
# 6                                     ChatGPT;GitHub Copilot
# 17          ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 31                                                   ChatGPT
# ...                                                      ...
# 65408                                                    NaN
# 65414                                                    NaN
# 65419                                                    NaN
# 65421                                                    NaN
# 65437                                                    NaN
#
#                                           AISearchDevAdmired  \
# ResponseId
# 4                                                        NaN
# 5                                                        NaN
# 6                                     ChatGPT;GitHub Copilot
# 17          ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 31                                                   ChatGPT
# ...                                                      ...
# 65408                                                    NaN
# 65414                                                    NaN
# 65419                                                    NaN
# 65421                                                    NaN
# 65437                                                    NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 4                                              Stack Overflow
# 5           Stack Overflow for Teams (private knowledge sh...
# 6                               Stack Overflow;Stack Exchange
# 17                                             Stack Overflow
# 31                              Stack Overflow;Stack Exchange
# ...                                                       ...
# 65408                                                     NaN
# 65414                           Stack Overflow;Stack Exchange
# 65419       Stack Overflow;Stack Exchange;Stack Overflow B...
# 65421                                                     NaN
# 65437                                          Stack Overflow
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 4                     Daily or almost daily        No
# 5                    Multiple times per day       Yes
# 6                    Multiple times per day       Yes
# 17                     A few times per week       Yes
# 31                                      NaN       Yes
# ...                                     ...       ...
# 65408                                   NaN       NaN
# 65414       A few times per month or weekly        No
# 65419                  A few times per week        No
# 65421                                   NaN       NaN
# 65437                 Daily or almost daily       Yes
#
#                                      SOPartFreq  \
# ResponseId
# 4                                           NaN
# 5                        Multiple times per day
# 6                        Multiple times per day
# 17          Less than once per month or monthly
# 31                         A few times per week
# ...                                         ...
# 65408                                       NaN
# 65414                                       NaN
# 65419                                       NaN
# 65421                                       NaN
# 65437       Less than once per month or monthly
#
#                                                         SOHow  \
# ResponseId
# 4                              Quickly finding code solutions
# 5           Quickly finding code solutions;Engage with com...
# 6           Quickly finding code solutions;Finding reliabl...
# 17          Quickly finding code solutions;Learning new-to...
# 31          Quickly finding code solutions;Showcase expert...
# ...                                                       ...
# 65408                                                     NaN
# 65414                          Quickly finding code solutions
# 65419       Quickly finding code solutions;Finding reliabl...
# 65421                                                     NaN
# 65437                          Quickly finding code solutions
#
#                      SOComm                 AISelect          AISent  \
# ResponseId
# 4            No, not really                      Yes  Very favorable
# 5           Yes, definitely  No, and I don't plan to             NaN
# 6           Yes, definitely                      Yes       Favorable
# 17           No, not really                      Yes       Favorable
# 31          Yes, definitely                      Yes     Indifferent
# ...                     ...                      ...             ...
# 65408                   NaN  No, and I don't plan to             NaN
# 65414        No, not at all                      Yes          Unsure
# 65419        No, not really                      NaN             NaN
# 65421                   NaN                      Yes       Favorable
# 65437         Yes, somewhat                      NaN             NaN
#
#                                                         AIBen  \
# ResponseId
# 4           Increase productivity;Greater efficiency;Impro...
# 5                                                         NaN
# 6           Increase productivity;Greater efficiency;Impro...
# 17                   Increase productivity;Greater efficiency
# 31            Speed up learning;Make workload more manageable
# ...                                                       ...
# 65408                                                     NaN
# 65414       Increase productivity;Speed up learning;Make w...
# 65419                                                     NaN
# 65421       Increase productivity;Greater efficiency;Speed...
# 65437                                                     NaN
#
#                         AIAcc                                      AIComplex  \
# ResponseId
# 4              Somewhat trust                  Bad at handling complex tasks
# 5                         NaN                                            NaN
# 6              Somewhat trust  Good, but not great at handling complex tasks
# 17          Somewhat distrust  Neither good or bad at handling complex tasks
# 31          Somewhat distrust  Neither good or bad at handling complex tasks
# ...                       ...                                            ...
# 65408                     NaN                                            NaN
# 65414          Somewhat trust                  Bad at handling complex tasks
# 65419                     NaN                                            NaN
# 65421            Highly trust  Good, but not great at handling complex tasks
# 65437                     NaN                                            NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 4           Learning about a codebase;Project planning;Wri...
# 5                                                         NaN
# 6                     Writing code;Debugging and getting help
# 17                                  Writing code;Testing code
# 31              Debugging and getting help;Search for answers
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421       Learning about a codebase;Project planning;Wri...
# 65437                                                     NaN
#
#                                     AIToolInterested in Using  \
# ResponseId
# 4           Testing code;Committing and reviewing code;Pre...
# 5                                                         NaN
# 6           Documenting code;Testing code;Committing and r...
# 17          Learning about a codebase;Documenting code;Sea...
# 31                                  Learning about a codebase
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421       Documenting code;Testing code;Committing and r...
# 65437                                                     NaN
#
#                                 AIToolNot interested in Using  \
# ResponseId
# 4                                                         NaN
# 5                                                         NaN
# 6                  Learning about a codebase;Project planning
# 17          Project planning;Debugging and getting help;Co...
# 31                                                        NaN
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                                    AINextMuch more integrated  \
# ResponseId
# 4           Learning about a codebase;Project planning;Wri...
# 5                                                         NaN
# 6                                                         NaN
# 17                                                        NaN
# 31                                                        NaN
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421                                                     NaN
# 65437                                                     NaN
#
#                                     AINextNo change  \
# ResponseId
# 4                                               NaN
# 5                                               NaN
# 6           Writing code;Debugging and getting help
# 17                                              NaN
# 31                                              NaN
# ...                                             ...
# 65408                                           NaN
# 65414                                           NaN
# 65419                                           NaN
# 65421                                           NaN
# 65437                                           NaN
#
#                                         AINextMore integrated  \
# ResponseId
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 17                                  Writing code;Testing code
# 31                                                        NaN
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421       Learning about a codebase;Project planning;Wri...
# 65437                                                     NaN
#
#                                     AINextLess integrated  \
# ResponseId
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 17                                                    NaN
# 31          Debugging and getting help;Search for answers
# ...                                                   ...
# 65408                                                 NaN
# 65414                                                 NaN
# 65419                                                 NaN
# 65421                                                 NaN
# 65437                                                 NaN
#
#            AINextMuch less integrated      AIThreat  \
# ResponseId
# 4                                 NaN            No
# 5                                 NaN           NaN
# 6                                 NaN            No
# 17                                NaN            No
# 31                                NaN            No
# ...                               ...           ...
# 65408                             NaN           NaN
# 65414                             NaN           NaN
# 65419                             NaN           NaN
# 65421                             NaN  I'm not sure
# 65437                             NaN           NaN
#
#                                                      AIEthics  \
# ResponseId
# 4           Circulating misinformation or disinformation;M...
# 5                                                         NaN
# 6           Circulating misinformation or disinformation;M...
# 17          Circulating misinformation or disinformation;M...
# 31                Imitating a person's likeness;Energy demand
# ...                                                       ...
# 65408                                                     NaN
# 65414                                                     NaN
# 65419                                                     NaN
# 65421       Circulating misinformation or disinformation;E...
# 65437                                                     NaN
#
#                                                  AIChallenges TBranch ICorPM  \
# ResponseId
# 4                           Don’t trust the output or answers     NaN    NaN
# 5                                                         NaN     NaN    NaN
# 6                                                         NaN     NaN    NaN
# 17                                                        NaN     NaN    NaN
# 31          AI tools lack context of codebase,  internal a...     NaN    NaN
# ...                                                       ...     ...    ...
# 65408                                                     NaN     NaN    NaN
# 65414                                                     NaN     NaN    NaN
# 65419                                                     NaN     NaN    NaN
# 65421       Lack of proper training and education on new t...     NaN    NaN
# 65437                                                     NaN     NaN    NaN
#
#             WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 4               NaN         NaN         NaN         NaN         NaN
# 5               NaN         NaN         NaN         NaN         NaN
# 6               NaN         NaN         NaN         NaN         NaN
# 17              NaN         NaN         NaN         NaN         NaN
# 31              NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 65408           NaN         NaN         NaN         NaN         NaN
# 65414           NaN         NaN         NaN         NaN         NaN
# 65419           NaN         NaN         NaN         NaN         NaN
# 65421           NaN         NaN         NaN         NaN         NaN
# 65437           NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5 Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9  \
# ResponseId
# 4                  NaN         NaN         NaN         NaN         NaN
# 5                  NaN         NaN         NaN         NaN         NaN
# 6                  NaN         NaN         NaN         NaN         NaN
# 17                 NaN         NaN         NaN         NaN         NaN
# 31                 NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 65408              NaN         NaN         NaN         NaN         NaN
# 65414              NaN         NaN         NaN         NaN         NaN
# 65419              NaN         NaN         NaN         NaN         NaN
# 65421              NaN         NaN         NaN         NaN         NaN
# 65437              NaN         NaN         NaN         NaN         NaN
#
#            Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering  \
# ResponseId
# 4                  NaN         NaN         NaN           NaN           NaN
# 5                  NaN         NaN         NaN           NaN           NaN
# 6                  NaN         NaN         NaN           NaN           NaN
# 17                 NaN         NaN         NaN           NaN           NaN
# 31                 NaN         NaN         NaN           NaN           NaN
# ...                ...         ...         ...           ...           ...
# 65408              NaN         NaN         NaN           NaN           NaN
# 65414              NaN         NaN         NaN           NaN           NaN
# 65419              NaN         NaN         NaN           NaN           NaN
# 65421              NaN         NaN         NaN           NaN           NaN
# 65437              NaN         NaN         NaN           NaN           NaN
#
#            Frustration ProfessionalTech ProfessionalCloud  \
# ResponseId
# 4                  NaN              NaN               NaN
# 5                  NaN              NaN               NaN
# 6                  NaN              NaN               NaN
# 17                 NaN              NaN               NaN
# 31                 NaN              NaN               NaN
# ...                ...              ...               ...
# 65408              NaN              NaN               NaN
# 65414              NaN              NaN               NaN
# 65419              NaN              NaN               NaN
# 65421              NaN              NaN               NaN
# 65437              NaN              NaN               NaN
#
#            ProfessionalQuestion Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 4                           NaN      NaN             NaN             NaN
# 5                           NaN      NaN             NaN             NaN
# 6                           NaN      NaN             NaN             NaN
# 17                          NaN      NaN             NaN             NaN
# 31                          NaN      NaN             NaN             NaN
# ...                         ...      ...             ...             ...
# 65408                       NaN      NaN             NaN             NaN
# 65414                       NaN      NaN             NaN             NaN
# 65419                       NaN      NaN             NaN             NaN
# 65421                       NaN      NaN             NaN             NaN
# 65437                       NaN      NaN             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 4                      NaN             NaN             NaN             NaN
# 5                      NaN             NaN             NaN             NaN
# 6                      NaN             NaN             NaN             NaN
# 17                     NaN             NaN             NaN             NaN
# 31                     NaN             NaN             NaN             NaN
# ...                    ...             ...             ...             ...
# 65408                  NaN             NaN             NaN             NaN
# 65414                  NaN             NaN             NaN             NaN
# 65419                  NaN             NaN             NaN             NaN
# 65421                  NaN             NaN             NaN             NaN
# 65437                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# ResponseId
# 4                      NaN              NaN              NaN
# 5                      NaN              NaN              NaN
# 6                      NaN              NaN              NaN
# 17                     NaN              NaN              NaN
# 31                     NaN              NaN              NaN
# ...                    ...              ...              ...
# 65408                  NaN              NaN              NaN
# 65414                  NaN              NaN              NaN
# 65419                  NaN              NaN              NaN
# 65421                  NaN              NaN              NaN
# 65437                  NaN              NaN              NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 4                        Too long                        Easy
# 5                       Too short                        Easy
# 6           Appropriate in length                        Easy
# 17          Appropriate in length                        Easy
# 31          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 65408                         NaN                         NaN
# 65414                         NaN                         NaN
# 65419                         NaN                         NaN
# 65421                         NaN                         NaN
# 65437                         NaN                         NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 4                           NaN     NaN
# 5                           NaN     NaN
# 6                           NaN     NaN
# 17                          NaN     NaN
# 31                          NaN     NaN
# ...                         ...     ...
# 65408                       NaN     NaN
# 65414                       NaN     NaN
# 65419                       NaN     NaN
# 65421                       NaN     NaN
# 65437                       NaN     NaN
#
# [4709 rows x 113 columns]

# %%
df.loc[filt, ['Age', 'Employment']]    #fetching only specific columns from the filter result
# Out:
#                            Age          Employment
# ResponseId
# 4              18-24 years old  Student, full-time
# 5              18-24 years old  Student, full-time
# 6           Under 18 years old  Student, full-time
# 17          Under 18 years old  Student, full-time
# 31           Prefer not to say  Student, full-time
# ...                        ...                 ...
# 65408          18-24 years old  Student, full-time
# 65414          18-24 years old  Student, full-time
# 65419          18-24 years old  Student, full-time
# 65421       Under 18 years old  Student, full-time
# 65437          18-24 years old  Student, full-time
#
# [4709 rows x 2 columns]

# %%
df["YearsCode"] = pd.to_numeric(df["YearsCode"], errors="coerce")              #YearsCode column is in string, hence converting it into numeric first
filt2 = (df['Employment'] == 'Student, full-time') & (df['YearsCode'] > 5)     #Filter with two condotions
df.loc[filt2, ['Employment', 'CodingActivities', 'YearsCode']]                   #Displaying the specifies columns of the filter
# Out:
#                     Employment CodingActivities  YearsCode
# ResponseId
# 5           Student, full-time              NaN        9.0
# 6           Student, full-time              NaN       10.0
# 17          Student, full-time              NaN        7.0
# 51          Student, full-time              NaN        6.0
# 66          Student, full-time              NaN        6.0
# ...                        ...              ...        ...
# 64663       Student, full-time              NaN        6.0
# 64691       Student, full-time              NaN        6.0
# 64871       Student, full-time              NaN        8.0
# 65022       Student, full-time              NaN        8.0
# 65278       Student, full-time              NaN        6.0
#
# [1608 rows x 3 columns]

# %%
df.loc[~filt2, ['Employment', 'CodingActivities', 'YearsCode']]        #Everything that is not part of the above filter
# Out:
#                      Employment  \
# ResponseId
# 1           Employed, full-time
# 2           Employed, full-time
# 3           Employed, full-time
# 4            Student, full-time
# 6            Student, full-time
# ...                         ...
# 65433       Employed, full-time
# 65434       Employed, full-time
# 65435       Employed, full-time
# 65436       Employed, full-time
# 65437        Student, full-time
#
#                                              CodingActivities YearsCode
# ResponseId
# 1                                                       Hobby       NaN
# 2           Hobby;Contribute to open-source projects;Other...        20
# 3           Hobby;Contribute to open-source projects;Other...        37
# 4                                                         NaN         4
# 6                                                         NaN        10
# ...                                                       ...       ...
# 65433                           Hobby;School or academic work         5
# 65434                Hobby;Contribute to open-source projects       NaN
# 65435                                                   Hobby         9
# 65436       Hobby;Contribute to open-source projects;Profe...         5
# 65437                                                     NaN       NaN
#
# [63556 rows x 3 columns]

# %%
countries = ['United States', 'India', 'United Kingdom', 'Canada']      #made a list of countries
filt3 = df['Country'].isin(countries)                                   #Passing the list in filter

# %%
df.loc[filt3]
# Out:
#                                                    MainBranch  \
# ResponseId
# 4                                       I am learning to code
# 17                                I code primarily as a hobby
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# ...                                                       ...
# 65340       I am not primarily a developer, but I write co...
# 65384                                   I am learning to code
# 65414                                   I am learning to code
# 65416                             I code primarily as a hobby
# 65429                          I am a developer by profession
#
#                            Age  \
# ResponseId
# 4              18-24 years old
# 17          Under 18 years old
# 18             18-24 years old
# 59             18-24 years old
# 76             25-34 years old
# ...                        ...
# 65340          18-24 years old
# 65384          18-24 years old
# 65414          18-24 years old
# 65416          35-44 years old
# 65429          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 4                                          Student, full-time        NaN
# 17                                         Student, full-time        NaN
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# ...                                                       ...        ...
# 65340                                      Student, full-time        NaN
# 65384                      Not employed, but looking for work        NaN
# 65414                                      Student, full-time        NaN
# 65416                                     I prefer not to say        NaN
# 65429                                     Employed, full-time     Remote
#
#              Check                                   CodingActivities  \
# ResponseId
# 4           Apples                                                NaN
# 17          Apples                                                NaN
# 18          Apples  Hobby;Professional development or self-paced l...
# 59          Apples                                                NaN
# 76          Apples                                                NaN
# ...            ...                                                ...
# 65340       Apples                                                NaN
# 65384       Apples                                                NaN
# 65414       Apples                                                NaN
# 65416       Apples                                                NaN
# 65429       Apples  Hobby;Contribute to open-source projects;Profe...
#
#                                                       EdLevel  \
# ResponseId
# 4           Some college/university study without earning ...
# 17                                  Primary/elementary school
# 18               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59          Some college/university study without earning ...
# 76          Some college/university study without earning ...
# ...                                                       ...
# 65340            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65384       Some college/university study without earning ...
# 65414       Secondary school (e.g. American high school, G...
# 65416            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65429            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 4           Other online resources (e.g., videos, blogs, f...
# 17          Books / Physical media;Other online resources ...
# 18          Other online resources (e.g., videos, blogs, f...
# 59          Other online resources (e.g., videos, blogs, f...
# 76            Online Courses or Certification;Coding Bootcamp
# ...                                                       ...
# 65340       Other online resources (e.g., videos, blogs, f...
# 65384                 School (i.e., University, College, etc)
# 65414       Other online resources (e.g., videos, blogs, f...
# 65416       Other online resources (e.g., videos, blogs, f...
# 65429       Books / Physical media;Colleague;Other online ...
#
#                                               LearnCodeOnline  \
# ResponseId
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 17          Technical documentation;Written Tutorials;Stac...
# 18          Blogs;Coding sessions (live or recorded);How-t...
# 59          Stack Overflow;Coding sessions (live or record...
# 76                                                        NaN
# ...                                                       ...
# 65340       Technical documentation;Social Media;How-to vi...
# 65384                                                     NaN
# 65414       Social Media;How-to videos;Video-based Online ...
# 65416       Blogs;Stack Overflow;Social Media;Video-based ...
# 65429       Technical documentation;Books;Interactive tuto...
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 4                                                         NaN         4
# 17          API document(s) and/or SDK document(s);Traditi...         7
# 18                                                        NaN         6
# 59                                                        NaN         4
# 76                                                        NaN         4
# ...                                                       ...       ...
# 65340                  API document(s) and/or SDK document(s)         4
# 65384                                                     NaN         9
# 65414                                                     NaN         3
# 65416                                                     NaN         4
# 65429       API document(s) and/or SDK document(s);User gu...         4
#
#            YearsCodePro                DevType                   OrgSize  \
# ResponseId
# 4                   NaN  Developer, full-stack                       NaN
# 17                  NaN                Student                       NaN
# 18                    3   Developer, front-end                       NaN
# 59                  NaN                Student                       NaN
# 76                  NaN               Designer                       NaN
# ...                 ...                    ...                       ...
# 65340                 2      Developer, mobile                       NaN
# 65384               NaN                Student                       NaN
# 65414               NaN                Student                       NaN
# 65416               NaN   System administrator                       NaN
# 65429                 7    Developer, back-end  1,000 to 4,999 employees
#
#                 PurchaseInfluence  \
# ResponseId
# 4                             NaN
# 17                            NaN
# 18                            NaN
# 59                            NaN
# 76                            NaN
# ...                           ...
# 65340                         NaN
# 65384                         NaN
# 65414                         NaN
# 65416                         NaN
# 65429       I have some influence
#
#                                                    BuyNewTool BuildvsBuy  \
# ResponseId
# 4                                                         NaN        NaN
# 17                                                        NaN        NaN
# 18                                                        NaN        NaN
# 59                                                        NaN        NaN
# 76                                                        NaN        NaN
# ...                                                       ...        ...
# 65340                                                     NaN        NaN
# 65384                                                     NaN        NaN
# 65414                                                     NaN        NaN
# 65416                                                     NaN        NaN
# 65429       Start a free trial;Ask developers I know/work ...        NaN
#
#                                                   TechEndorse Country  \
# ResponseId
# 4                                                         NaN  Canada
# 17                                                        NaN  Canada
# 18                                                        NaN   India
# 59                                                        NaN   India
# 76                                                        NaN   India
# ...                                                       ...     ...
# 65340                                                     NaN   India
# 65384                                                     NaN   India
# 65414                                                     NaN   India
# 65416                                                     NaN   India
# 65429       Integrated developer community;Frequent update...   India
#
#                      Currency  CompTotal  \
# ResponseId
# 4                         NaN        NaN
# 17                        NaN        NaN
# 18                        NaN        NaN
# 59                        NaN        NaN
# 76                        NaN        NaN
# ...                       ...        ...
# 65340                     NaN        NaN
# 65384                     NaN        NaN
# 65414                     NaN        NaN
# 65416                     NaN        NaN
# 65429       INR\tIndian rupee        NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 4           C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 17                                            Rust;TypeScript
# 18                             HTML/CSS;JavaScript;TypeScript
# 59                       C;C++;HTML/CSS;JavaScript;Python;SQL
# 76                                        HTML/CSS;JavaScript
# ...                                                       ...
# 65340       C;C#;C++;Go;HTML/CSS;JavaScript;Objective-C;Py...
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 17                                            Rust;TypeScript
# 18                             HTML/CSS;JavaScript;TypeScript
# 59                                        C++;HTML/CSS;Python
# 76                                          Dart;Kotlin;Swift
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                               LanguageAdmired  \
# ResponseId
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 17                                            Rust;TypeScript
# 18                             HTML/CSS;JavaScript;TypeScript
# 59                                        C++;HTML/CSS;Python
# 76                                                        NaN
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 4                             MongoDB;MySQL;PostgreSQL;SQLite
# 17                                                        NaN
# 18                                                        NaN
# 59                                                     SQLite
# 76                                                    MongoDB
# ...                                                       ...
# 65340       Cassandra;Firebase Realtime Database;MariaDB;M...
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#               DatabaseWantToWorkWith           DatabaseAdmired  \
# ResponseId
# 4           MongoDB;MySQL;PostgreSQL  MongoDB;MySQL;PostgreSQL
# 17                               NaN                       NaN
# 18                               NaN                       NaN
# 59                               NaN                       NaN
# 76                               NaN                       NaN
# ...                              ...                       ...
# 65340                            NaN                       NaN
# 65384                            NaN                       NaN
# 65414                            NaN                       NaN
# 65416                            NaN                       NaN
# 65429                            NaN                       NaN
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 4                     Amazon Web Services (AWS);Fly.io;Heroku
# 17                                                        NaN
# 18          Amazon Web Services (AWS);Digital Ocean;Fireba...
# 59                                                        NaN
# 76                                     Firebase;Heroku;VMware
# ...                                                       ...
# 65340       Amazon Web Services (AWS);Cloudflare;Firebase;...
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                       PlatformWantToWorkWith            PlatformAdmired  \
# ResponseId
# 4           Amazon Web Services (AWS);Vercel  Amazon Web Services (AWS)
# 17                                       NaN                        NaN
# 18                                       NaN                        NaN
# 59                                       NaN                        NaN
# 76                             Digital Ocean                        NaN
# ...                                      ...                        ...
# 65340                                    NaN                        NaN
# 65384                                    NaN                        NaN
# 65414                                    NaN                        NaN
# 65416                                    NaN                        NaN
# 65429                                    NaN                        NaN
#
#                             WebframeHaveWorkedWith  \
# ResponseId
# 4           jQuery;Next.js;Node.js;React;WordPress
# 17                                         Node.js
# 18                            jQuery;Next.js;React
# 59                                  Django;Node.js
# 76                                   Node.js;React
# ...                                            ...
# 65340           Django;Flask;Next.js;Node.js;React
# 65384                                          NaN
# 65414                                          NaN
# 65416                                          NaN
# 65429                                          NaN
#
#                   WebframeWantToWorkWith               WebframeAdmired  \
# ResponseId
# 4           jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 17                         Deno;Solid.js                           NaN
# 18                         Next.js;React                 Next.js;React
# 59                                Django                        Django
# 76                                   NaN                           NaN
# ...                                  ...                           ...
# 65340                                NaN                           NaN
# 65384                                NaN                           NaN
# 65414                                NaN                           NaN
# 65416                                NaN                           NaN
# 65429                                NaN                           NaN
#
#            EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# ResponseId
# 4                     Rasberry Pi                    NaN             NaN
# 17                            NaN                    NaN             NaN
# 18                            NaN                    NaN             NaN
# 59                        Arduino                Arduino         Arduino
# 76                            NaN                    NaN             NaN
# ...                           ...                    ...             ...
# 65340         Arduino;Rasberry Pi                    NaN             NaN
# 65384                         NaN                    NaN             NaN
# 65414                         NaN                    NaN             NaN
# 65416                         NaN                    NaN             NaN
# 65429                         NaN                    NaN             NaN
#
#                   MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# ResponseId
# 4           NumPy;Pandas;Ruff;TensorFlow                    NaN
# 17                                   NaN                    NaN
# 18                          React Native    OpenGL;React Native
# 59                                   NaN                    NaN
# 76            Flutter;Ionic;React Native                    NaN
# ...                                  ...                    ...
# 65340                                NaN                    NaN
# 65384                                NaN                    NaN
# 65414                                NaN                    NaN
# 65416                                NaN                    NaN
# 65429                                NaN                    NaN
#
#            MiscTechAdmired ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# ResponseId
# 4                      NaN          Docker;npm;Pip   Docker;Kubernetes;npm
# 17                     NaN                npm;Vite                    Vite
# 18            React Native    Docker;npm;Vite;Yarn        Docker;pnpm;Vite
# 59                     NaN                     npm                     NaN
# 76                     NaN                     npm                     NaN
# ...                    ...                     ...                     ...
# 65340                  NaN                     NaN                     NaN
# 65384                  NaN                     NaN                     NaN
# 65414                  NaN                     NaN                     NaN
# 65416                  NaN                     NaN                     NaN
# 65429                  NaN                     NaN                     NaN
#
#            ToolsTechAdmired  \
# ResponseId
# 4                Docker;npm
# 17                     Vite
# 18              Docker;Vite
# 59                      NaN
# 76                      NaN
# ...                     ...
# 65340                   NaN
# 65384                   NaN
# 65414                   NaN
# 65416                   NaN
# 65429                   NaN
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 4                                                         NaN
# 17                                         Visual Studio Code
# 18                                                   VSCodium
# 59                    Code::Blocks;PyCharm;Visual Studio Code
# 76          Android Studio;IntelliJ IDEA;Notepad++;Sublime...
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                NEWCollabToolsWantToWorkWith            NEWCollabToolsAdmired  \
# ResponseId
# 4                                       NaN                              NaN
# 17                       Visual Studio Code               Visual Studio Code
# 18                                 VSCodium                         VSCodium
# 59          Code::Blocks;Visual Studio Code  Code::Blocks;Visual Studio Code
# 76                                      NaN                              NaN
# ...                                     ...                              ...
# 65340                                   NaN                              NaN
# 65384                                   NaN                              NaN
# 65414                                   NaN                              NaN
# 65416                                   NaN                              NaN
# 65429                                   NaN                              NaN
#
#                  OpSysPersonal use OpSysProfessional use  \
# ResponseId
# 4                              NaN                   NaN
# 17                            Arch                   NaN
# 18                         Windows               Windows
# 59          Android;Ubuntu;Windows               Windows
# 76          Android;Ubuntu;Windows                   NaN
# ...                            ...                   ...
# 65340                          NaN                   NaN
# 65384                          NaN                   NaN
# 65414                          NaN                   NaN
# 65416                          NaN                   NaN
# 65429                          NaN                   NaN
#
#            OfficeStackAsyncHaveWorkedWith   OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 4                                     NaN                              NaN
# 17                                    NaN                              NaN
# 18                           Azure Devops                     Azure Devops
# 59                                    NaN                              NaN
# 76          Asana;Clickup;Miro;Monday.com  Notion;Stack Overflow for Teams
# ...                                   ...                              ...
# 65340                                 NaN                              NaN
# 65384                                 NaN                              NaN
# 65414                                 NaN                              NaN
# 65416                                 NaN                              NaN
# 65429                                 NaN                              NaN
#
#            OfficeStackAsyncAdmired  \
# ResponseId
# 4                              NaN
# 17                             NaN
# 18                    Azure Devops
# 59                             NaN
# 76                             NaN
# ...                            ...
# 65340                          NaN
# 65384                          NaN
# 65414                          NaN
# 65416                          NaN
# 65429                          NaN
#
#                             OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 4                                                     NaN
# 17                                                Discord
# 18          Google Meet;Microsoft Teams;Telegram;Whatsapp
# 59                              Discord;Telegram;Whatsapp
# 76                              Skype;Slack;Whatsapp;Zoom
# ...                                                   ...
# 65340                                                 NaN
# 65384                                                 NaN
# 65414                                                 NaN
# 65416                                                 NaN
# 65429                                                 NaN
#
#            OfficeStackSyncWantToWorkWith       OfficeStackSyncAdmired  \
# ResponseId
# 4                                    NaN                          NaN
# 17                               Discord                      Discord
# 18           Google Meet;Microsoft Teams  Google Meet;Microsoft Teams
# 59                              Whatsapp                     Whatsapp
# 76                   Discord;Google Chat                          NaN
# ...                                  ...                          ...
# 65340                                NaN                          NaN
# 65384                                NaN                          NaN
# 65414                                NaN                          NaN
# 65416                                NaN                          NaN
# 65429                                NaN                          NaN
#
#                                    AISearchDevHaveWorkedWith  \
# ResponseId
# 4                                                        NaN
# 17          ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 18                                                   ChatGPT
# 59                                                   ChatGPT
# 76                                             Google Gemini
# ...                                                      ...
# 65340                                                    NaN
# 65384                                                    NaN
# 65414                                                    NaN
# 65416                                                    NaN
# 65429                                                    NaN
#
#                                    AISearchDevWantToWorkWith  \
# ResponseId
# 4                                                        NaN
# 17          ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 18                              GitHub Copilot;Google Gemini
# 59                              GitHub Copilot;Google Gemini
# 76                                                       NaN
# ...                                                      ...
# 65340                                                    NaN
# 65384                                                    NaN
# 65414                                                    NaN
# 65416                                                    NaN
# 65429                                                    NaN
#
#                                           AISearchDevAdmired  \
# ResponseId
# 4                                                        NaN
# 17          ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 18                                                       NaN
# 59                                                       NaN
# 76                                                       NaN
# ...                                                      ...
# 65340                                                    NaN
# 65384                                                    NaN
# 65414                                                    NaN
# 65416                                                    NaN
# 65429                                                    NaN
#
#                                NEWSOSites  \
# ResponseId
# 4                          Stack Overflow
# 17                         Stack Overflow
# 18          Stack Overflow;Stack Exchange
# 59          Stack Overflow;Stack Exchange
# 76          Stack Overflow;Stack Exchange
# ...                                   ...
# 65340       Stack Overflow;Stack Exchange
# 65384                      Stack Exchange
# 65414       Stack Overflow;Stack Exchange
# 65416                      Stack Overflow
# 65429       Stack Overflow;Stack Exchange
#
#                                     SOVisitFreq SOAccount  \
# ResponseId
# 4                         Daily or almost daily        No
# 17                         A few times per week       Yes
# 18          Less than once per month or monthly       Yes
# 59                         A few times per week       Yes
# 76                        Daily or almost daily       Yes
# ...                                         ...       ...
# 65340                     Daily or almost daily        No
# 65384       Less than once per month or monthly       Yes
# 65414           A few times per month or weekly        No
# 65416                      A few times per week       Yes
# 65429           A few times per month or weekly        No
#
#                                                    SOPartFreq  \
# ResponseId
# 4                                                         NaN
# 17                        Less than once per month or monthly
# 18                        Less than once per month or monthly
# 59                        Less than once per month or monthly
# 76                                       A few times per week
# ...                                                       ...
# 65340                                                     NaN
# 65384       I have never participated in Q&A on Stack Over...
# 65414                                                     NaN
# 65416                     Less than once per month or monthly
# 65429                                                     NaN
#
#                                                         SOHow  \
# ResponseId
# 4                              Quickly finding code solutions
# 17          Quickly finding code solutions;Learning new-to...
# 18                             Quickly finding code solutions
# 59          Quickly finding code solutions;Finding reliabl...
# 76          Quickly finding code solutions;Finding reliabl...
# ...                                                       ...
# 65340       Quickly finding code solutions;Finding reliabl...
# 65384       Quickly finding code solutions;Finding reliabl...
# 65414                          Quickly finding code solutions
# 65416       Quickly finding code solutions;Engage with com...
# 65429       Quickly finding code solutions;Finding reliabl...
#
#                      SOComm                 AISelect          AISent  \
# ResponseId
# 4            No, not really                      Yes  Very favorable
# 17           No, not really                      Yes       Favorable
# 18                  Neutral   No, but I plan to soon       Favorable
# 59                  Neutral                      Yes       Favorable
# 76                  Neutral   No, but I plan to soon       Favorable
# ...                     ...                      ...             ...
# 65340               Neutral                      NaN             NaN
# 65384       Yes, definitely                      NaN             NaN
# 65414        No, not at all                      Yes          Unsure
# 65416         Yes, somewhat                      NaN             NaN
# 65429               Neutral  No, and I don't plan to             NaN
#
#                                                         AIBen  \
# ResponseId
# 4           Increase productivity;Greater efficiency;Impro...
# 17                   Increase productivity;Greater efficiency
# 18                                                        NaN
# 59          Increase productivity;Greater efficiency;Make ...
# 76                                                        NaN
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414       Increase productivity;Speed up learning;Make w...
# 65416                                                     NaN
# 65429                                                     NaN
#
#                         AIAcc                                      AIComplex  \
# ResponseId
# 4              Somewhat trust                  Bad at handling complex tasks
# 17          Somewhat distrust  Neither good or bad at handling complex tasks
# 18                        NaN                                            NaN
# 59             Somewhat trust  Neither good or bad at handling complex tasks
# 76                        NaN                                            NaN
# ...                       ...                                            ...
# 65340                     NaN                                            NaN
# 65384                     NaN                                            NaN
# 65414          Somewhat trust                  Bad at handling complex tasks
# 65416                     NaN                                            NaN
# 65429                     NaN                                            NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 4           Learning about a codebase;Project planning;Wri...
# 17                                  Writing code;Testing code
# 18                                                        NaN
# 59              Debugging and getting help;Search for answers
# 76                                                        NaN
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                     AIToolInterested in Using  \
# ResponseId
# 4           Testing code;Committing and reviewing code;Pre...
# 17          Learning about a codebase;Documenting code;Sea...
# 18                                                        NaN
# 59                                                        NaN
# 76                                                        NaN
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                 AIToolNot interested in Using  \
# ResponseId
# 4                                                         NaN
# 17          Project planning;Debugging and getting help;Co...
# 18                                                        NaN
# 59                                                        NaN
# 76                                                        NaN
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                    AINextMuch more integrated  \
# ResponseId
# 4           Learning about a codebase;Project planning;Wri...
# 17                                                        NaN
# 18                                                        NaN
# 59                                                        NaN
# 76                                                        NaN
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                AINextNo change       AINextMore integrated  \
# ResponseId
# 4                          NaN                         NaN
# 17                         NaN   Writing code;Testing code
# 18                         NaN                         NaN
# 59          Search for answers  Debugging and getting help
# 76                         NaN                         NaN
# ...                        ...                         ...
# 65340                      NaN                         NaN
# 65384                      NaN                         NaN
# 65414                      NaN                         NaN
# 65416                      NaN                         NaN
# 65429                      NaN                         NaN
#
#            AINextLess integrated AINextMuch less integrated      AIThreat  \
# ResponseId
# 4                            NaN                        NaN            No
# 17                           NaN                        NaN            No
# 18                           NaN                        NaN  I'm not sure
# 59                           NaN                        NaN            No
# 76                           NaN                        NaN            No
# ...                          ...                        ...           ...
# 65340                        NaN                        NaN           NaN
# 65384                        NaN                        NaN           NaN
# 65414                        NaN                        NaN           NaN
# 65416                        NaN                        NaN           NaN
# 65429                        NaN                        NaN           NaN
#
#                                                      AIEthics  \
# ResponseId
# 4           Circulating misinformation or disinformation;M...
# 17          Circulating misinformation or disinformation;M...
# 18          Replacing jobs without options for new employm...
# 59          Circulating misinformation or disinformation;M...
# 76          Replacing jobs without options for new employm...
# ...                                                       ...
# 65340                                                     NaN
# 65384                                                     NaN
# 65414                                                     NaN
# 65416                                                     NaN
# 65429                                                     NaN
#
#                                                  AIChallenges TBranch ICorPM  \
# ResponseId
# 4                           Don’t trust the output or answers     NaN    NaN
# 17                                                        NaN     NaN    NaN
# 18                                   Lack of executive buy-in     NaN    NaN
# 59                                                        NaN     NaN    NaN
# 76          Don’t trust the output or answers;Not everyone...     NaN    NaN
# ...                                                       ...     ...    ...
# 65340                                                     NaN     NaN    NaN
# 65384                                                     NaN     NaN    NaN
# 65414                                                     NaN     NaN    NaN
# 65416                                                     NaN     NaN    NaN
# 65429                                                     NaN     NaN    NaN
#
#             WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 4               NaN         NaN         NaN         NaN         NaN
# 17              NaN         NaN         NaN         NaN         NaN
# 18              NaN         NaN         NaN         NaN         NaN
# 59              NaN         NaN         NaN         NaN         NaN
# 76              NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 65340           NaN         NaN         NaN         NaN         NaN
# 65384           NaN         NaN         NaN         NaN         NaN
# 65414           NaN         NaN         NaN         NaN         NaN
# 65416           NaN         NaN         NaN         NaN         NaN
# 65429           NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5 Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9  \
# ResponseId
# 4                  NaN         NaN         NaN         NaN         NaN
# 17                 NaN         NaN         NaN         NaN         NaN
# 18                 NaN         NaN         NaN         NaN         NaN
# 59                 NaN         NaN         NaN         NaN         NaN
# 76                 NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 65340              NaN         NaN         NaN         NaN         NaN
# 65384              NaN         NaN         NaN         NaN         NaN
# 65414              NaN         NaN         NaN         NaN         NaN
# 65416              NaN         NaN         NaN         NaN         NaN
# 65429              NaN         NaN         NaN         NaN         NaN
#
#            Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering  \
# ResponseId
# 4                  NaN         NaN         NaN           NaN           NaN
# 17                 NaN         NaN         NaN           NaN           NaN
# 18                 NaN         NaN         NaN           NaN           NaN
# 59                 NaN         NaN         NaN           NaN           NaN
# 76                 NaN         NaN         NaN           NaN           NaN
# ...                ...         ...         ...           ...           ...
# 65340              NaN         NaN         NaN           NaN           NaN
# 65384              NaN         NaN         NaN           NaN           NaN
# 65414              NaN         NaN         NaN           NaN           NaN
# 65416              NaN         NaN         NaN           NaN           NaN
# 65429              NaN         NaN         NaN           NaN           NaN
#
#            Frustration ProfessionalTech ProfessionalCloud  \
# ResponseId
# 4                  NaN              NaN               NaN
# 17                 NaN              NaN               NaN
# 18                 NaN              NaN               NaN
# 59                 NaN              NaN               NaN
# 76                 NaN              NaN               NaN
# ...                ...              ...               ...
# 65340              NaN              NaN               NaN
# 65384              NaN              NaN               NaN
# 65414              NaN              NaN               NaN
# 65416              NaN              NaN               NaN
# 65429              NaN              NaN               NaN
#
#            ProfessionalQuestion Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 4                           NaN      NaN             NaN             NaN
# 17                          NaN      NaN             NaN             NaN
# 18                          NaN      NaN             NaN             NaN
# 59                          NaN      NaN             NaN             NaN
# 76                          NaN      NaN             NaN             NaN
# ...                         ...      ...             ...             ...
# 65340                       NaN      NaN             NaN             NaN
# 65384                       NaN      NaN             NaN             NaN
# 65414                       NaN      NaN             NaN             NaN
# 65416                       NaN      NaN             NaN             NaN
# 65429                       NaN      NaN             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 4                      NaN             NaN             NaN             NaN
# 17                     NaN             NaN             NaN             NaN
# 18                     NaN             NaN             NaN             NaN
# 59                     NaN             NaN             NaN             NaN
# 76                     NaN             NaN             NaN             NaN
# ...                    ...             ...             ...             ...
# 65340                  NaN             NaN             NaN             NaN
# 65384                  NaN             NaN             NaN             NaN
# 65414                  NaN             NaN             NaN             NaN
# 65416                  NaN             NaN             NaN             NaN
# 65429                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# ResponseId
# 4                      NaN              NaN              NaN
# 17                     NaN              NaN              NaN
# 18                     NaN              NaN              NaN
# 59                     NaN              NaN              NaN
# 76                     NaN              NaN              NaN
# ...                    ...              ...              ...
# 65340                  NaN              NaN              NaN
# 65384                  NaN              NaN              NaN
# 65414                  NaN              NaN              NaN
# 65416                  NaN              NaN              NaN
# 65429                  NaN              NaN              NaN
#
#                      SurveyLength SurveyEase  ConvertedCompYearly  JobSat
# ResponseId
# 4                        Too long       Easy                  NaN     NaN
# 17          Appropriate in length       Easy                  NaN     NaN
# 18          Appropriate in length       Easy                  NaN     NaN
# 59          Appropriate in length       Easy                  NaN     NaN
# 76          Appropriate in length       Easy                  NaN     NaN
# ...                           ...        ...                  ...     ...
# 65340                         NaN        NaN                  NaN     NaN
# 65384                         NaN        NaN                  NaN     NaN
# 65414                         NaN        NaN                  NaN     NaN
# 65416                         NaN        NaN                  NaN     NaN
# 65429                         NaN        NaN                  NaN     NaN
#
# [6335 rows x 113 columns]

# %%
filt4 = (df['LanguageHaveWorkedWith'].str.contains('Python', na = False))   #string operation filter

# %%
df.loc[filt4, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2        Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 4        C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                  C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 6        Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 11                                  JavaScript;Python;Ruby
#                                ...
# 65422                       Bash/Shell (all shells);Python
# 65428                                    MATLAB;Python;SQL
# 65432    Bash/Shell (all shells);C;C#;C++;Delphi;Groovy...
# 65436             C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65437     C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 30795, dtype: str
